# %% [markdown]
# # Setup

# %%
save_files = True

# %%
# %%capture
# %pip install git+https://github.com/neelnanda-io/TransformerLens.git

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import einops
from fancy_einsum import einsum
import tqdm.notebook as tqdm
import random
from pathlib import Path
# import plotly.express as px
from torch.utils.data import DataLoader

from jaxtyping import Float, Int
from typing import List, Union, Optional
from functools import partial
import copy

import itertools
from transformers import AutoModelForCausalLM, AutoConfig, AutoTokenizer
import dataclasses
import datasets
from IPython.display import HTML

import pickle
from google.colab import files

import matplotlib.pyplot as plt
import statistics

# %%
import transformer_lens
import transformer_lens.utils as utils
from transformer_lens.hook_points import (
    HookedRootModule,
    HookPoint,
)  # Hooking utilities
from transformer_lens import HookedTransformer #, HookedTransformerConfig, FactoredMatrix, ActivationCache

# %% [markdown]
# We turn automatic differentiation off, to save GPU memory, as this notebook focuses on model inference not model training.

# %%
torch.set_grad_enabled(False)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import pdb

# %% [markdown]
# ## Import functions from repo

# %%
# !git clone https://github.com/apartresearch/seqcont_circuits.git
# %cd /content/seqcont_circuits/src/iter_node_pruning
# Out:
# Cloning into 'seqcont_circuits'...
# remote: Enumerating objects: 909, done.
# remote: Counting objects: 100% (375/375), done.
# remote: Compressing objects: 100% (243/243), done.
# remote: Total 909 (delta 208), reused 284 (delta 121), pack-reused 534
# Receiving objects: 100% (909/909), 17.08 MiB | 19.65 MiB/s, done.
# Resolving deltas: 100% (571/571), done.
# /content/seqcont_circuits/src/iter_node_pruning

# %%
## comment this out when debugging functions in colab to use funcs defined in colab

# don't improt this
# # from dataset import Dataset

from metrics import *
from head_ablation_fns import *
from mlp_ablation_fns import *
from node_ablation_fns import *
from loop_node_ablation_fns import *

# %% [markdown]
# ## fns

# %%
class Dataset:
    def __init__(self, prompts, pos_dict, tokenizer):  # , S1_is_first=False
        self.prompts = prompts
        self.tokenizer = tokenizer
        self.N = len(prompts)
        self.max_len = max(
            [
                len(self.tokenizer(prompt["text"]).input_ids)
                for prompt in self.prompts
            ]
        )
        all_ids = [0 for prompt in self.prompts] # only 1 template
        all_ids_ar = np.array(all_ids)
        self.groups = []
        for id in list(set(all_ids)):
            self.groups.append(np.where(all_ids_ar == id)[0])

        texts = [ prompt["text"] for prompt in self.prompts ]
        self.toks = torch.Tensor(self.tokenizer(texts, padding=True).input_ids).type(
            torch.int
        )
        self.corr_tokenIDs = [
            # self.tokenizer.encode(" " + prompt["corr"])[0] for prompt in self.prompts
            self.tokenizer.encode(prompt["corr"])[0] for prompt in self.prompts
        ]
        self.incorr_tokenIDs = [
            # self.tokenizer.encode(" " + prompt["incorr"])[0] for prompt in self.prompts
            self.tokenizer.encode(prompt["incorr"])[0] for prompt in self.prompts
        ]

        # word_idx: for every prompt, find the token index of each target token and "end"
        # word_idx is a dict whose values are tensor with an element for each prompt. The element is the targ token's ind at that prompt
        self.word_idx = {}
        # for targ in [key for key in self.prompts[0].keys() if (key != 'text' and key != 'corr' and key != 'incorr')]:
        for targ in [key for key in pos_dict]:
            targ_lst = []
            for prompt in self.prompts:
                input_text = prompt["text"]
                tokens = self.tokenizer.tokenize(input_text)
                # if S1_is_first and targ == "S1":  # only use this if first token doesn't have space Ġ in front
                #     target_token = prompt[targ]
                # else:
                #     target_token = "Ġ" + prompt[targ]
                # target_index = tokens.index(target_token)
                target_index = pos_dict[targ]
                targ_lst.append(target_index)
            self.word_idx[targ] = torch.tensor(targ_lst)

        targ_lst = []
        for prompt in self.prompts:
            input_text = prompt["text"]
            tokens = self.tokenizer.tokenize(input_text)
            end_token_index = len(tokens) - 1
            targ_lst.append(end_token_index)
        self.word_idx["end"] = torch.tensor(targ_lst)

    def __len__(self):
        return self.N

# %%
def generate_prompts_list_longer(text, tokens):
    prompts_list = []
    prompt_dict = {
        'corr': str(1),
        'incorr': str(2),
        'text': text
        # 'text': model.to_string(tokens)[0]
        }
    tokens_as_strs = model.tokenizer.tokenize(text)
    # tokens_as_strs = model.to_string(tokens)[0].split()
    # for i in range(tokens.shape[1]):
    for i, tok in enumerate(tokens_as_strs):
        prompt_dict['S'+str(i)] = tok
    # for i, tok in enumerate(tokens):
    #     prompt_dict['S'+str(i)] = model.to_string(tok)

    # prompt_dict = {
    #     'corr': '4',
    #     'incorr': '3',
    #     'text': model.to_string(tokens)[0]
    # }
    # # list_tokens = tokenizer.tokenize('1 2 3 ')
    # tokens_as_strs = model.to_string(tokens)[0].split()
    # for i, tok_as_str in enumerate(tokens_as_strs):
    #     if tok_as_str == '▁':
    #         prompt_dict['S'+str(i)] = ' '
    #     else:
    #         prompt_dict['S'+str(i)] = tok_as_str
    prompts_list.append(prompt_dict)
    return prompts_list

# %% [markdown]
# # Load Model

# %%
from transformers import LlamaForCausalLM, LlamaTokenizer

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
LLAMA_2_7B_CHAT_PATH = "meta-llama/Llama-2-7b-chat-hf"

tokenizer = LlamaTokenizer.from_pretrained(LLAMA_2_7B_CHAT_PATH)
# tokenizer = LlamaTokenizer.from_pretrained(LLAMA_2_7B_CHAT_PATH, use_fast= False, add_prefix_space= False)
hf_model = LlamaForCausalLM.from_pretrained(LLAMA_2_7B_CHAT_PATH, low_cpu_mem_usage=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]

# %%
import transformer_lens.utils as utils
from transformer_lens.hook_points import HookPoint
from transformer_lens import HookedTransformer

# %%
model = HookedTransformer.from_pretrained(
    LLAMA_2_7B_CHAT_PATH,
    hf_model = hf_model,
    tokenizer = tokenizer,
    device = "cpu",
    fold_ln = False,
    center_writing_weights = False,
    center_unembed = False,
)

del hf_model

model = model.to("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# Loaded pretrained model meta-llama/Llama-2-7b-chat-hf into HookedTransformer
# Moving model to device:  cuda

# %% [markdown]
# # new ablation functions

# %%
def get_heads_actv_mean(
    means_dataset: Dataset,
    model: HookedTransformer
) -> Float[Tensor, "layer batch seq head_idx d_head"]:
    '''
    Output: The mean activations of a head's output
    '''
    _, means_cache = model.run_with_cache(
        means_dataset.toks.long(),
        return_type=None,
        names_filter=lambda name: name.endswith("z"),
    )
    n_layers, n_heads, d_head = model.cfg.n_layers, model.cfg.n_heads, model.cfg.d_head
    batch, seq_len = len(means_dataset), means_dataset.max_len
    means = t.zeros(size=(n_layers, batch, seq_len, n_heads, d_head), device=model.cfg.device)

    # for layer in range(model.cfg.n_layers):
    #     z_for_this_layer: Float[Tensor, "batch seq head d_head"] = means_cache[utils.get_act_name("z", layer)]
    #     for template_group in means_dataset.groups:
    #         z_for_this_template = z_for_this_layer[template_group]
    #         z_means_for_this_template = einops.reduce(z_for_this_template, "batch seq head d_head -> seq head d_head", "mean")
    #         if z_means_for_this_template.shape[0] == 5:
    #             pdb.set_trace()
    #         means[layer, template_group] = z_means_for_this_template

    del(means_cache)

    return means

# %%
# def mask_circ_heads(
#     means_dataset: Dataset,
#     model: HookedTransformer,
#     circuit: Dict[str, List[Tuple[int, int]]],
#     seq_pos_to_keep: Dict[str, str],
# ) -> Dict[int, Bool[Tensor, "batch seq head"]]:
#     '''
#     Output: for each layer, a mask of circuit components that should not be ablated
#     '''
#     heads_and_posns_to_keep = {}
#     batch, seq, n_heads = len(means_dataset), means_dataset.max_len, model.cfg.n_heads

#     for layer in range(model.cfg.n_layers):

#         mask = t.zeros(size=(batch, seq, n_heads))

#         for (head_type, head_list) in circuit.items():
#             seq_pos = seq_pos_to_keep[head_type]
#             # if seq_pos == 'S7':
#             #     pdb.set_trace()
#             indices = means_dataset.word_idx[seq_pos] # modify this for key vs query pos. curr, this is query
#             for (layer_idx, head_idx) in head_list:
#                 if layer_idx == layer:
#                     # if indices.item() == 7:
#                     #     pdb.set_trace()
#                     mask[:, indices, head_idx] = 1
#                     # mask[:, :, head_idx] = 1  # keep L.H at all pos

#         heads_and_posns_to_keep[layer] = mask.bool()
#     # pdb.set_trace()
#     return heads_and_posns_to_keep

# %%
def mask_circ_heads(
    means_dataset: Dataset,
    model: HookedTransformer,
    circuit: Dict[str, List[Tuple[int, int]]],
    seq_pos_to_keep: Dict[str, str],
) -> Dict[int, Bool[Tensor, "batch seq head"]]:
    '''
    Output: for each layer, a mask of circuit components that should not be ablated
    '''
    heads_and_posns_to_keep = {}
    # batch, seq, n_heads = len(means_dataset), means_dataset.max_len, model.cfg.n_heads
    batch, seq, n_heads = len(means_dataset), len(circuit.keys()), model.cfg.n_heads
    print(seq)

    for layer in range(model.cfg.n_layers):

        mask = t.zeros(size=(batch, seq, n_heads))

        for (head_type, head_list) in circuit.items():
            seq_pos = seq_pos_to_keep[head_type]
            indices = means_dataset.word_idx[seq_pos] # modify this for key vs query pos. curr, this is query
            for (layer_idx, head_idx) in head_list:
                if layer_idx == layer:
                    # mask[:, indices, head_idx] = 1
                    mask[:, :, head_idx] = 1

        heads_and_posns_to_keep[layer] = mask.bool()

    return heads_and_posns_to_keep

# %%
def hook_func_mask_head(
    z: Float[Tensor, "batch seq head d_head"],
    hook: HookPoint,
    # components_to_keep: Dict[int, Bool[Tensor, "batch seq head"]],
    # means: Float[Tensor, "layer batch seq head d_head"],
    circuit: Dict[str, List[Tuple[int, int]]],
) -> Float[Tensor, "batch seq head d_head"]:
    '''
    Use this to not mask components
    '''
    # mask_for_this_layer = components_to_keep[hook.layer()].unsqueeze(-1).to(z.device)
    # z = t.where(mask_for_this_layer, z, means[hook.layer()])

    ###
    # heads_and_posns_to_keep = {}
    # batch, seq, n_heads = z.shape[0], z.shape[1], model.cfg.n_heads  # components_to_keep[0].shape[0] is batch

    # for layer in range(model.cfg.n_layers):

    #     mask = t.zeros(size=(batch, seq, n_heads))

    #     for (head_type, head_list) in circuit.items():
    #         # seq_pos = seq_pos_to_keep[head_type]
    #         # indices = means_dataset.word_idx[seq_pos] # modify this for key vs query pos. curr, this is query
    #         for (layer_idx, head_idx) in head_list:
    #             if layer_idx == layer:
    #                 # mask[:, indices, head_idx] = 1
    #                 mask[:, :, head_idx] = 1

    #     heads_and_posns_to_keep[layer] = mask.bool()
    ###
    mask_for_this_layer = t.zeros(size=(z.shape[0], z.shape[1], z.shape[2]))
    for (head_type, head_list) in circuit.items():
        # seq_pos = seq_pos_to_keep[head_type]
        # indices = means_dataset.word_idx[seq_pos] # modify this for key vs query pos. curr, this is query
        for (layer_idx, head_idx) in head_list:
            if layer_idx == hook.layer():
                # mask[:, indices, head_idx] = 1
                mask_for_this_layer[:, :, head_idx] = 1

    mask_for_this_layer = mask_for_this_layer.bool()
    mask_for_this_layer = mask_for_this_layer.unsqueeze(-1).to(z.device)  # d_model is 1; then is broadcast in where

    z = t.where(mask_for_this_layer, z, 0)

    return z

# %%
def add_ablation_hook_head(
    model: HookedTransformer,
    means_dataset: Dataset,
    circuit: Dict[str, List[Tuple[int, int]]],
    seq_pos_to_keep: Dict[str, str],
    is_permanent: bool = True,
) -> HookedTransformer:
    '''
    Ablate the model, except as components and positions to keep
    '''

    model.reset_hooks(including_permanent=True)
    means = get_heads_actv_mean(means_dataset, model)
    components_to_keep = mask_circ_heads(means_dataset, model, circuit, seq_pos_to_keep)

    hook_fn = partial(
        hook_func_mask_head,
        # components_to_keep=components_to_keep,
        # means=means,
        circuit=circuit,
    )

    model.add_hook(lambda name: name.endswith("z"), hook_fn, is_permanent=is_permanent)
    return model

# %%
# from dataset import Dataset
from transformer_lens import HookedTransformer, utils
from transformer_lens.hook_points import HookPoint
import einops
from functools import partial
import torch as t
from torch import Tensor
from typing import Dict, Tuple, List
from jaxtyping import Float, Bool

# from head_ablation_fns import *
# from mlp_ablation_fns import *

def add_ablation_hook_MLP_head(
    model: HookedTransformer,
    means_dataset: Dataset,
    heads_lst, mlp_lst,
    is_permanent: bool = True,
) -> HookedTransformer:
    CIRCUIT = {}
    SEQ_POS_TO_KEEP = {}
    # for i in range(len(model.tokenizer.tokenize(means_dataset.prompts[0]['text']))):
    num_pos = len(model.tokenizer(means_dataset.prompts[0]['text']).input_ids)
    for i in range(num_pos ):
        CIRCUIT['S'+str(i)] = heads_lst
        # if i == len(model.tokenizer.tokenize(means_dataset.prompts[0]['text'])) - 1:
        # if i == num_pos - 1:
        #     SEQ_POS_TO_KEEP['S'+str(i)] = 'end'
        # else:
        SEQ_POS_TO_KEEP['S'+str(i)] = 'S'+str(i)

    model.reset_hooks(including_permanent=True)

    # Compute the mean of each head's output on the ABC dataset, grouped by template
    means = get_heads_actv_mean(means_dataset, model)
    # Convert this into a boolean map
    components_to_keep = mask_circ_heads(means_dataset, model, CIRCUIT, SEQ_POS_TO_KEEP)

    # Get a hook function which will patch in the mean z values for each head, at
    # all positions which aren't important for the circuit
    hook_fn = partial(
        hook_func_mask_head,
        # components_to_keep=components_to_keep,
        # means=means,
        circuit=CIRCUIT,
    )

    # Apply hook
    model.add_hook(lambda name: name.endswith("z"), hook_fn, is_permanent=is_permanent)

    # if all_entries_true(components_to_keep) == False:
    #     pdb.set_trace()
    ########################
    # CIRCUIT = {}
    # SEQ_POS_TO_KEEP = {}
    # # for i in range(len(model.tokenizer.tokenize(means_dataset.prompts[0]['text']))):
    # num_pos = len(model.tokenizer(means_dataset.prompts[0]['text']).input_ids)
    # for i in range(num_pos ):
    #     CIRCUIT['S'+str(i)] = mlp_lst
    #     # if i == len(model.tokenizer.tokenize(means_dataset.prompts[0]['text'])) - 1:
    #     # if i == num_pos - 1:
    #     #     SEQ_POS_TO_KEEP['S'+str(i)] = 'end'
    #     # else:
    #     SEQ_POS_TO_KEEP['S'+str(i)] = 'S'+str(i)

    # # Compute the mean of each head's output on the ABC dataset, grouped by template
    # means = get_MLPs_actv_mean(means_dataset, model)

    # # Convert this into a boolean map
    # components_to_keep = mask_circ_MLPs(means_dataset, model, CIRCUIT, SEQ_POS_TO_KEEP)

    # # Get a hook function which will patch in the mean z values for each head, at
    # # all positions which aren't important for the circuit
    # hook_fn = partial(
    #     hook_func_mask_mlp_out,
    #     components_to_keep=components_to_keep,
    #     means=means
    # )

    # model.add_hook(lambda name: name.endswith("mlp_out"), hook_fn, is_permanent=True)

    return model

# %%
def all_entries_true(tensor_dict):
    for key, tensor in tensor_dict.items():
        if not torch.all(tensor).item():
            return False
    return True

# %% [markdown]
# # ablation fns mult tok answers

# %%
def clean_gen(model, clean_text, corr_ans):
    model.reset_hooks(including_permanent=True)  #must do this after running with mean ablation hook
    tokens = model.to_tokens(clean_text).to(device)
    # tokens = tokens[:, 1:] # get rid of prepend bos when using model.to_tokens

    total_score = 0
    corr_ans_tokLen = 0
    ans_so_far = ''
    # while True:
    for i in range(5):
        print(f"Sequence so far: {model.to_string(tokens)[0]!r}")
        logits = model(tokens)
        next_token = logits[0, -1].argmax(dim=-1) # Get the predicted token at the end of our sequence
        next_char = model.to_string(next_token)

        corr_logits = logits[:, -1, next_token]
        total_score += corr_logits
        print(f"logit diff of new char: {corr_logits}")

        ans_so_far += next_char
        corr_ans_tokLen += 1
        print(f"{tokens.shape[-1]+1}th char = {next_char!r}")
        if ans_so_far == corr_ans:
            print('\nTotal logit diff: ', total_score.item())
            break

        # Define new input sequence, by appending the previously generated token
        tokens = torch.cat([tokens, next_token[None, None]], dim=-1)
        # if next_char == '':
        #     next_char = ' '
        # clean_text = clean_text + next_char
        # tokens = model.to_tokens(clean_text).to(device)
    return corr_ans_tokLen

# %%
def ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, corr_ans_tokLen):
    tokens = model.to_tokens(clean_text).to(device)
    prompts_list = generate_prompts_list_longer(clean_text, tokens)

    corr_tokens = model.to_tokens(corr_text).to(device)
    prompts_list_2 = generate_prompts_list_longer(corr_text, corr_tokens)

    model.reset_hooks(including_permanent=True)  #must do this after running with mean ablation hook
    pos_dict = {}
    num_pos = len(model.tokenizer(prompts_list_2[0]['text']).input_ids)
    for i in range(num_pos ):
        pos_dict['S'+str(i)] = i
    dataset_2 = Dataset(prompts_list_2, pos_dict, model.tokenizer)
    model = add_ablation_hook_MLP_head(model, dataset_2, heads_not_ablate, mlps_not_ablate)

    logits = model(tokens)
    next_token = logits[0, -1].argmax(dim=-1)
    next_char = model.to_string(next_token)

    total_score = 0

    for i in range(corr_ans_tokLen):
        if next_char == '':
            next_char = ' '

        clean_text = clean_text + next_char
        print(f"Sequence so far: {clean_text}")
        print(f"{tokens.shape[-1]+1}th char = {next_char!r}")

        tokens = torch.cat([tokens, next_token[None, None]], dim=-1)

        # get new ablation dataset
        # model.reset_hooks(including_permanent=True)  #must do this after running with mean ablation hook

        # corr_text = corr_text + next_char
        # corr_tokens = torch.cat([corr_tokens, next_token[None, None]], dim=-1)
        # prompts_list_2 = generate_prompts_list_longer(corr_text, corr_tokens)

        # pos_dict = {}
        # num_pos = len(model.tokenizer(prompts_list_2[0]['text']).input_ids)
        # for i in range(num_pos ):
        #     pos_dict['S'+str(i)] = i

        # dataset_2 = Dataset(prompts_list_2, pos_dict, model.tokenizer, corr_tokens)

        # model = add_ablation_hook_MLP_head(model, dataset_2, heads_not_ablate, mlps_not_ablate)

        logits = model(tokens)
        next_token = logits[0, -1].argmax(dim=-1) # Get the predicted token at the end of our sequence
        next_char = model.to_string(next_token)

        # new_score = get_logit_diff(logits, dataset)
        # total_score += new_score
        # print(f"corr logit of new char: {new_score}")
    # print('\n Total corr logit: ', total_score.item())

# %%
# Function to randomly choose 50 pairs ensuring less than 10 overlap with heads_of_circ
def choose_heads_to_remove(filtered_pairs, heads_of_circ, num_pairs=50, max_overlap=10):
    while True:
        head_to_remove = random.sample(filtered_pairs, num_pairs)
        overlap_count = len([head for head in head_to_remove if head in heads_of_circ])
        if overlap_count < max_overlap:
            return head_to_remove

# %% [markdown]
# # Define circs

# %%
# nw_circ = [(0, 1), (0, 4), (0, 6), (0, 7), (0, 8), (0, 10), (0, 11), (0, 12), (1, 16), (1, 24), (1, 27), (1, 28), (2, 2), (2, 5), (2, 8), (2, 24), (2, 30), (3, 7), (3, 14), (3, 19), (3, 23), (4, 3), (5, 16), (5, 25), (6, 11), (6, 14), (7, 0), (7, 30), (8, 0), (8, 2), (8, 3), (8, 4), (8, 6), (8, 21), (8, 31), (9, 1), (9, 3), (9, 7), (9, 11), (9, 29), (9, 31), (10, 13), (10, 18), (10, 23), (10, 24), (10, 25), (10, 27), (11, 18), (11, 28), (12, 18), (12, 26), (13, 11), (13, 17), (13, 18), (13, 19), (13, 20), (13, 21), (13, 23), (14, 7), (14, 14), (15, 25), (15, 28), (16, 0), (16, 12), (16, 14), (16, 15), (16, 16), (16, 19), (16, 24), (16, 29), (17, 17), (17, 23), (17, 31), (18, 31), (19, 12), (20, 17), (27, 20), (27, 25), (27, 27), (27, 31), (28, 5), (29, 5)]
# in order from most impt to least based on how much changes perf when ablated
nw_circ = [(20, 17), (5, 25), (16, 0), (29, 5), (3, 19), (6, 11), (15, 25), (8, 0), (16, 24), (8, 4), (7, 0), (6, 14), (16, 29), (5, 16), (12, 26), (4, 3), (3, 7), (7, 30), (11, 28), (28, 5), (17, 31), (13, 11), (13, 20), (12, 18), (1, 27), (10, 13), (18, 31), (8, 6), (9, 1), (0, 4), (2, 2), (9, 11), (19, 12), (1, 16), (13, 17), (9, 7), (11, 18), (2, 24), (10, 18), (9, 31), (9, 29), (2, 30), (2, 5), (1, 24), (2, 8), (15, 28), (27, 31), (16, 14), (3, 23), (3, 14), (10, 23), (27, 20), (8, 3), (14, 7), (14, 14), (16, 15), (8, 2), (17, 17), (0, 1), (10, 27), (16, 19), (0, 8), (0, 12), (1, 28), (0, 11), (17, 23), (0, 10), (0, 6), (13, 19), (8, 31), (10, 24), (16, 12), (13, 23), (13, 21), (27, 27), (9, 3), (27, 25), (16, 16), (8, 21), (0, 7), (13, 18), (10, 25)]

# %%
len(nw_circ)
# Out:
# 82

# %%
impt_months_heads = ([(23, 17), (17, 11), (16, 0), (26, 14), (18, 9), (5, 25), (22, 20), (6, 24), (26, 9), (12, 18), (13, 20), (19, 12), (27, 29), (13, 14), (16, 14), (12, 26), (19, 30), (16, 18), (31, 27), (26, 28), (16, 1), (18, 1), (19, 28), (18, 31), (29, 4), (17, 0), (14, 1), (17, 12), (12, 15), (28, 16), (10, 1), (16, 19), (9, 27), (30, 1), (19, 27), (0, 3), (15, 11), (21, 3), (11, 19), (12, 0), (23, 11), (8, 14), (16, 8), (22, 13), (13, 3), (4, 19), (14, 15), (12, 20), (19, 16), (18, 5)])
months_circ = [(20, 17), (6, 11), (16, 0), (5, 15), (17, 11), (23, 16), (5, 25), (7, 0), (26, 14), (6, 14), (12, 22), (8, 4), (12, 15), (16, 29), (15, 25), (5, 16), (18, 31), (14, 7), (11, 18), (4, 12), (3, 19), (12, 2), (11, 28), (4, 3), (18, 9), (8, 14), (12, 3), (11, 2), (10, 13), (4, 16), (1, 22), (11, 16), (3, 15), (13, 31), (2, 4), (2, 16), (8, 13), (0, 13), (8, 15), (12, 28), (1, 5), (0, 4), (0, 25), (3, 24), (13, 11), (1, 24), (8, 16), (13, 8), (3, 26), (0, 6), (3, 23), (1, 3), (14, 3), (8, 19), (8, 12), (14, 2), (8, 5), (1, 28), (8, 20), (2, 30), (8, 6), (10, 1), (13, 20), (19, 27)]

# %%
spanish_nw = [(20, 17), (16, 0), (7, 0), (22, 25), (8, 0), (12, 26), (6, 11), (16, 24), (5, 25), (12, 18), (0, 7), (2, 22), (7, 30), (0, 2), (1, 24), (14, 31), (3, 23), (2, 30), (14, 22), (1, 31), (0, 21), (2, 24), (11, 28), (2, 2), (13, 20), (8, 11), (12, 22), (13, 10), (2, 0), (3, 24), (11, 25), (2, 26), (17, 22), (13, 11), (8, 6), (12, 31), (2, 31), (12, 6), (11, 18), (13, 12), (11, 23), (2, 17), (13, 19), (11, 24), (13, 7), (14, 7), (3, 30), (17, 19), (1, 4), (9, 26), (13, 9), (1, 23), (12, 23), (2, 3), (8, 8), (13, 5), (0, 13), (13, 6), (1, 5)]

# %%
spanish_months = [(20, 17), (23, 16), (17, 11), (5, 25), (6, 11), (16, 0), (5, 15), (16, 29), (15, 25), (8, 0), (23, 17), (6, 14), (9, 1), (12, 3), (1, 25), (3, 15), (12, 26), (8, 13), (12, 15), (11, 27), (12, 22), (12, 4), (11, 18), (26, 25), (26, 28), (12, 13), (12, 31), (10, 7), (9, 25), (12, 20), (8, 4), (12, 23), (10, 30), (10, 13), (12, 1), (11, 0), (10, 20), (10, 6), (12, 21), (8, 1), (8, 7), (12, 5), (8, 8), (25, 18), (13, 21), (12, 29), (9, 23), (9, 2), (8, 3), (10, 9), (9, 0)]

# %%
intersect_all = list(set(spanish_nw) & set(nw_circ) & set(months_circ) & set(spanish_months))

# %%
intersect_en_nw_months = list(set(nw_circ) & set(months_circ))

# %%
circ_multp_124 = [(4, 3), (6, 11), (16, 0), (5, 15), (12, 2), (17, 31), (18, 14), (3, 6), (12, 15), (3, 24), (15, 15), (15, 25), (7, 27), (22, 9), (3, 19), (5, 25), (4, 4), (6, 31), (5, 29), (4, 16), (11, 28), (16, 27), (21, 17), (12, 22), (8, 0), (5, 16), (6, 14), (2, 30), (7, 21), (1, 15), (14, 7), (0, 15), (12, 18), (9, 5), (2, 2), (6, 24), (22, 25), (6, 5), (10, 9), (0, 1), (6, 12), (15, 24), (16, 19), (16, 29), (16, 4), (10, 25), (3, 7), (12, 23), (0, 2), (14, 4), (7, 30), (3, 26), (6, 27), (3, 15), (10, 10), (9, 27), (4, 26), (6, 1), (6, 20), (22, 14), (7, 29), (11, 16), (14, 3), (3, 2), (6, 28), (10, 30), (4, 12), (3, 23), (0, 5), (4, 18), (15, 21), (16, 13), (3, 10), (4, 28), (4, 22), (11, 13), (9, 1), (9, 3), (9, 2), (3, 9), (6, 30), (4, 27), (3, 13), (10, 11), (11, 12), (16, 8), (3, 22), (4, 19), (2, 0), (3, 28), (3, 3), (4, 23), (1, 29), (12, 24), (11, 18), (1, 22), (7, 25), (0, 24)]

# %%
len(circ_multp_124)
# Out:
# 98

# %%
singleTok_multp = [(12, 22), (16, 0), (17, 31), (14, 19), (22, 25), (29, 5), (6, 24), (5, 26), (21, 17), (0, 15), (2, 5), (16, 27), (19, 22), (0, 13), (0, 14), (3, 13), (13, 11), (15, 15), (18, 26), (19, 6), (0, 21), (13, 14), (5, 15), (19, 10), (3, 2), (4, 0), (9, 5), (5, 2), (10, 5), (19, 11), (10, 6), (0, 25), (18, 31), (14, 2), (16, 24), (3, 16), (20, 17), (8, 0), (14, 27), (15, 5), (5, 16), (9, 2), (7, 24), (5, 24), (6, 5), (6, 14), (7, 30), (20, 16), (4, 3), (5, 9), (0, 2), (6, 11), (2, 28), (9, 31), (1, 19), (7, 18), (3, 24), (0, 29), (6, 22), (13, 6), (6, 31), (2, 2), (2, 12), (2, 18), (6, 19), (8, 1), (2, 20), (16, 5), (7, 13), (8, 16), (15, 9), (9, 7), (5, 0), (6, 4), (3, 15), (13, 2), (7, 19), (14, 24), (6, 3), (16, 2), (16, 13), (16, 31), (2, 7), (2, 0), (2, 24), (16, 10), (6, 23), (1, 20), (13, 1), (1, 18), (8, 30), (9, 9), (7, 8), (1, 30), (6, 15), (16, 26), (0, 30), (0, 12), (8, 29), (2, 23), (9, 6), (20, 20), (3, 27), (8, 2), (16, 7), (2, 1), (6, 7), (6, 18), (16, 4), (9, 10), (3, 29), (16, 9), (2, 13), (6, 25), (2, 22), (0, 7), (2, 19), (16, 8), (19, 30), (5, 28), (1, 1), (1, 22)]

# %%
len(singleTok_multp)
# Out:
# 122

# %%
len(list(set(circ_multp_124) & set(singleTok_multp)))
# Out:
# 31

# %%
len(list(set(circ_multp_124) & set(nw_circ)))
# Out:
# 25

# %% [markdown]
# # test prompts

# %%
clean_text = "Given the sequence 2, 4, 6, 8, ..., identify the 10th term. Be concise."
corr_text = "uno uno uno" # dos tres cinco seis
heads_not_ablate = [(layer, head) for layer in range(32) for head in range(32)]  # unablated
mlps_not_ablate = [layer for layer in range(32)]
ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, 20)
# Out:
# 4
# Sequence so far: Given the sequence 2, 4, 6, 8, ..., identify the 10th term. Be concise.</s>
# 31th char = '</s>'
# Sequence so far: Given the sequence 2, 4, 6, 8, ..., identify the 10th term. Be concise.</s>s
# 32th char = 's'
# Sequence so far: Given the sequence 2, 4, 6, 8, ..., identify the 10th term. Be concise.</s>sports
# 33th char = 'ports'
# Sequence so far: Given the sequence 2, 4, 6, 8, ..., identify the 10th term. Be concise.</s>sportsbet
# 34th char = 'bet'
# Sequence so far: Given the sequence 2, 4, 6, 8, ..., identify the 10th term. Be concise.</s>sportsbetting
# 35th char = 'ting'
# Sequence so far: Given the sequence 2, 4, 6, 8, ..., identify the 10th term. Be concise.</s>sportsbetting,
# 36th char = ','
# Sequence so far: Given the sequence 2, 4, 6, 8, ..., identify the 10th term. Be concise.</s>sportsbetting,sports
# 37th char = 'sports'
# Sequence so far: Given the sequence 2, 4, 6, 8, ..., identify the 10th term. Be concise.</s>sportsbetting,sportsbook
# 38th char = 'book'
# Sequence so far: Given the sequence 2, 4, 6, 8, ..., identify the 10th term. Be concise.</s>sportsbetting,sportsbook,
# 39th char = ','
# Sequence so far: Given the sequence 2, 4, 6, 8, ..., identify the 10th term. Be concise.</s>sportsbetting,sportsbook,bet
# 40th char = 'bet'
# Sequence so far: Given the sequence 2, 4, 6, 8, ..., identify the 10th term. Be concise.</s>sportsbetting,sportsbook,betting
# 41th char = 'ting'
# Sequence so far: Given the sequence 2, 4, 6, 8, ..., identify the 10th term. Be concise.</s>sportsbetting,sportsbook,bettingodd
# 42th char = 'odd'
# Sequence so far: Given the sequence 2, 4, 6, 8, ..., identify the 10th term. Be concise.</s>sportsbetting,sportsbook,bettingodds
# 43th char = 's'
# Sequence so far: Given the sequence 2, 4, 6, 8, ..., identify the 10th term. Be concise.</s>sportsbetting,sportsbook,bettingodds,
# 44th char = ','
# Sequence so far: Given the sequence 2, 4, 6, 8, ..., identify the 10th term. Be concise.</s>sportsbetting,sportsbook,bettingodds,bet
# 45th char = 'bet'
# Sequence so far: Given the sequence 2, 4, 6, 8, ..., identify the 10th term. Be concise.</s>sportsbetting,sportsbook,bettingodds,betting
# 46th char = 'ting'
# Sequence so far: Given the sequence 2, 4, 6, 8, ..., identify the 10th term. Be concise.</s>sportsbetting,sportsbook,bettingodds,bettinglines
# 47th char = 'lines'
# Sequence so far: Given the sequence 2, 4, 6, 8, ..., identify the 10th term. Be concise.</s>sportsbetting,sportsbook,bettingodds,bettinglines,
# 48th char = ','
# Sequence so far: Given the sequence 2, 4, 6, 8, ..., identify the 10th term. Be concise.</s>sportsbetting,sportsbook,bettingodds,bettinglines,bet
# 49th char = 'bet'
# Sequence so far: Given the sequence 2, 4, 6, 8, ..., identify the 10th term. Be concise.</s>sportsbetting,sportsbook,bettingodds,bettinglines,betting
# 50th char = 'ting'

# %%
clean_text = "Be concise. In the arithmetic sequence starting at 5 and increasing by 3 each time, what is the 7th term?"
corr_text = "uno uno uno" # dos tres cinco seis
heads_not_ablate = [(layer, head) for layer in range(32) for head in range(32)]  # unablated
mlps_not_ablate = [layer for layer in range(32)]
ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, 20)
# Out:
# 4
# Sequence so far: Be concise. In the arithmetic sequence starting at 5 and increasing by 3 each time, what is the 7th term?<0x0A>
# 30th char = '<0x0A>'
# Sequence so far: Be concise. In the arithmetic sequence starting at 5 and increasing by 3 each time, what is the 7th term?<0x0A><0x0A>
# 31th char = '<0x0A>'
# Sequence so far: Be concise. In the arithmetic sequence starting at 5 and increasing by 3 each time, what is the 7th term?<0x0A><0x0A>Answer
# 32th char = 'Answer'
# Sequence so far: Be concise. In the arithmetic sequence starting at 5 and increasing by 3 each time, what is the 7th term?<0x0A><0x0A>Answer:
# 33th char = ':'
# Sequence so far: Be concise. In the arithmetic sequence starting at 5 and increasing by 3 each time, what is the 7th term?<0x0A><0x0A>Answer:
# 34th char = ' '
# Sequence so far: Be concise. In the arithmetic sequence starting at 5 and increasing by 3 each time, what is the 7th term?<0x0A><0x0A>Answer: 1
# 35th char = '1'
# Sequence so far: Be concise. In the arithmetic sequence starting at 5 and increasing by 3 each time, what is the 7th term?<0x0A><0x0A>Answer: 15
# 36th char = '5'
# Sequence so far: Be concise. In the arithmetic sequence starting at 5 and increasing by 3 each time, what is the 7th term?<0x0A><0x0A>Answer: 15<0x0A>
# 37th char = '<0x0A>'
# Sequence so far: Be concise. In the arithmetic sequence starting at 5 and increasing by 3 each time, what is the 7th term?<0x0A><0x0A>Answer: 15<0x0A><0x0A>
# 38th char = '<0x0A>'
# Sequence so far: Be concise. In the arithmetic sequence starting at 5 and increasing by 3 each time, what is the 7th term?<0x0A><0x0A>Answer: 15<0x0A><0x0A>Ex
# 39th char = 'Ex'
# Sequence so far: Be concise. In the arithmetic sequence starting at 5 and increasing by 3 each time, what is the 7th term?<0x0A><0x0A>Answer: 15<0x0A><0x0A>Explan
# 40th char = 'plan'
# Sequence so far: Be concise. In the arithmetic sequence starting at 5 and increasing by 3 each time, what is the 7th term?<0x0A><0x0A>Answer: 15<0x0A><0x0A>Explanation
# 41th char = 'ation'
# Sequence so far: Be concise. In the arithmetic sequence starting at 5 and increasing by 3 each time, what is the 7th term?<0x0A><0x0A>Answer: 15<0x0A><0x0A>Explanation:
# 42th char = ':'
# Sequence so far: Be concise. In the arithmetic sequence starting at 5 and increasing by 3 each time, what is the 7th term?<0x0A><0x0A>Answer: 15<0x0A><0x0A>Explanation:The
# 43th char = 'The'
# Sequence so far: Be concise. In the arithmetic sequence starting at 5 and increasing by 3 each time, what is the 7th term?<0x0A><0x0A>Answer: 15<0x0A><0x0A>Explanation:Thepattern
# 44th char = 'pattern'
# Sequence so far: Be concise. In the arithmetic sequence starting at 5 and increasing by 3 each time, what is the 7th term?<0x0A><0x0A>Answer: 15<0x0A><0x0A>Explanation:Thepatternof
# 45th char = 'of'
# Sequence so far: Be concise. In the arithmetic sequence starting at 5 and increasing by 3 each time, what is the 7th term?<0x0A><0x0A>Answer: 15<0x0A><0x0A>Explanation:Thepatternofthe
# 46th char = 'the'
# Sequence so far: Be concise. In the arithmetic sequence starting at 5 and increasing by 3 each time, what is the 7th term?<0x0A><0x0A>Answer: 15<0x0A><0x0A>Explanation:Thepatternofthesequence
# 47th char = 'sequence'
# Sequence so far: Be concise. In the arithmetic sequence starting at 5 and increasing by 3 each time, what is the 7th term?<0x0A><0x0A>Answer: 15<0x0A><0x0A>Explanation:Thepatternofthesequenceis
# 48th char = 'is'
# Sequence so far: Be concise. In the arithmetic sequence starting at 5 and increasing by 3 each time, what is the 7th term?<0x0A><0x0A>Answer: 15<0x0A><0x0A>Explanation:Thepatternofthesequenceis:
# 49th char = ':'

# %%
instruction = "Be concise. "
clean_text =  "Starting on the 1st of January, what date falls 50 days later?"
clean_text = instruction + clean_text
corr_text = "uno uno uno" # dos tres cinco seis
heads_not_ablate = [(layer, head) for layer in range(32) for head in range(32)]  # unablated
mlps_not_ablate = [layer for layer in range(32)]
ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, 20)
# Out:
# 4
# Sequence so far: Be concise. Starting on the 1st of January, what date falls 50 days later?<0x0A>
# 24th char = '<0x0A>'
# Sequence so far: Be concise. Starting on the 1st of January, what date falls 50 days later?<0x0A><0x0A>
# 25th char = '<0x0A>'
# Sequence so far: Be concise. Starting on the 1st of January, what date falls 50 days later?<0x0A><0x0A>Answer
# 26th char = 'Answer'
# Sequence so far: Be concise. Starting on the 1st of January, what date falls 50 days later?<0x0A><0x0A>Answer:
# 27th char = ':'
# Sequence so far: Be concise. Starting on the 1st of January, what date falls 50 days later?<0x0A><0x0A>Answer:
# 28th char = ' '
# Sequence so far: Be concise. Starting on the 1st of January, what date falls 50 days later?<0x0A><0x0A>Answer: 5
# 29th char = '5'
# Sequence so far: Be concise. Starting on the 1st of January, what date falls 50 days later?<0x0A><0x0A>Answer: 50
# 30th char = '0'
# Sequence so far: Be concise. Starting on the 1st of January, what date falls 50 days later?<0x0A><0x0A>Answer: 50days
# 31th char = 'days'
# Sequence so far: Be concise. Starting on the 1st of January, what date falls 50 days later?<0x0A><0x0A>Answer: 50daysafter
# 32th char = 'after'
# Sequence so far: Be concise. Starting on the 1st of January, what date falls 50 days later?<0x0A><0x0A>Answer: 50daysafterJanuary
# 33th char = 'January'
# Sequence so far: Be concise. Starting on the 1st of January, what date falls 50 days later?<0x0A><0x0A>Answer: 50daysafterJanuary
# 34th char = ' '
# Sequence so far: Be concise. Starting on the 1st of January, what date falls 50 days later?<0x0A><0x0A>Answer: 50daysafterJanuary 1
# 35th char = '1'
# Sequence so far: Be concise. Starting on the 1st of January, what date falls 50 days later?<0x0A><0x0A>Answer: 50daysafterJanuary 1st
# 36th char = 'st'
# Sequence so far: Be concise. Starting on the 1st of January, what date falls 50 days later?<0x0A><0x0A>Answer: 50daysafterJanuary 1stis
# 37th char = 'is'
# Sequence so far: Be concise. Starting on the 1st of January, what date falls 50 days later?<0x0A><0x0A>Answer: 50daysafterJanuary 1stisFebruary
# 38th char = 'February'
# Sequence so far: Be concise. Starting on the 1st of January, what date falls 50 days later?<0x0A><0x0A>Answer: 50daysafterJanuary 1stisFebruary
# 39th char = ' '
# Sequence so far: Be concise. Starting on the 1st of January, what date falls 50 days later?<0x0A><0x0A>Answer: 50daysafterJanuary 1stisFebruary 2
# 40th char = '2'
# Sequence so far: Be concise. Starting on the 1st of January, what date falls 50 days later?<0x0A><0x0A>Answer: 50daysafterJanuary 1stisFebruary 28
# 41th char = '8'
# Sequence so far: Be concise. Starting on the 1st of January, what date falls 50 days later?<0x0A><0x0A>Answer: 50daysafterJanuary 1stisFebruary 28th
# 42th char = 'th'
# Sequence so far: Be concise. Starting on the 1st of January, what date falls 50 days later?<0x0A><0x0A>Answer: 50daysafterJanuary 1stisFebruary 28th.
# 43th char = '.'

# %%
instruction = "Be concise. "
clean_text =  "If today is the 11th of a month, what date will it be in 6 days?"
clean_text = instruction + clean_text
corr_text = "uno uno uno" # dos tres cinco seis
heads_not_ablate = [(layer, head) for layer in range(32) for head in range(32)]  # unablated
mlps_not_ablate = [layer for layer in range(32)]
ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, 10)
# Out:
# 4
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A>
# 28th char = '<0x0A>'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>
# 29th char = '<0x0A>'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer
# 30th char = 'Answer'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:
# 31th char = ':'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:
# 32th char = ' '
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 1
# 33th char = '1'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17
# 34th char = '7'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th
# 35th char = 'th'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A>
# 36th char = '<0x0A>'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>
# 37th char = '<0x0A>'

# %%
# instruction = "Be concise. "
clean_text =  "5 + 16 = "
# clean_text = instruction + clean_text
corr_text = "uno uno uno" # dos tres cinco seis
heads_not_ablate = [(layer, head) for layer in range(32) for head in range(32)]  # unablated
mlps_not_ablate = [layer for layer in range(32)]
ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, 3)
# Out:
# 4
# Sequence so far: 5 + 16 = 2
# 10th char = '2'
# Sequence so far: 5 + 16 = 21
# 11th char = '1'
# Sequence so far: 5 + 16 = 21<0x0A>
# 12th char = '<0x0A>'

# %%
instruction = "Be concise. "
clean_text =  "100 + 58 = "
clean_text = instruction + clean_text
corr_text = "uno uno uno" # dos tres cinco seis
heads_not_ablate = [(layer, head) for layer in range(32) for head in range(32)]  # unablated
mlps_not_ablate = [layer for layer in range(32)]
ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, 5)
# Out:
# 4
# Sequence so far: Be concise. 100 + 58 = 1
# 16th char = '1'
# Sequence so far: Be concise. 100 + 58 = 15
# 17th char = '5'
# Sequence so far: Be concise. 100 + 58 = 158
# 18th char = '8'
# Sequence so far: Be concise. 100 + 58 = 158.
# 19th char = '.'
# Sequence so far: Be concise. 100 + 58 = 158.<0x0A>
# 20th char = '<0x0A>'

# %%
instruction = "Be concise. "
clean_text =  "5 x 6 = "
# clean_text = instruction + clean_text
corr_text = "uno uno uno" # dos tres cinco seis
heads_not_ablate = [(layer, head) for layer in range(32) for head in range(32)]  # unablated
mlps_not_ablate = [layer for layer in range(32)]
ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, 3)
# Out:
# 4
# Sequence so far: 5 x 6 = 3
# 9th char = '3'
# Sequence so far: 5 x 6 = 30
# 10th char = '0'
# Sequence so far: 5 x 6 = 30<0x0A>
# 11th char = '<0x0A>'

# %%
instruction = "Be concise. "
clean_text =  "2 x 2 = "
# clean_text = instruction + clean_text
corr_text = "uno uno uno" # dos tres cinco seis
heads_not_ablate = [(layer, head) for layer in range(32) for head in range(32)]  # unablated
mlps_not_ablate = [layer for layer in range(32)]
ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, 3)
# Out:
# 4
# Sequence so far: 2 x 2 = 4
# 9th char = '4'
# Sequence so far: 2 x 2 = 4<0x0A>
# 10th char = '<0x0A>'
# Sequence so far: 2 x 2 = 4<0x0A><0x0A>
# 11th char = '<0x0A>'

# %%
instruction = "Be concise. "
clean_text =  "In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?"
clean_text = instruction + clean_text
corr_text = "uno uno uno" # dos tres cinco seis
heads_not_ablate = [(layer, head) for layer in range(32) for head in range(32)]  # unablated
mlps_not_ablate = [layer for layer in range(32)]
ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, 10)
# Out:
# 4
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A>
# 35th char = '<0x0A>'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>
# 36th char = '<0x0A>'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer
# 37th char = 'Answer'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:
# 38th char = ':'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:Y
# 39th char = 'Y'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:Yellow
# 40th char = 'ellow'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:Yellow.
# 41th char = '.'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:Yellow.</s>
# 42th char = '</s>'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:Yellow.</s>s
# 43th char = 's'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:Yellow.</s>s<0x0A>
# 44th char = '<0x0A>'

# %% [markdown]
# # 1 2 3 genr ablation expms

# %%
clean_text = "1 2 3"
corr_text = "5 3 9"
# corr_text = "1 2 3"

# %% [markdown]
# ## ablate circ

# %%
heads_not_ablate = [(layer, head) for layer in range(32) for head in range(32)]  # unablated
head_to_remove = intersect_all
heads_not_ablate = [x for x in heads_not_ablate if (x not in head_to_remove)]

mlps_not_ablate = [layer for layer in range(32)]

ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, 3)
# Out:
# 7
# Sequence so far: 1 2 3
# 8th char = ' '
# Sequence so far: 1 2 3 4
# 9th char = '4'
# Sequence so far: 1 2 3 4
# 10th char = ' '

# %%
heads_not_ablate = [(layer, head) for layer in range(32) for head in range(32)]  # unablated
head_to_remove = intersect_en_nw_months
heads_not_ablate = [x for x in heads_not_ablate if (x not in head_to_remove)]

mlps_not_ablate = [layer for layer in range(32)]

ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, 3)
# Out:
# 7
# Sequence so far: 1 2 3
# 8th char = ' '
# Sequence so far: 1 2 3 4
# 9th char = '4'
# Sequence so far: 1 2 3 4
# 10th char = ' '

# %% [markdown]
# # 2 4 6

# %%
clean_text = "2 4 6"
corr_text = "uno uno uno" # dos tres cinco seis
num_toks_gen = 10

# %% [markdown]
# clean

# %%
heads_not_ablate = [(layer, head) for layer in range(32) for head in range(32)]  # unablated
mlps_not_ablate = [layer for layer in range(32)]
num_toks_gen = 5
ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, num_toks_gen)
# Out:
# 4
# Sequence so far: 2 4 6
# 8th char = ' '
# Sequence so far: 2 4 6 8
# 9th char = '8'
# Sequence so far: 2 4 6 8
# 10th char = ' '
# Sequence so far: 2 4 6 8 1
# 11th char = '1'
# Sequence so far: 2 4 6 8 10
# 12th char = '0'

# %% [markdown]
# ## ablate circ

# %%
heads_not_ablate = [(layer, head) for layer in range(32) for head in range(32)]  # unablated
head_to_remove = nw_circ
heads_not_ablate = [x for x in heads_not_ablate if (x not in head_to_remove)]

mlps_not_ablate = [layer for layer in range(32)]
num_toks_gen = 5

ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, num_toks_gen)
# Out:
# 4
# Sequence so far: 2 4 6
# 8th char = ' '
# Sequence so far: 2 4 6 2
# 9th char = '2'
# Sequence so far: 2 4 6 2
# 10th char = ' '
# Sequence so far: 2 4 6 2 4
# 11th char = '4'
# Sequence so far: 2 4 6 2 4
# 12th char = ' '

# %% [markdown]
# ## top nw circ heads

# %%
heads_not_ablate = [(layer, head) for layer in range(32) for head in range(32)]  # unablated
head_to_remove = nw_circ[:10]
heads_not_ablate = [x for x in heads_not_ablate if (x not in head_to_remove)]

mlps_not_ablate = [layer for layer in range(32)]

num_toks_gen = 5
ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, num_toks_gen)
# Out:
# 4
# Sequence so far: 2 4 6
# 8th char = ' '
# Sequence so far: 2 4 6 8
# 9th char = '8'
# Sequence so far: 2 4 6 8
# 10th char = ' '
# Sequence so far: 2 4 6 8 1
# 11th char = '1'
# Sequence so far: 2 4 6 8 10
# 12th char = '0'

# %% [markdown]
# ## 124 circ

# %%
heads_not_ablate = [(layer, head) for layer in range(32) for head in range(32)]  # unablated
head_to_remove = circ_multp_124
heads_not_ablate = [x for x in heads_not_ablate if (x not in head_to_remove)]

mlps_not_ablate = [layer for layer in range(32)]
num_toks_gen = 5

ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, num_toks_gen)
# Out:
# 4
# Sequence so far: 2 4 6
# 8th char = ' '
# Sequence so far: 2 4 6 1
# 9th char = '1'
# Sequence so far: 2 4 6 10
# 10th char = '0'
# Sequence so far: 2 4 6 10
# 11th char = ' '
# Sequence so far: 2 4 6 10 1
# 12th char = '1'

# %% [markdown]
# ## random

# %%
import random

heads_of_circ = nw_circ

all_possible_pairs =  [(layer, head) for layer in range(32) for head in range(32)]
# Filter out heads_of_circ from all_possible_pairs
filtered_pairs = [pair for pair in all_possible_pairs if pair not in heads_of_circ]

# Randomly choose 10 pairs ensuring less than 10 overlaps with heads_of_circ
head_to_remove = choose_heads_to_remove(filtered_pairs, heads_of_circ, 100, 10)

heads_not_ablate = [x for x in all_possible_pairs if x not in head_to_remove]

mlps_not_ablate = [layer for layer in range(32)]

num_toks_gen = 5
ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, num_toks_gen)
# Out:
# 4
# Sequence so far: 2 4 6
# 8th char = ' '
# Sequence so far: 2 4 6 8
# 9th char = '8'
# Sequence so far: 2 4 6 8
# 10th char = ' '
# Sequence so far: 2 4 6 8 1
# 11th char = '1'
# Sequence so far: 2 4 6 8 10
# 12th char = '0'

# %% [markdown]
# # 1 2 4

# %%
clean_text = "1 2 4"
corr_text = "uno uno uno" # dos tres cinco seis
num_toks_gen = 10

# %% [markdown]
# clean

# %%
heads_not_ablate = [(layer, head) for layer in range(32) for head in range(32)]  # unablated
mlps_not_ablate = [layer for layer in range(32)]
num_toks_gen = 5
ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, num_toks_gen)
# Out:
# 4
# Sequence so far: 1 2 4
# 8th char = ' '
# Sequence so far: 1 2 4 8
# 9th char = '8'
# Sequence so far: 1 2 4 8
# 10th char = ' '
# Sequence so far: 1 2 4 8 1
# 11th char = '1'
# Sequence so far: 1 2 4 8 16
# 12th char = '6'

# %% [markdown]
# ## ablate circ

# %%
heads_not_ablate = [(layer, head) for layer in range(32) for head in range(32)]  # unablated
head_to_remove = nw_circ
heads_not_ablate = [x for x in heads_not_ablate if (x not in head_to_remove)]

mlps_not_ablate = [layer for layer in range(32)]
num_toks_gen = 5

ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, num_toks_gen)
# Out:
# 4
# Sequence so far: 1 2 4
# 8th char = ' '
# Sequence so far: 1 2 4 1
# 9th char = '1'
# Sequence so far: 1 2 4 1
# 10th char = ' '
# Sequence so far: 1 2 4 1 2
# 11th char = '2'
# Sequence so far: 1 2 4 1 2
# 12th char = ' '

# %% [markdown]
# ## top nw circ heads

# %%
heads_not_ablate = [(layer, head) for layer in range(32) for head in range(32)]  # unablated
head_to_remove = nw_circ[:10]
heads_not_ablate = [x for x in heads_not_ablate if (x not in head_to_remove)]

mlps_not_ablate = [layer for layer in range(32)]

num_toks_gen = 5
ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, num_toks_gen)
# Out:
# 4
# Sequence so far: 1 2 4
# 8th char = ' '
# Sequence so far: 1 2 4 3
# 9th char = '3'
# Sequence so far: 1 2 4 3
# 10th char = ' '
# Sequence so far: 1 2 4 3 1
# 11th char = '1'
# Sequence so far: 1 2 4 3 1
# 12th char = ' '

# %% [markdown]
# ## 124 circ

# %%
heads_not_ablate = [(layer, head) for layer in range(32) for head in range(32)]  # unablated
head_to_remove = circ_multp_124
heads_not_ablate = [x for x in heads_not_ablate if (x not in head_to_remove)]

mlps_not_ablate = [layer for layer in range(32)]
num_toks_gen = 5

ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, num_toks_gen)
# Out:
# 4
# Sequence so far: 1 2 4
# 8th char = ' '
# Sequence so far: 1 2 4 1
# 9th char = '1'
# Sequence so far: 1 2 4 1
# 10th char = ' '
# Sequence so far: 1 2 4 1 1
# 11th char = '1'
# Sequence so far: 1 2 4 1 1
# 12th char = ' '

# %% [markdown]
# ## random

# %%
import random

heads_of_circ = nw_circ

all_possible_pairs =  [(layer, head) for layer in range(32) for head in range(32)]
# Filter out heads_of_circ from all_possible_pairs
filtered_pairs = [pair for pair in all_possible_pairs if pair not in heads_of_circ]

# Randomly choose 10 pairs ensuring less than 10 overlaps with heads_of_circ
head_to_remove = choose_heads_to_remove(filtered_pairs, heads_of_circ, 100, 10)

heads_not_ablate = [x for x in all_possible_pairs if x not in head_to_remove]

mlps_not_ablate = [layer for layer in range(32)]

num_toks_gen = 5
ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, num_toks_gen)
# Out:
# 4
# Sequence so far: 1 2 4
# 8th char = ' '
# Sequence so far: 1 2 4 8
# 9th char = '8'
# Sequence so far: 1 2 4 8
# 10th char = ' '
# Sequence so far: 1 2 4 8 1
# 11th char = '1'
# Sequence so far: 1 2 4 8 16
# 12th char = '6'

# %% [markdown]
# # Be concise. If today is the 11th of a month, what date will it be in 6 days?

# %%
clean_text = "Be concise. If today is the 11th of a month, what date will it be in 6 days?"
# corr_text = "uno uno uno" # dos tres cinco seis
num_toks_gen = 10

# %% [markdown]
# clean

# %%
heads_not_ablate = [(layer, head) for layer in range(32) for head in range(32)]  # unablated
mlps_not_ablate = [layer for layer in range(32)]
num_toks_gen = 10
ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, num_toks_gen)
# Out:
# 4
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A>
# 28th char = '<0x0A>'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>
# 29th char = '<0x0A>'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer
# 30th char = 'Answer'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:
# 31th char = ':'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:
# 32th char = ' '
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 1
# 33th char = '1'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17
# 34th char = '7'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th
# 35th char = 'th'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A>
# 36th char = '<0x0A>'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>
# 37th char = '<0x0A>'

# %% [markdown]
# ## ablate circ

# %%
heads_not_ablate = [(layer, head) for layer in range(32) for head in range(32)]  # unablated
head_to_remove = nw_circ
heads_not_ablate = [x for x in heads_not_ablate if (x not in head_to_remove)]

mlps_not_ablate = [layer for layer in range(32)]
num_toks_gen = 30

ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, num_toks_gen)
# Out:
# 4
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A>
# 28th char = '<0x0A>'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>
# 29th char = '<0x0A>'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer
# 30th char = 'Answer'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:
# 31th char = ':'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:If
# 32th char = 'If'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:Iftoday
# 33th char = 'today'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:Iftodayis
# 34th char = 'is'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:Iftodayisthe
# 35th char = 'the'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:Iftodayisthe
# 36th char = ' '
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:Iftodayisthe 1
# 37th char = '1'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:Iftodayisthe 1st
# 38th char = 'st'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:Iftodayisthe 1stof
# 39th char = 'of'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:Iftodayisthe 1stofa
# 40th char = 'a'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:Iftodayisthe 1stofamonth
# 41th char = 'month'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:Iftodayisthe 1stofamonth,
# 42th char = ','
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:Iftodayisthe 1stofamonth,in
# 43th char = 'in'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:Iftodayisthe 1stofamonth,in
# 44th char = ' '
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:Iftodayisthe 1stofamonth,in 6
# 45th char = '6'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:Iftodayisthe 1stofamonth,in 6days
# 46th char = 'days'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:Iftodayisthe 1stofamonth,in 6daysit
# 47th char = 'it'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:Iftodayisthe 1stofamonth,in 6daysitwill
# 48th char = 'will'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:Iftodayisthe 1stofamonth,in 6daysitwillbe
# 49th char = 'be'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:Iftodayisthe 1stofamonth,in 6daysitwillbethe
# 50th char = 'the'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:Iftodayisthe 1stofamonth,in 6daysitwillbethe
# 51th char = ' '
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:Iftodayisthe 1stofamonth,in 6daysitwillbethe 6
# 52th char = '6'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:Iftodayisthe 1stofamonth,in 6daysitwillbethe 6th
# 53th char = 'th'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:Iftodayisthe 1stofamonth,in 6daysitwillbethe 6thof
# 54th char = 'of'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:Iftodayisthe 1stofamonth,in 6daysitwillbethe 6thofthe
# 55th char = 'the'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:Iftodayisthe 1stofamonth,in 6daysitwillbethe 6thofthemonth
# 56th char = 'month'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:Iftodayisthe 1stofamonth,in 6daysitwillbethe 6thofthemonth.
# 57th char = '.'

# %% [markdown]
# ## top nw circ heads

# %%
heads_not_ablate = [(layer, head) for layer in range(32) for head in range(32)]  # unablated
head_to_remove = nw_circ[:10]
heads_not_ablate = [x for x in heads_not_ablate if (x not in head_to_remove)]

mlps_not_ablate = [layer for layer in range(32)]

num_toks_gen = 30
ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, num_toks_gen)
# Out:
# 4
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A>
# 28th char = '<0x0A>'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>
# 29th char = '<0x0A>'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer
# 30th char = 'Answer'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:
# 31th char = ':'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:March
# 32th char = 'March'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:March
# 33th char = ' '
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:March 1
# 34th char = '1'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:March 17
# 35th char = '7'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:March 17th
# 36th char = 'th'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:March 17th.
# 37th char = '.'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:March 17th.</s>
# 38th char = '</s>'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:March 17th.</s>s
# 39th char = 's'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:March 17th.</s>s<0x0A>
# 40th char = '<0x0A>'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:March 17th.</s>s<0x0A><0x0A>
# 41th char = '<0x0A>'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:March 17th.</s>s<0x0A><0x0A>Ex
# 42th char = 'Ex'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:March 17th.</s>s<0x0A><0x0A>Explan
# 43th char = 'plan'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:March 17th.</s>s<0x0A><0x0A>Explanation
# 44th char = 'ation'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:March 17th.</s>s<0x0A><0x0A>Explanation:
# 45th char = ':'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:March 17th.</s>s<0x0A><0x0A>Explanation:<0x0A>
# 46th char = '<0x0A>'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:March 17th.</s>s<0x0A><0x0A>Explanation:<0x0A>If
# 47th char = 'If'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:March 17th.</s>s<0x0A><0x0A>Explanation:<0x0A>Iftoday
# 48th char = 'today'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:March 17th.</s>s<0x0A><0x0A>Explanation:<0x0A>Iftodayis
# 49th char = 'is'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:March 17th.</s>s<0x0A><0x0A>Explanation:<0x0A>Iftodayisthe
# 50th char = 'the'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:March 17th.</s>s<0x0A><0x0A>Explanation:<0x0A>Iftodayisthe
# 51th char = ' '
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:March 17th.</s>s<0x0A><0x0A>Explanation:<0x0A>Iftodayisthe 1
# 52th char = '1'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:March 17th.</s>s<0x0A><0x0A>Explanation:<0x0A>Iftodayisthe 11
# 53th char = '1'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:March 17th.</s>s<0x0A><0x0A>Explanation:<0x0A>Iftodayisthe 11th
# 54th char = 'th'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:March 17th.</s>s<0x0A><0x0A>Explanation:<0x0A>Iftodayisthe 11thof
# 55th char = 'of'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:March 17th.</s>s<0x0A><0x0A>Explanation:<0x0A>Iftodayisthe 11thofa
# 56th char = 'a'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:March 17th.</s>s<0x0A><0x0A>Explanation:<0x0A>Iftodayisthe 11thofamonth
# 57th char = 'month'

# %% [markdown]
# ## random

# %%
import random

heads_of_circ = nw_circ

all_possible_pairs =  [(layer, head) for layer in range(32) for head in range(32)]
# Filter out heads_of_circ from all_possible_pairs
filtered_pairs = [pair for pair in all_possible_pairs if pair not in heads_of_circ]

# Randomly choose 10 pairs ensuring less than 10 overlaps with heads_of_circ
head_to_remove = choose_heads_to_remove(filtered_pairs, heads_of_circ, 10, 10)

heads_not_ablate = [x for x in all_possible_pairs if x not in head_to_remove]

mlps_not_ablate = [layer for layer in range(32)]

num_toks_gen = 50
ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, num_toks_gen)
# Out:
# 4
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A>
# 28th char = '<0x0A>'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>
# 29th char = '<0x0A>'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer
# 30th char = 'Answer'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:
# 31th char = ':'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:
# 32th char = ' '
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 1
# 33th char = '1'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17
# 34th char = '7'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th
# 35th char = 'th'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A>
# 36th char = '<0x0A>'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>
# 37th char = '<0x0A>'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Ex
# 38th char = 'Ex'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explan
# 39th char = 'plan'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation
# 40th char = 'ation'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:
# 41th char = ':'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:If
# 42th char = 'If'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftoday
# 43th char = 'today'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayis
# 44th char = 'is'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe
# 45th char = 'the'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe
# 46th char = ' '
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 1
# 47th char = '1'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11
# 48th char = '1'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11th
# 49th char = 'th'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thof
# 50th char = 'of'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofa
# 51th char = 'a'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth
# 52th char = 'month'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,
# 53th char = ','
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in
# 54th char = 'in'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in
# 55th char = ' '
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6
# 56th char = '6'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6days
# 57th char = 'days'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysit
# 58th char = 'it'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysitwill
# 59th char = 'will'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysitwillbe
# 60th char = 'be'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysitwillbethe
# 61th char = 'the'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysitwillbethe
# 62th char = ' '
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysitwillbethe 1
# 63th char = '1'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysitwillbethe 17
# 64th char = '7'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysitwillbethe 17th
# 65th char = 'th'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysitwillbethe 17thof
# 66th char = 'of'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysitwillbethe 17thofthe
# 67th char = 'the'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysitwillbethe 17thofthesame
# 68th char = 'same'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysitwillbethe 17thofthesamemonth
# 69th char = 'month'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysitwillbethe 17thofthesamemonth.
# 70th char = '.'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysitwillbethe 17thofthesamemonth.</s>
# 71th char = '</s>'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysitwillbethe 17thofthesamemonth.</s>s
# 72th char = 's'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysitwillbethe 17thofthesamemonth.</s>s<0x0A>
# 73th char = '<0x0A>'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysitwillbethe 17thofthesamemonth.</s>s<0x0A><0x0A>
# 74th char = '<0x0A>'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysitwillbethe 17thofthesamemonth.</s>s<0x0A><0x0A></s>
# 75th char = '</s>'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysitwillbethe 17thofthesamemonth.</s>s<0x0A><0x0A></s><0x0A>
# 76th char = '<0x0A>'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysitwillbethe 17thofthesamemonth.</s>s<0x0A><0x0A></s><0x0A></s>
# 77th char = '</s>'

# %%
heads_of_circ = nw_circ

all_possible_pairs =  [(layer, head) for layer in range(32) for head in range(32)]
# Filter out heads_of_circ from all_possible_pairs
filtered_pairs = [pair for pair in all_possible_pairs if pair not in heads_of_circ]

# Randomly choose 10 pairs ensuring less than 10 overlaps with heads_of_circ
head_to_remove = choose_heads_to_remove(filtered_pairs, heads_of_circ, 100, 10)

heads_not_ablate = [x for x in all_possible_pairs if x not in head_to_remove]

mlps_not_ablate = [layer for layer in range(32)]

num_toks_gen = 50
ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, num_toks_gen)
# Out:
# 4
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A>
# 28th char = '<0x0A>'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>
# 29th char = '<0x0A>'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer
# 30th char = 'Answer'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:
# 31th char = ':'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer:
# 32th char = ' '
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 1
# 33th char = '1'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17
# 34th char = '7'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th
# 35th char = 'th'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A>
# 36th char = '<0x0A>'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>
# 37th char = '<0x0A>'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Ex
# 38th char = 'Ex'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explan
# 39th char = 'plan'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation
# 40th char = 'ation'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:
# 41th char = ':'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:If
# 42th char = 'If'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftoday
# 43th char = 'today'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayis
# 44th char = 'is'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe
# 45th char = 'the'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe
# 46th char = ' '
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 1
# 47th char = '1'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11
# 48th char = '1'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11th
# 49th char = 'th'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thof
# 50th char = 'of'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofa
# 51th char = 'a'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth
# 52th char = 'month'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,
# 53th char = ','
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in
# 54th char = 'in'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in
# 55th char = ' '
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6
# 56th char = '6'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6days
# 57th char = 'days'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysit
# 58th char = 'it'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysitwill
# 59th char = 'will'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysitwillbe
# 60th char = 'be'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysitwillbethe
# 61th char = 'the'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysitwillbethe
# 62th char = ' '
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysitwillbethe 1
# 63th char = '1'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysitwillbethe 17
# 64th char = '7'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysitwillbethe 17th
# 65th char = 'th'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysitwillbethe 17thof
# 66th char = 'of'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysitwillbethe 17thofthe
# 67th char = 'the'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysitwillbethe 17thofthesame
# 68th char = 'same'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysitwillbethe 17thofthesamemonth
# 69th char = 'month'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysitwillbethe 17thofthesamemonth.
# 70th char = '.'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysitwillbethe 17thofthesamemonth.<0x0A>
# 71th char = '<0x0A>'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysitwillbethe 17thofthesamemonth.<0x0A><0x0A>
# 72th char = '<0x0A>'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysitwillbethe 17thofthesamemonth.<0x0A><0x0A>Be
# 73th char = 'Be'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysitwillbethe 17thofthesamemonth.<0x0A><0x0A>Beconc
# 74th char = 'conc'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysitwillbethe 17thofthesamemonth.<0x0A><0x0A>Beconcise
# 75th char = 'ise'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysitwillbethe 17thofthesamemonth.<0x0A><0x0A>Beconcise.
# 76th char = '.'
# Sequence so far: Be concise. If today is the 11th of a month, what date will it be in 6 days?<0x0A><0x0A>Answer: 17th<0x0A><0x0A>Explanation:Iftodayisthe 11thofamonth,in 6daysitwillbethe 17thofthesamemonth.<0x0A><0x0A>Beconcise.If
# 77th char = 'If'

# %% [markdown]
# # 5 + 16 =

# %%
clean_text = "5 + 16 = "
# corr_text = "uno uno uno" # dos tres cinco seis
num_toks_gen = 10

# %% [markdown]
# clean

# %%
heads_not_ablate = [(layer, head) for layer in range(32) for head in range(32)]  # unablated
mlps_not_ablate = [layer for layer in range(32)]
num_toks_gen = 10
ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, num_toks_gen)
# Out:
# 4
# Sequence so far: 5 + 16 = 2
# 10th char = '2'
# Sequence so far: 5 + 16 = 21
# 11th char = '1'
# Sequence so far: 5 + 16 = 21<0x0A>
# 12th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A>
# 13th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A>2
# 14th char = '2'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A>21
# 15th char = '1'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A>21-
# 16th char = '-'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A>21-
# 17th char = ' '
# Sequence so far: 5 + 16 = 21<0x0A><0x0A>21- 5
# 18th char = '5'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A>21- 5=
# 19th char = '='

# %% [markdown]
# ## ablate circ

# %%
heads_not_ablate = [(layer, head) for layer in range(32) for head in range(32)]  # unablated
head_to_remove = nw_circ
heads_not_ablate = [x for x in heads_not_ablate if (x not in head_to_remove)]

mlps_not_ablate = [layer for layer in range(32)]
num_toks_gen = 30

ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, num_toks_gen)
# Out:
# 4
# Sequence so far: 5 + 16 = 1
# 10th char = '1'
# Sequence so far: 5 + 16 = 11
# 11th char = '1'
# Sequence so far: 5 + 16 = 111
# 12th char = '1'
# Sequence so far: 5 + 16 = 111<0x0A>
# 13th char = '<0x0A>'
# Sequence so far: 5 + 16 = 111<0x0A><0x0A>
# 14th char = '<0x0A>'
# Sequence so far: 5 + 16 = 111<0x0A><0x0A>
# 15th char = ' '
# Sequence so far: 5 + 16 = 111<0x0A><0x0A> 1
# 16th char = '1'
# Sequence so far: 5 + 16 = 111<0x0A><0x0A> 11
# 17th char = '1'
# Sequence so far: 5 + 16 = 111<0x0A><0x0A> 111
# 18th char = '1'
# Sequence so far: 5 + 16 = 111<0x0A><0x0A> 111-
# 19th char = '-'
# Sequence so far: 5 + 16 = 111<0x0A><0x0A> 111-
# 20th char = ' '
# Sequence so far: 5 + 16 = 111<0x0A><0x0A> 111- 5
# 21th char = '5'
# Sequence so far: 5 + 16 = 111<0x0A><0x0A> 111- 5=
# 22th char = '='
# Sequence so far: 5 + 16 = 111<0x0A><0x0A> 111- 5=
# 23th char = ' '
# Sequence so far: 5 + 16 = 111<0x0A><0x0A> 111- 5= 1
# 24th char = '1'
# Sequence so far: 5 + 16 = 111<0x0A><0x0A> 111- 5= 10
# 25th char = '0'
# Sequence so far: 5 + 16 = 111<0x0A><0x0A> 111- 5= 10<0x0A>
# 26th char = '<0x0A>'
# Sequence so far: 5 + 16 = 111<0x0A><0x0A> 111- 5= 10<0x0A>So
# 27th char = 'So'
# Sequence so far: 5 + 16 = 111<0x0A><0x0A> 111- 5= 10<0x0A>Sothe
# 28th char = 'the'
# Sequence so far: 5 + 16 = 111<0x0A><0x0A> 111- 5= 10<0x0A>Sotheanswer
# 29th char = 'answer'
# Sequence so far: 5 + 16 = 111<0x0A><0x0A> 111- 5= 10<0x0A>Sotheansweris
# 30th char = 'is'
# Sequence so far: 5 + 16 = 111<0x0A><0x0A> 111- 5= 10<0x0A>Sotheansweris
# 31th char = ' '
# Sequence so far: 5 + 16 = 111<0x0A><0x0A> 111- 5= 10<0x0A>Sotheansweris 0
# 32th char = '0'
# Sequence so far: 5 + 16 = 111<0x0A><0x0A> 111- 5= 10<0x0A>Sotheansweris 0.
# 33th char = '.'
# Sequence so far: 5 + 16 = 111<0x0A><0x0A> 111- 5= 10<0x0A>Sotheansweris 0.</s>
# 34th char = '</s>'
# Sequence so far: 5 + 16 = 111<0x0A><0x0A> 111- 5= 10<0x0A>Sotheansweris 0.</s>t
# 35th char = 't'
# Sequence so far: 5 + 16 = 111<0x0A><0x0A> 111- 5= 10<0x0A>Sotheansweris 0.</s>t<0x0A>
# 36th char = '<0x0A>'
# Sequence so far: 5 + 16 = 111<0x0A><0x0A> 111- 5= 10<0x0A>Sotheansweris 0.</s>t<0x0A></s>
# 37th char = '</s>'
# Sequence so far: 5 + 16 = 111<0x0A><0x0A> 111- 5= 10<0x0A>Sotheansweris 0.</s>t<0x0A></s>t
# 38th char = 't'
# Sequence so far: 5 + 16 = 111<0x0A><0x0A> 111- 5= 10<0x0A>Sotheansweris 0.</s>t<0x0A></s>t=
# 39th char = '='

# %% [markdown]
# ## top nw circ heads

# %%
heads_not_ablate = [(layer, head) for layer in range(32) for head in range(32)]  # unablated
head_to_remove = nw_circ[:10]
heads_not_ablate = [x for x in heads_not_ablate if (x not in head_to_remove)]

mlps_not_ablate = [layer for layer in range(32)]

num_toks_gen = 30
ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, num_toks_gen)
# Out:
# 4
# Sequence so far: 5 + 16 = 2
# 10th char = '2'
# Sequence so far: 5 + 16 = 21
# 11th char = '1'
# Sequence so far: 5 + 16 = 21<0x0A>
# 12th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A>
# 13th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A>5
# 14th char = '5'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A>5+
# 15th char = '+'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A>5+
# 16th char = ' '
# Sequence so far: 5 + 16 = 21<0x0A><0x0A>5+ 1
# 17th char = '1'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A>5+ 16
# 18th char = '6'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A>5+ 16=
# 19th char = '='
# Sequence so far: 5 + 16 = 21<0x0A><0x0A>5+ 16=
# 20th char = ' '
# Sequence so far: 5 + 16 = 21<0x0A><0x0A>5+ 16= 2
# 21th char = '2'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A>5+ 16= 21
# 22th char = '1'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A>5+ 16= 21<0x0A>
# 23th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A>5+ 16= 21<0x0A><0x0A>
# 24th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A>5+ 16= 21<0x0A><0x0A>So
# 25th char = 'So'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A>5+ 16= 21<0x0A><0x0A>So,
# 26th char = ','
# Sequence so far: 5 + 16 = 21<0x0A><0x0A>5+ 16= 21<0x0A><0x0A>So,the
# 27th char = 'the'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A>5+ 16= 21<0x0A><0x0A>So,theanswer
# 28th char = 'answer'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A>5+ 16= 21<0x0A><0x0A>So,theansweris
# 29th char = 'is'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A>5+ 16= 21<0x0A><0x0A>So,theansweris
# 30th char = ' '
# Sequence so far: 5 + 16 = 21<0x0A><0x0A>5+ 16= 21<0x0A><0x0A>So,theansweris 2
# 31th char = '2'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A>5+ 16= 21<0x0A><0x0A>So,theansweris 21
# 32th char = '1'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A>5+ 16= 21<0x0A><0x0A>So,theansweris 21.
# 33th char = '.'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A>5+ 16= 21<0x0A><0x0A>So,theansweris 21.</s>
# 34th char = '</s>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A>5+ 16= 21<0x0A><0x0A>So,theansweris 21.</s>0
# 35th char = '0'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A>5+ 16= 21<0x0A><0x0A>So,theansweris 21.</s>05
# 36th char = '5'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A>5+ 16= 21<0x0A><0x0A>So,theansweris 21.</s>05+
# 37th char = '+'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A>5+ 16= 21<0x0A><0x0A>So,theansweris 21.</s>05+
# 38th char = ' '
# Sequence so far: 5 + 16 = 21<0x0A><0x0A>5+ 16= 21<0x0A><0x0A>So,theansweris 21.</s>05+ 1
# 39th char = '1'

# %% [markdown]
# ## random

# %%
import random

heads_of_circ = nw_circ

all_possible_pairs =  [(layer, head) for layer in range(32) for head in range(32)]
# Filter out heads_of_circ from all_possible_pairs
filtered_pairs = [pair for pair in all_possible_pairs if pair not in heads_of_circ]

# Randomly choose 10 pairs ensuring less than 10 overlaps with heads_of_circ
head_to_remove = choose_heads_to_remove(filtered_pairs, heads_of_circ, 100, 10)

heads_not_ablate = [x for x in all_possible_pairs if x not in head_to_remove]

mlps_not_ablate = [layer for layer in range(32)]

num_toks_gen = 50
ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, num_toks_gen)
# Out:
# 4
# Sequence so far: 5 + 16 = 2
# 10th char = '2'
# Sequence so far: 5 + 16 = 21
# 11th char = '1'
# Sequence so far: 5 + 16 = 21<0x0A>
# 12th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A>
# 13th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A>
# 14th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A>
# 15th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A>
# 16th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 17th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 18th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 19th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 20th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 21th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 22th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 23th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 24th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 25th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 26th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 27th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 28th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 29th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 30th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 31th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 32th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 33th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 34th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 35th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 36th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 37th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 38th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 39th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 40th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 41th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 42th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 43th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 44th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 45th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 46th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 47th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 48th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 49th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 50th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 51th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 52th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 53th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 54th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 55th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 56th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 57th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 58th char = '<0x0A>'
# Sequence so far: 5 + 16 = 21<0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A><0x0A>
# 59th char = '<0x0A>'

# %% [markdown]
# # Be concise. 100 + 58 =

# %%
clean_text = "Be concise. 100 + 58 = "
# corr_text = "uno uno uno" # dos tres cinco seis
num_toks_gen = 6

# %% [markdown]
# ## ablate circ

# %%
heads_not_ablate = [(layer, head) for layer in range(32) for head in range(32)]  # unablated
head_to_remove = nw_circ
heads_not_ablate = [x for x in heads_not_ablate if (x not in head_to_remove)]

mlps_not_ablate = [layer for layer in range(32)]
num_toks_gen = 6

ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, num_toks_gen)
# Out:
# 4
# Sequence so far: Be concise. 100 + 58 = 1
# 16th char = '1'
# Sequence so far: Be concise. 100 + 58 = 10
# 17th char = '0'
# Sequence so far: Be concise. 100 + 58 = 100
# 18th char = '0'
# Sequence so far: Be concise. 100 + 58 = 100+
# 19th char = '+'
# Sequence so far: Be concise. 100 + 58 = 100+
# 20th char = ' '
# Sequence so far: Be concise. 100 + 58 = 100+ 5
# 21th char = '5'

# %% [markdown]
# ## random

# %%
heads_of_circ = nw_circ

all_possible_pairs =  [(layer, head) for layer in range(32) for head in range(32)]
# Filter out heads_of_circ from all_possible_pairs
filtered_pairs = [pair for pair in all_possible_pairs if pair not in heads_of_circ]

# Randomly choose 10 pairs ensuring less than 10 overlaps with heads_of_circ
head_to_remove = choose_heads_to_remove(filtered_pairs, heads_of_circ, 100, 10)

heads_not_ablate = [x for x in all_possible_pairs if x not in head_to_remove]

mlps_not_ablate = [layer for layer in range(32)]

num_toks_gen = 6
ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, num_toks_gen)
# Out:
# 4
# Sequence so far: Be concise. 100 + 58 = 1
# 16th char = '1'
# Sequence so far: Be concise. 100 + 58 = 15
# 17th char = '5'
# Sequence so far: Be concise. 100 + 58 = 158
# 18th char = '8'
# Sequence so far: Be concise. 100 + 58 = 158.
# 19th char = '.'
# Sequence so far: Be concise. 100 + 58 = 158.<0x0A>
# 20th char = '<0x0A>'
# Sequence so far: Be concise. 100 + 58 = 158.<0x0A><0x0A>
# 21th char = '<0x0A>'

# %% [markdown]
# Be concise. 100 + 58 =

# %% [markdown]
# # 5 x 6 =

# %%
clean_text = "5 x 6 = "
# corr_text = "uno uno uno" # dos tres cinco seis
num_toks_gen = 6

# %% [markdown]
# ## ablate circ

# %%
heads_not_ablate = [(layer, head) for layer in range(32) for head in range(32)]  # unablated
head_to_remove = nw_circ
heads_not_ablate = [x for x in heads_not_ablate if (x not in head_to_remove)]

mlps_not_ablate = [layer for layer in range(32)]
num_toks_gen = 6

ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, num_toks_gen)
# Out:
# 4
# Sequence so far: 5 x 6 = 3
# 9th char = '3'
# Sequence so far: 5 x 6 = 30
# 10th char = '0'
# Sequence so far: 5 x 6 = 30<0x0A>
# 11th char = '<0x0A>'
# Sequence so far: 5 x 6 = 30<0x0A><0x0A>
# 12th char = '<0x0A>'
# Sequence so far: 5 x 6 = 30<0x0A><0x0A><0x0A>
# 13th char = '<0x0A>'
# Sequence so far: 5 x 6 = 30<0x0A><0x0A><0x0A>Answer
# 14th char = 'Answer'

# %% [markdown]
# ## random

# %%
heads_of_circ = nw_circ

all_possible_pairs =  [(layer, head) for layer in range(32) for head in range(32)]
# Filter out heads_of_circ from all_possible_pairs
filtered_pairs = [pair for pair in all_possible_pairs if pair not in heads_of_circ]

# Randomly choose 10 pairs ensuring less than 10 overlaps with heads_of_circ
head_to_remove = choose_heads_to_remove(filtered_pairs, heads_of_circ, 100, 10)

heads_not_ablate = [x for x in all_possible_pairs if x not in head_to_remove]

mlps_not_ablate = [layer for layer in range(32)]

num_toks_gen = 6
ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, num_toks_gen)
# Out:
# 4
# Sequence so far: 5 x 6 = 3
# 9th char = '3'
# Sequence so far: 5 x 6 = 30
# 10th char = '0'
# Sequence so far: 5 x 6 = 30<0x0A>
# 11th char = '<0x0A>'
# Sequence so far: 5 x 6 = 30<0x0A><0x0A>
# 12th char = '<0x0A>'
# Sequence so far: 5 x 6 = 30<0x0A><0x0A>5
# 13th char = '5'
# Sequence so far: 5 x 6 = 30<0x0A><0x0A>5x
# 14th char = 'x'

# %% [markdown]
# # 2 x 2 =

# %%
clean_text = "2 x 2 = "
# corr_text = "uno uno uno" # dos tres cinco seis
num_toks_gen = 6

# %% [markdown]
# ## ablate circ

# %%
heads_not_ablate = [(layer, head) for layer in range(32) for head in range(32)]  # unablated
head_to_remove = nw_circ
heads_not_ablate = [x for x in heads_not_ablate if (x not in head_to_remove)]

mlps_not_ablate = [layer for layer in range(32)]
num_toks_gen = 6

ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, num_toks_gen)
# Out:
# 4
# Sequence so far: 2 x 2 = 4
# 9th char = '4'
# Sequence so far: 2 x 2 = 4<0x0A>
# 10th char = '<0x0A>'
# Sequence so far: 2 x 2 = 4<0x0A><0x0A>
# 11th char = '<0x0A>'
# Sequence so far: 2 x 2 = 4<0x0A><0x0A><0x0A>
# 12th char = '<0x0A>'
# Sequence so far: 2 x 2 = 4<0x0A><0x0A><0x0A>Answer
# 13th char = 'Answer'
# Sequence so far: 2 x 2 = 4<0x0A><0x0A><0x0A>Answer:
# 14th char = ':'

# %% [markdown]
# ## random

# %%
heads_of_circ = nw_circ

all_possible_pairs =  [(layer, head) for layer in range(32) for head in range(32)]
# Filter out heads_of_circ from all_possible_pairs
filtered_pairs = [pair for pair in all_possible_pairs if pair not in heads_of_circ]

# Randomly choose 10 pairs ensuring less than 10 overlaps with heads_of_circ
head_to_remove = choose_heads_to_remove(filtered_pairs, heads_of_circ, 100, 10)

heads_not_ablate = [x for x in all_possible_pairs if x not in head_to_remove]

mlps_not_ablate = [layer for layer in range(32)]

num_toks_gen = 6
ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, num_toks_gen)
# Out:
# 4
# Sequence so far: 2 x 2 = 4
# 9th char = '4'
# Sequence so far: 2 x 2 = 4<0x0A>
# 10th char = '<0x0A>'
# Sequence so far: 2 x 2 = 4<0x0A><0x0A>
# 11th char = '<0x0A>'
# Sequence so far: 2 x 2 = 4<0x0A><0x0A>4
# 12th char = '4'
# Sequence so far: 2 x 2 = 4<0x0A><0x0A>4x
# 13th char = 'x'
# Sequence so far: 2 x 2 = 4<0x0A><0x0A>4x
# 14th char = ' '

# %% [markdown]
# # Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?

# %%
clean_text = "Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?"
# corr_text = "uno uno uno" # dos tres cinco seis
num_toks_gen = 6

# %% [markdown]
# ## ablate circ

# %%
heads_not_ablate = [(layer, head) for layer in range(32) for head in range(32)]  # unablated
head_to_remove = nw_circ
heads_not_ablate = [x for x in heads_not_ablate if (x not in head_to_remove)]

mlps_not_ablate = [layer for layer in range(32)]
num_toks_gen = 30

ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, num_toks_gen)
# Out:
# 4
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A>
# 35th char = '<0x0A>'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>
# 36th char = '<0x0A>'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer
# 37th char = 'Answer'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:
# 38th char = ':'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:<0x0A>
# 39th char = '<0x0A>'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:<0x0A>In
# 40th char = 'In'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:<0x0A>Ina
# 41th char = 'a'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:<0x0A>Inacy
# 42th char = 'cy'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:<0x0A>Inacyclic
# 43th char = 'clic'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:<0x0A>Inacyclicpattern
# 44th char = 'pattern'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:<0x0A>Inacyclicpatternof
# 45th char = 'of'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:<0x0A>Inacyclicpatternofcolors
# 46th char = 'colors'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:<0x0A>Inacyclicpatternofcolors,
# 47th char = ','
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:<0x0A>Inacyclicpatternofcolors,the
# 48th char = 'the'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:<0x0A>Inacyclicpatternofcolors,thecolor
# 49th char = 'color'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:<0x0A>Inacyclicpatternofcolors,thecolorthat
# 50th char = 'that'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:<0x0A>Inacyclicpatternofcolors,thecolorthatcomes
# 51th char = 'comes'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:<0x0A>Inacyclicpatternofcolors,thecolorthatcomesafter
# 52th char = 'after'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:<0x0A>Inacyclicpatternofcolors,thecolorthatcomesafterGreen
# 53th char = 'Green'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:<0x0A>Inacyclicpatternofcolors,thecolorthatcomesafterGreenin
# 54th char = 'in'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:<0x0A>Inacyclicpatternofcolors,thecolorthatcomesafterGreeninthe
# 55th char = 'the'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:<0x0A>Inacyclicpatternofcolors,thecolorthatcomesafterGreeninthethird
# 56th char = 'third'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:<0x0A>Inacyclicpatternofcolors,thecolorthatcomesafterGreeninthethirdcycle
# 57th char = 'cycle'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:<0x0A>Inacyclicpatternofcolors,thecolorthatcomesafterGreeninthethirdcycleis
# 58th char = 'is'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:<0x0A>Inacyclicpatternofcolors,thecolorthatcomesafterGreeninthethirdcycleisY
# 59th char = 'Y'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:<0x0A>Inacyclicpatternofcolors,thecolorthatcomesafterGreeninthethirdcycleisYellow
# 60th char = 'ellow'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:<0x0A>Inacyclicpatternofcolors,thecolorthatcomesafterGreeninthethirdcycleisYellow.
# 61th char = '.'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:<0x0A>Inacyclicpatternofcolors,thecolorthatcomesafterGreeninthethirdcycleisYellow.</s>
# 62th char = '</s>'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:<0x0A>Inacyclicpatternofcolors,thecolorthatcomesafterGreeninthethirdcycleisYellow.</s><s>
# 63th char = '<s>'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:<0x0A>Inacyclicpatternofcolors,thecolorthatcomesafterGreeninthethirdcycleisYellow.</s><s>nobody
# 64th char = 'nobody'

# %% [markdown]
# ## random

# %%
heads_of_circ = nw_circ

all_possible_pairs =  [(layer, head) for layer in range(32) for head in range(32)]
# Filter out heads_of_circ from all_possible_pairs
filtered_pairs = [pair for pair in all_possible_pairs if pair not in heads_of_circ]

# Randomly choose 10 pairs ensuring less than 10 overlaps with heads_of_circ
head_to_remove = choose_heads_to_remove(filtered_pairs, heads_of_circ, 100, 10)

heads_not_ablate = [x for x in all_possible_pairs if x not in head_to_remove]

mlps_not_ablate = [layer for layer in range(32)]

num_toks_gen = 30
ablate_then_gen(model, clean_text, corr_text, heads_not_ablate, mlps_not_ablate, num_toks_gen)
# Out:
# 4
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A>
# 35th char = '<0x0A>'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>
# 36th char = '<0x0A>'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer
# 37th char = 'Answer'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:
# 38th char = ':'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:Y
# 39th char = 'Y'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:Yellow
# 40th char = 'ellow'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:Yellow.
# 41th char = '.'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:Yellow.</s>
# 42th char = '</s>'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:Yellow.</s><s>
# 43th char = '<s>'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:Yellow.</s><s>everybody
# 44th char = 'everybody'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:Yellow.</s><s>everybodylov
# 45th char = 'lov'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:Yellow.</s><s>everybodyloves
# 46th char = 'es'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:Yellow.</s><s>everybodylovesray
# 47th char = 'ray'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:Yellow.</s><s>everybodylovesrayg
# 48th char = 'g'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:Yellow.</s><s>everybodylovesrayguns
# 49th char = 'uns'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:Yellow.</s><s>everybodylovesrayguns<0x0A>
# 50th char = '<0x0A>'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:Yellow.</s><s>everybodylovesrayguns<0x0A><0x0A>
# 51th char = '<0x0A>'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:Yellow.</s><s>everybodylovesrayguns<0x0A><0x0A>In
# 52th char = 'In'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:Yellow.</s><s>everybodylovesrayguns<0x0A><0x0A>Ina
# 53th char = 'a'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:Yellow.</s><s>everybodylovesrayguns<0x0A><0x0A>Inacy
# 54th char = 'cy'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:Yellow.</s><s>everybodylovesrayguns<0x0A><0x0A>Inacyclic
# 55th char = 'clic'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:Yellow.</s><s>everybodylovesrayguns<0x0A><0x0A>Inacyclicpattern
# 56th char = 'pattern'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:Yellow.</s><s>everybodylovesrayguns<0x0A><0x0A>Inacyclicpatternof
# 57th char = 'of'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:Yellow.</s><s>everybodylovesrayguns<0x0A><0x0A>Inacyclicpatternofcolors
# 58th char = 'colors'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:Yellow.</s><s>everybodylovesrayguns<0x0A><0x0A>Inacyclicpatternofcolors,
# 59th char = ','
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:Yellow.</s><s>everybodylovesrayguns<0x0A><0x0A>Inacyclicpatternofcolors,the
# 60th char = 'the'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:Yellow.</s><s>everybodylovesrayguns<0x0A><0x0A>Inacyclicpatternofcolors,thecolor
# 61th char = 'color'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:Yellow.</s><s>everybodylovesrayguns<0x0A><0x0A>Inacyclicpatternofcolors,thecolorthat
# 62th char = 'that'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:Yellow.</s><s>everybodylovesrayguns<0x0A><0x0A>Inacyclicpatternofcolors,thecolorthatcomes
# 63th char = 'comes'
# Sequence so far: Be concise. In a cyclic pattern of colors: Red, Blue, Green, Yellow, what color comes after Green in the 3rd cycle?<0x0A><0x0A>Answer:Yellow.</s><s>everybodylovesrayguns<0x0A><0x0A>Inacyclicpatternofcolors,thecolorthatcomesafter
# 64th char = 'after'
