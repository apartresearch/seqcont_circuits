#  (15, 25),
#  (16, 0),
#  (16, 29),
#  (18, 31),
#  (20, 17)}

# %%
# are these numword related heads?

# print(list(set(nw_circ) - set(spanish_nw)))
# print(list(set(spanish_nw) - set(nw_circ)))
print(len(list(set(nw_circ) - set(spanish_nw))))
print(len(list(set(spanish_nw) - set(nw_circ))))

print(len(set(spanish_nw) & set(nw_circ)))
set(spanish_nw) & set(nw_circ)
# Out:
# 59
# 36
# 23
# {(0, 7),
#  (1, 24),
#  (2, 2),
#  (2, 24),
#  (2, 30),
#  (3, 23),
#  (5, 25),
#  (6, 11),
#  (7, 0),
#  (7, 30),
#  (8, 0),
#  (8, 6),
#  (11, 18),
#  (11, 28),
#  (12, 18),
#  (12, 26),
#  (13, 11),
#  (13, 19),
#  (13, 20),
#  (14, 7),
#  (16, 0),
#  (16, 24),
#  (20, 17)}

# %%
# are these spanish seqcont related heads?

# print(list(set(spanish_months) - set(spanish_nw)))
# print(list(set(spanish_nw) - set(spanish_months)))
print(len(list(set(spanish_months) - set(spanish_nw))))
print(len(list(set(spanish_nw) - set(spanish_months))))

print(len(set(spanish_nw) & set(spanish_months)))
set(spanish_nw) & set(spanish_months)
# Out:
# 40
# 48
# 11
# {(5, 25),
#  (6, 11),
#  (8, 0),
#  (8, 8),
#  (11, 18),
#  (12, 22),
#  (12, 23),
#  (12, 26),
#  (12, 31),
#  (16, 0),
#  (20, 17)}

# %%
# are these month seqcont related heads?

# print(list(set(spanish_months) - set(months_circ)))
# print(list(set(months_circ) - set(spanish_months)))
print(len(list(set(spanish_months) - set(months_circ))))
print(len(list(set(months_circ) - set(spanish_months))))

print(len(set(months_circ) & set(spanish_months)))
set(months_circ) & set(spanish_months)
# Out:
# 33
# 46
# 18
# {(3, 15),
#  (5, 15),
#  (5, 25),
#  (6, 11),
#  (6, 14),
#  (8, 4),
#  (8, 13),
#  (10, 13),
#  (11, 18),
#  (12, 3),
#  (12, 15),
#  (12, 22),
#  (15, 25),
#  (16, 0),
#  (16, 29),
#  (17, 11),
#  (20, 17),
#  (23, 16)}

# %%
print(len(set(spanish_nw) & set(nw_circ) & set(months_circ)))
set(spanish_nw) & set(nw_circ) & set(months_circ)
# Out:
# 14
# {(1, 24),
#  (2, 30),
#  (3, 23),
#  (5, 25),
#  (6, 11),
#  (7, 0),
#  (8, 6),
#  (11, 18),
#  (11, 28),
#  (13, 11),
#  (13, 20),
#  (14, 7),
#  (16, 0),
#  (20, 17)}

# %%
# most general heads related to seqcon?

print(len(set(spanish_nw) & set(nw_circ) & set(months_circ) & set(spanish_months) ))
set(spanish_nw) & set(nw_circ) & set(months_circ) & set(spanish_months)
# Out:
# 5
# {(5, 25), (6, 11), (11, 18), (16, 0), (20, 17)}
