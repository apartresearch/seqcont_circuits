# %% [markdown]
# Only keep (not ablate) the query activations (query vector, the output of query weights times inputs) of certain positions. Keep all the key activations; the query positions that were kept will automatically attend to relevant key positions by matrix multiplication.

# %% [markdown]
# # Setup
# (No need to change anything)

# %% [markdown]
# ## import libs

# %%
# Janky code to do different setup when run in a Colab notebook vs VSCode
DEBUG_MODE = False
try:
    import google.colab
    IN_COLAB = True
    print("Running as a Colab notebook")
    # %pip install git+https://github.com/neelnanda-io/TransformerLens.git
    # Install another version of node that makes PySvelte work way faster
    # !curl -fsSL https://deb.nodesource.com/setup_16.x | sudo -E bash -; sudo apt-get install -y nodejs
    # %pip install git+https://github.com/neelnanda-io/PySvelte.git
except:
    IN_COLAB = False
    print("Running as a Jupyter notebook - intended for development only!")
    from IPython import get_ipython

    ipython = get_ipython()
    # Code to automatically update the HookedTransformer code as its edited without restarting the kernel
    ipython.magic("load_ext autoreload")
    ipython.magic("autoreload 2")
# Out:
# Running as a Colab notebook
# Collecting git+https://github.com/neelnanda-io/TransformerLens.git
#   Cloning https://github.com/neelnanda-io/TransformerLens.git to /tmp/pip-req-build-en8z19cx
#   Running command git clone --filter=blob:none --quiet https://github.com/neelnanda-io/TransformerLens.git /tmp/pip-req-build-en8z19cx
#   Resolved https://github.com/neelnanda-io/TransformerLens.git to commit fa287750606075574df2c538058e67d648e2f952
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting accelerate>=0.23.0 (from transformer-lens==0.0.0)
#   Downloading accelerate-0.24.1-py3-none-any.whl (261 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 kB 4.6 MB/s eta 0:00:00
# Collecting beartype<0.15.0,>=0.14.1 (from transformer-lens==0.0.0)
#   Downloading beartype-0.14.1-py3-none-any.whl (739 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.7/739.7 kB 39.4 MB/s eta 0:00:00
# Collecting datasets>=2.7.1 (from transformer-lens==0.0.0)
#   Downloading datasets-2.14.6-py3-none-any.whl (493 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.7/493.7 kB 39.4 MB/s eta 0:00:00
# Collecting einops>=0.6.0 (from transformer-lens==0.0.0)
#   Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 6.7 MB/s eta 0:00:00
# Collecting fancy-einsum>=0.0.3 (from transformer-lens==0.0.0)
#   Downloading fancy_einsum-0.0.3-py3-none-any.whl (6.2 kB)
# Collecting jaxtyping>=0.2.11 (from transformer-lens==0.0.0)
#   Downloading jaxtyping-0.2.23-py3-none-any.whl (29 kB)
# Collecting numpy>=1.24 (from transformer-lens==0.0.0)
#   Downloading numpy-1.26.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 89.2 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12>=12.1.3.1 (from transformer-lens==0.0.0)
#   Downloading nvidia_cublas_cu12-12.3.2.9-py3-none-manylinux1_x86_64.whl (417.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 1.8 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12>=12.1.105 (from transformer-lens==0.0.0)
#   Downloading nvidia_cuda_cupti_cu12-12.3.52-py3-none-manylinux1_x86_64.whl (14.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 92.9 MB/s eta 0:00:00
# Collecting nvidia-cuda-nvrtc-cu12>=12.1.105 (from transformer-lens==0.0.0)
#   Downloading nvidia_cuda_nvrtc_cu12-12.3.52-py3-none-manylinux1_x86_64.whl (24.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.9/24.9 MB 76.4 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12>=12.1.105 (from transformer-lens==0.0.0)
#   Downloading nvidia_cuda_runtime_cu12-12.3.52-py3-none-manylinux1_x86_64.whl (867 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 867.7/867.7 kB 73.8 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12>=8.9.2.26 (from transformer-lens==0.0.0)
#   Downloading nvidia_cudnn_cu12-8.9.4.25-py3-none-manylinux1_x86_64.whl (720.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 720.1/720.1 MB 2.4 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12>=11.0.2.54 (from transformer-lens==0.0.0)
#   Downloading nvidia_cufft_cu12-11.0.11.19-py3-none-manylinux1_x86_64.whl (98.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.8/98.8 MB 16.9 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12>=10.3.2.106 (from transformer-lens==0.0.0)
#   Downloading nvidia_curand_cu12-10.3.4.52-py3-none-manylinux1_x86_64.whl (56.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 26.5 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12>=11.4.5.107 (from transformer-lens==0.0.0)
#   Downloading nvidia_cusolver_cu12-11.5.3.52-py3-none-manylinux1_x86_64.whl (125.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 MB 9.6 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12>=12.1.0.106 (from transformer-lens==0.0.0)
#   Downloading nvidia_cusparse_cu12-12.1.3.153-py3-none-manylinux1_x86_64.whl (195.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.6/195.6 MB 5.2 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12>=2.18.1 (from transformer-lens==0.0.0)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 6.7 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12>=12.1.105 (from transformer-lens==0.0.0)
#   Downloading nvidia_nvtx_cu12-12.3.52-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 13.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from transformer-lens==0.0.0) (1.5.3)
# Requirement already satisfied: rich>=12.6.0 in /usr/local/lib/python3.10/dist-packages (from transformer-lens==0.0.0) (13.6.0)
# Requirement already satisfied: torch>=1.10 in /usr/local/lib/python3.10/dist-packages (from transformer-lens==0.0.0) (2.1.0+cu118)
# Requirement already satisfied: tqdm>=4.64.1 in /usr/local/lib/python3.10/dist-packages (from transformer-lens==0.0.0) (4.66.1)
# Collecting transformers>=4.25.1 (from transformer-lens==0.0.0)
#   Downloading transformers-4.34.1-py3-none-any.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 131.1 MB/s eta 0:00:00
# Requirement already satisfied: triton>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from transformer-lens==0.0.0) (2.1.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from transformer-lens==0.0.0) (4.5.0)
# Collecting wandb>=0.13.5 (from transformer-lens==0.0.0)
#   Downloading wandb-0.15.12-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 90.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.23.0->transformer-lens==0.0.0) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.23.0->transformer-lens==0.0.0) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.23.0->transformer-lens==0.0.0) (6.0.1)
# Collecting huggingface-hub (from accelerate>=0.23.0->transformer-lens==0.0.0)
#   Downloading huggingface_hub-0.18.0-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 35.9 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.7.1->transformer-lens==0.0.0) (9.0.0)
# Collecting dill<0.3.8,>=0.3.0 (from datasets>=2.7.1->transformer-lens==0.0.0)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 15.8 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.7.1->transformer-lens==0.0.0) (2.31.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets>=2.7.1->transformer-lens==0.0.0) (3.4.1)
# Collecting multiprocess (from datasets>=2.7.1->transformer-lens==0.0.0)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 17.8 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.7.1->transformer-lens==0.0.0) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.7.1->transformer-lens==0.0.0) (3.8.6)
# Collecting typeguard<3,>=2.13.3 (from jaxtyping>=0.2.11->transformer-lens==0.0.0)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12>=11.4.5.107->transformer-lens==0.0.0)
#   Downloading nvidia_nvjitlink_cu12-12.3.52-py3-none-manylinux1_x86_64.whl (20.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.5/20.5 MB 85.6 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->transformer-lens==0.0.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->transformer-lens==0.0.0) (2023.3.post1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=12.6.0->transformer-lens==0.0.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=12.6.0->transformer-lens==0.0.0) (2.16.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10->transformer-lens==0.0.0) (3.12.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10->transformer-lens==0.0.0) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10->transformer-lens==0.0.0) (3.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10->transformer-lens==0.0.0) (3.1.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->transformer-lens==0.0.0) (2023.6.3)
# Collecting tokenizers<0.15,>=0.14 (from transformers>=4.25.1->transformer-lens==0.0.0)
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 126.0 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers>=4.25.1->transformer-lens==0.0.0)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 87.0 MB/s eta 0:00:00
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb>=0.13.5->transformer-lens==0.0.0) (8.1.7)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb>=0.13.5->transformer-lens==0.0.0)
#   Downloading GitPython-3.1.40-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 23.3 MB/s eta 0:00:00
# Collecting sentry-sdk>=1.0.0 (from wandb>=0.13.5->transformer-lens==0.0.0)
#   Downloading sentry_sdk-1.32.0-py2.py3-none-any.whl (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.0/241.0 kB 28.8 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb>=0.13.5->transformer-lens==0.0.0)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting pathtools (from wandb>=0.13.5->transformer-lens==0.0.0)
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting setproctitle (from wandb>=0.13.5->transformer-lens==0.0.0)
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb>=0.13.5->transformer-lens==0.0.0) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb>=0.13.5->transformer-lens==0.0.0) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb>=0.13.5->transformer-lens==0.0.0) (3.20.3)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb>=0.13.5->transformer-lens==0.0.0) (1.16.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.7.1->transformer-lens==0.0.0) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.7.1->transformer-lens==0.0.0) (3.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.7.1->transformer-lens==0.0.0) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.7.1->transformer-lens==0.0.0) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.7.1->transformer-lens==0.0.0) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.7.1->transformer-lens==0.0.0) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.7.1->transformer-lens==0.0.0) (1.3.1)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb>=0.13.5->transformer-lens==0.0.0)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=12.6.0->transformer-lens==0.0.0) (0.1.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.7.1->transformer-lens==0.0.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.7.1->transformer-lens==0.0.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.7.1->transformer-lens==0.0.0) (2023.7.22)
# Collecting huggingface-hub (from accelerate>=0.23.0->transformer-lens==0.0.0)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 655.9 kB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10->transformer-lens==0.0.0) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10->transformer-lens==0.0.0) (1.3.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb>=0.13.5->transformer-lens==0.0.0)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Building wheels for collected packages: transformer-lens, pathtools
#   Building wheel for transformer-lens (pyproject.toml) ... done
#   Created wheel for transformer-lens: filename=transformer_lens-0.0.0-py3-none-any.whl size=116432 sha256=c797ec6c169bd4dd3b94c94a6a6e6c77438ff526c16d7937b5c638131c77e4db
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_b8cm5r8/wheels/8a/1e/37/ffb9c15454a1725b13a9d9f5e74fb91725048884ad734b8c1f
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8791 sha256=8ce0232305247839c7d35426badfc1a3b04f614b4399bb188e68f4a83537ebac
#   Stored in directory: /root/.cache/pip/wheels/e7/f3/22/152153d6eb222ee7a56ff8617d80ee5207207a8c00a7aab794
# Successfully built transformer-lens pathtools
# Installing collected packages: pathtools, typeguard, smmap, setproctitle, sentry-sdk, safetensors, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, fancy-einsum, einops, docker-pycreds, dill, beartype, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, jaxtyping, huggingface-hub, gitdb, tokenizers, nvidia-cusolver-cu12, GitPython, accelerate, wandb, transformers, datasets, transformer-lens
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# cupy-cuda11x 11.0.0 requires numpy<1.26,>=1.20, but you have numpy 1.26.1 which is incompatible.
# numba 0.56.4 requires numpy<1.24,>=1.18, but you have numpy 1.26.1 which is incompatible.
# Successfully installed GitPython-3.1.40 accelerate-0.24.1 beartype-0.14.1 datasets-2.14.6 dill-0.3.7 docker-pycreds-0.4.0 einops-0.7.0 fancy-einsum-0.0.3 gitdb-4.0.11 huggingface-hub-0.17.3 jaxtyping-0.2.23 multiprocess-0.70.15 numpy-1.26.1 nvidia-cublas-cu12-12.3.2.9 nvidia-cuda-cupti-cu12-12.3.52 nvidia-cuda-nvrtc-cu12-12.3.52 nvidia-cuda-runtime-cu12-12.3.52 nvidia-cudnn-cu12-8.9.4.25 nvidia-cufft-cu12-11.0.11.19 nvidia-curand-cu12-10.3.4.52 nvidia-cusolver-cu12-11.5.3.52 nvidia-cusparse-cu12-12.1.3.153 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.3.52 nvidia-nvtx-cu12-12.3.52 pathtools-0.1.2 safetensors-0.4.0 sentry-sdk-1.32.0 setproctitle-1.3.3 smmap-5.0.1 tokenizers-0.14.1 transformer-lens-0.0.0 transformers-4.34.1 typeguard-2.13.3 wandb-0.15.12
#
# ================================================================================
# ▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓
# ================================================================================
#
#                            SCRIPT DEPRECATION WARNING
#
#
#   This script, located at https://deb.nodesource.com/setup_X, used to
#   install Node.js is deprecated now and will eventually be made inactive.
#
#   Please visit the NodeSource distributions Github and follow the
#   instructions to migrate your repo.
#   https://github.com/nodesource/distributions
#
#   The NodeSource Node.js Linux distributions GitHub repository contains
#   information about which versions of Node.js and which Linux distributions
#   are supported and how to install it.
#   https://github.com/nodesource/distributions
#
#
#                           SCRIPT DEPRECATION WARNING
#
# ================================================================================
# ▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓
# ================================================================================
#
# TO AVOID THIS WAIT MIGRATE THE SCRIPT
# Continuing in 60 seconds (press Ctrl-C to abort) ...
#
#
# ## Installing the NodeSource Node.js 16.x repo...
#
#
# ## Populating apt-get cache...
#
# + apt-get update
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Get:5 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease [18.1 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [109 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [1,331 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [1,403 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,276 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [34.1 kB]
# Hit:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:13 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:14 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy/main Sources [2,231 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Get:16 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy/main amd64 Packages [1,145 kB]
# Get:17 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [1,306 kB]
# Get:18 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,134 kB]
# Get:19 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,010 kB]
# Fetched 11.2 MB in 8s (1,390 kB/s)
# Reading package lists... Done
#
# ## Confirming "jammy" is supported...
#
# + curl -sLf -o /dev/null 'https://deb.nodesource.com/node_16.x/dists/jammy/Release'
#
# ## Adding the NodeSource signing key to your keyring...
#
# + curl -s https://deb.nodesource.com/gpgkey/nodesource.gpg.key | gpg --dearmor | tee /usr/share/keyrings/nodesource.gpg >/dev/null
#
# ## Creating apt sources list file for the NodeSource Node.js 16.x repo...
#
# + echo 'deb [signed-by=/usr/share/keyrings/nodesource.gpg] https://deb.nodesource.com/node_16.x jammy main' > /etc/apt/sources.list.d/nodesource.list
# + echo 'deb-src [signed-by=/usr/share/keyrings/nodesource.gpg] https://deb.nodesource.com/node_16.x jammy main' >> /etc/apt/sources.list.d/nodesource.list
#
# ## Running `apt-get update` for you...
#
# + apt-get update
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:3 https://deb.nodesource.com/node_16.x jammy InRelease [4,583 B]
# Get:4 https://deb.nodesource.com/node_16.x jammy/main amd64 Packages [776 B]
# Hit:5 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:6 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:11 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Fetched 5,359 B in 10s (561 B/s)
# Reading package lists... Done
#
# ## Run `sudo apt-get install -y nodejs` to install Node.js 16.x and npm
# ## You may also need development tools to build native addons:
#      sudo apt-get install gcc g++ make
# ## To install the Yarn package manager, run:
#      curl -sL https://dl.yarnpkg.com/debian/pubkey.gpg | gpg --dearmor | sudo tee /usr/share/keyrings/yarnkey.gpg >/dev/null
#      echo "deb [signed-by=/usr/share/keyrings/yarnkey.gpg] https://dl.yarnpkg.com/debian stable main" | sudo tee /etc/apt/sources.list.d/yarn.list
#      sudo apt-get update && sudo apt-get install yarn
#
#
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   nodejs
# 0 upgraded, 1 newly installed, 0 to remove and 21 not upgraded.
# Need to get 27.2 MB of archives.
# After this operation, 128 MB of additional disk space will be used.
# Get:1 https://deb.nodesource.com/node_16.x jammy/main amd64 nodejs amd64 16.20.2-deb-1nodesource1 [27.2 MB]
# Fetched 27.2 MB in 1s (53.3 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package nodejs.
# (Reading database ... 120874 files and directories currently installed.)
# Preparing to unpack .../nodejs_16.20.2-deb-1nodesource1_amd64.deb ...
# Unpacking nodejs (16.20.2-deb-1nodesource1) ...
# Setting up nodejs (16.20.2-deb-1nodesource1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Collecting git+https://github.com/neelnanda-io/PySvelte.git
#   Cloning https://github.com/neelnanda-io/PySvelte.git to /tmp/pip-req-build-yyn7kgjn
#   Running command git clone --filter=blob:none --quiet https://github.com/neelnanda-io/PySvelte.git /tmp/pip-req-build-yyn7kgjn
#   Resolved https://github.com/neelnanda-io/PySvelte.git to commit 6f5d971a148d40fb7481d400ae74551b37340e83
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# Plotly needs a different renderer for VSCode/Notebooks vs Colab argh
import plotly.io as pio

if IN_COLAB or not DEBUG_MODE:
    # Thanks to annoying rendering issues, Plotly graphics will either show up in colab OR Vscode depending on the renderer - this is bad for developing demos! Thus creating a debug mode.
    pio.renderers.default = "colab"
else:
    pio.renderers.default = "png"

# %%
# Import stuff
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import einops
from fancy_einsum import einsum
import tqdm.notebook as tqdm
import random
from pathlib import Path
import plotly.express as px
from torch.utils.data import DataLoader

from jaxtyping import Float, Int
from typing import List, Union, Optional
from functools import partial
import copy

import itertools
from transformers import AutoModelForCausalLM, AutoConfig, AutoTokenizer
import dataclasses
import datasets
from IPython.display import HTML

# %%
# import pysvelte

import transformer_lens
import transformer_lens.utils as utils
from transformer_lens.hook_points import (
    HookedRootModule,
    HookPoint,
)  # Hooking utilities
from transformer_lens import HookedTransformer, HookedTransformerConfig, FactoredMatrix, ActivationCache

# %% [markdown]
# We turn automatic differentiation off, to save GPU memory, as this notebook focuses on model inference not model training.

# %%
torch.set_grad_enabled(False)

# %% [markdown]
# Plotting helper functions:

# %%
def imshow(tensor, renderer=None, **kwargs):
    px.imshow(utils.to_numpy(tensor), color_continuous_midpoint=0.0, color_continuous_scale="RdBu", **kwargs).show(renderer)

def line(tensor, renderer=None, **kwargs):
    px.line(y=utils.to_numpy(tensor), **kwargs).show(renderer)

def scatter(x, y, xaxis="", yaxis="", caxis="", renderer=None, **kwargs):
    x = utils.to_numpy(x)
    y = utils.to_numpy(y)
    px.scatter(y=y, x=x, labels={"x":xaxis, "y":yaxis, "color":caxis}, **kwargs).show(renderer)

# %% [markdown]
# ## Load Model

# %% [markdown]
# Decide which model to use (eg. gpt2-small vs -medium)

# %%
model = HookedTransformer.from_pretrained(
    "gpt2-medium",
    center_unembed=True,
    center_writing_weights=True,
    fold_ln=True,
    refactor_factored_attn_matrices=True,
)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/718 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/1.52G [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Loaded pretrained model gpt2-medium into HookedTransformer

# %% [markdown]
# ## Import functions from repo

# %%
# !git clone https://github.com/callummcdougall/ARENA_2.0.git
# Out:
# Cloning into 'ARENA_2.0'...
# remote: Enumerating objects: 9106, done.
# remote: Counting objects: 100% (1820/1820), done.
# remote: Compressing objects: 100% (289/289), done.
# remote: Total 9106 (delta 1614), reused 1608 (delta 1528), pack-reused 7286
# Receiving objects: 100% (9106/9106), 155.60 MiB | 16.25 MiB/s, done.
# Resolving deltas: 100% (5507/5507), done.

# %%
cd ARENA_2.0/chapter1_transformers/exercises/part3_indirect_object_identification
# Out:
# /content/ARENA_2.0/chapter1_transformers/exercises/part3_indirect_object_identification

# %%
import ioi_circuit_extraction as ioi_circuit_extraction

# %% [markdown]
# # Generate dataset with multiple prompts

# %%
class Dataset:
    def __init__(self, prompts, pos_dict, tokenizer, S1_is_first=False):
        self.prompts = prompts
        self.tokenizer = tokenizer
        self.N = len(prompts)
        self.max_len = max(
            [
                len(self.tokenizer(prompt["text"]).input_ids)
                for prompt in self.prompts
            ]
        )
        # all_ids = [prompt["TEMPLATE_IDX"] for prompt in self.ioi_prompts]
        all_ids = [0 for prompt in self.prompts] # only 1 template
        all_ids_ar = np.array(all_ids)
        self.groups = []
        for id in list(set(all_ids)):
            self.groups.append(np.where(all_ids_ar == id)[0])

        texts = [ prompt["text"] for prompt in self.prompts ]
        self.toks = torch.Tensor(self.tokenizer(texts, padding=True).input_ids).type(
            torch.int
        )
        self.io_tokenIDs = [
            self.tokenizer.encode(" " + prompt["corr"])[0] for prompt in self.prompts
        ]
        self.s_tokenIDs = [
            self.tokenizer.encode(" " + prompt["incorr"])[0] for prompt in self.prompts
        ]

        # word_idx: for every prompt, find the token index of each target token and "end"
        # word_idx is a tensor with an element for each prompt. The element is the targ token's ind at that prompt
        self.word_idx = {}
        for targ in [key for key in self.prompts[0].keys() if (key != 'text' and key != 'corr' and key != 'incorr')]:
            targ_lst = []
            for prompt in self.prompts:
                input_text = prompt["text"]
                tokens = model.tokenizer.tokenize(input_text)
                # if S1_is_first and targ == "S1":  # only use this if first token doesn't have space Ġ in front
                #     target_token = prompt[targ]
                # else:
                #     target_token = "Ġ" + prompt[targ]
                # target_index = tokens.index(target_token)
                target_index = pos_dict[targ]
                targ_lst.append(target_index)
            self.word_idx[targ] = torch.tensor(targ_lst)

        targ_lst = []
        for prompt in self.prompts:
            input_text = prompt["text"]
            tokens = self.tokenizer.tokenize(input_text)
            end_token_index = len(tokens) - 1
            targ_lst.append(end_token_index)
        self.word_idx["end"] = torch.tensor(targ_lst)

    def __len__(self):
        return self.N

# %%
pos_dict = {
    'S1': 0,
    'S2': 1,
    'S3': 2,
    'S4': 3,
    'S5': 4,
    'S6': 5,
}

# %%
def generate_prompts_list(x ,y):
    prompts_list = []
    for i in range(x, y):
        prompt_dict = {
            'S1': str(i),
            'S2': str(i+1),
            'S3': str(i+2),
            'S4': str(i+3),
            'S5': str(i+4),
            'S6': str(i+5),
            'corr': str(i+6),
            'incorr': str(i+5),
            'text': f"{i} {i+1} {i+2} {i+3} {i+4} {i+5}"
        }
        prompts_list.append(prompt_dict)
    return prompts_list

prompts_list = generate_prompts_list(1, 101)
dataset = Dataset(prompts_list, pos_dict, model.tokenizer, S1_is_first=True)

# %%
import random

def generate_prompts_list_corr(x ,y):
    prompts_list = []
    for i in range(x, y):
        r1 = random.randint(1, 100)
        r2 = random.randint(1, 100)
        r3 = random.randint(1, 100)
        r4 = random.randint(1, 100)
        r5 = random.randint(1, 100)
        r6 = random.randint(1, 100)
        prompt_dict = {
            'S1': str(r1),
            'S2': str(r2),
            'S3': str(r3),
            'S4': str(r4),
            'S5': str(r5),
            'S6': str(r6),
            'corr': str(r1),
            'incorr': str(i+6),
            'text': f"{r1} {r2} {r3} {r4} {r5} {r6}"
        }
        prompts_list.append(prompt_dict)
    return prompts_list

prompts_list_2 = generate_prompts_list_corr(1, 101)
dataset_2 = Dataset(prompts_list_2, pos_dict, model.tokenizer, S1_is_first=True)
prompts_list_2
# Out:
# [{'S1': '81',
#   'S2': '92',
#   'S3': '80',
#   'S4': '94',
#   'S5': '7',
#   'S6': '38',
#   'corr': '81',
#   'incorr': '7',
#   'text': '81 92 80 94 7 38'},
#  {'S1': '81',
#   'S2': '75',
#   'S3': '4',
#   'S4': '1',
#   'S5': '45',
#   'S6': '11',
#   'corr': '81',
#   'incorr': '8',
#   'text': '81 75 4 1 45 11'},
#  {'S1': '21',
#   'S2': '24',
#   'S3': '28',
#   'S4': '36',
#   'S5': '77',
#   'S6': '19',
#   'corr': '21',
#   'incorr': '9',
#   'text': '21 24 28 36 77 19'},
#  {'S1': '19',
#   'S2': '43',
#   'S3': '16',
#   'S4': '89',
#   'S5': '92',
#   'S6': '35',
#   'corr': '19',
#   'incorr': '10',
#   'text': '19 43 16 89 92 35'},
#  {'S1': '80',
#   'S2': '88',
#   'S3': '23',
#   'S4': '35',
#   'S5': '65',
#   'S6': '28',
#   'corr': '80',
#   'incorr': '11',
#   'text': '80 88 23 35 65 28'},
#  {'S1': '64',
#   'S2': '98',
#   'S3': '27',
#   'S4': '84',
#   'S5': '90',
#   'S6': '100',
#   'corr': '64',
#   'incorr': '12',
#   'text': '64 98 27 84 90 100'},
#  {'S1': '53',
#   'S2': '62',
#   'S3': '19',
#   'S4': '17',
#   'S5': '96',
#   'S6': '85',
#   'corr': '53',
#   'incorr': '13',
#   'text': '53 62 19 17 96 85'},
#  {'S1': '27',
#   'S2': '84',
#   'S3': '81',
#   'S4': '34',
#   'S5': '39',
#   'S6': '56',
#   'corr': '27',
#   'incorr': '14',
#   'text': '27 84 81 34 39 56'},
#  {'S1': '44',
#   'S2': '32',
#   'S3': '100',
#   'S4': '52',
#   'S5': '27',
#   'S6': '51',
#   'corr': '44',
#   'incorr': '15',
#   'text': '44 32 100 52 27 51'},
#  {'S1': '10',
#   'S2': '45',
#   'S3': '11',
#   'S4': '1',
#   'S5': '84',
#   'S6': '99',
#   'corr': '10',
#   'incorr': '16',
#   'text': '10 45 11 1 84 99'},
#  {'S1': '36',
#   'S2': '67',
#   'S3': '12',
#   'S4': '23',
#   'S5': '79',
#   'S6': '35',
#   'corr': '36',
#   'incorr': '17',
#   'text': '36 67 12 23 79 35'},
#  {'S1': '99',
#   'S2': '76',
#   'S3': '46',
#   'S4': '39',
#   'S5': '49',
#   'S6': '27',
#   'corr': '99',
#   'incorr': '18',
#   'text': '99 76 46 39 49 27'},
#  {'S1': '12',
#   'S2': '44',
#   'S3': '64',
#   'S4': '28',
#   'S5': '81',
#   'S6': '96',
#   'corr': '12',
#   'incorr': '19',
#   'text': '12 44 64 28 81 96'},
#  {'S1': '52',
#   'S2': '69',
#   'S3': '34',
#   'S4': '58',
#   'S5': '85',
#   'S6': '87',
#   'corr': '52',
#   'incorr': '20',
#   'text': '52 69 34 58 85 87'},
#  {'S1': '16',
#   'S2': '3',
#   'S3': '21',
#   'S4': '49',
#   'S5': '42',
#   'S6': '63',
#   'corr': '16',
#   'incorr': '21',
#   'text': '16 3 21 49 42 63'},
#  {'S1': '50',
#   'S2': '92',
#   'S3': '13',
#   'S4': '70',
#   'S5': '26',
#   'S6': '39',
#   'corr': '50',
#   'incorr': '22',
#   'text': '50 92 13 70 26 39'},
#  {'S1': '62',
#   'S2': '17',
#   'S3': '82',
#   'S4': '42',
#   'S5': '37',
#   'S6': '65',
#   'corr': '62',
#   'incorr': '23',
#   'text': '62 17 82 42 37 65'},
#  {'S1': '84',
#   'S2': '26',
#   'S3': '40',
#   'S4': '24',
#   'S5': '25',
#   'S6': '72',
#   'corr': '84',
#   'incorr': '24',
#   'text': '84 26 40 24 25 72'},
#  {'S1': '62',
#   'S2': '11',
#   'S3': '45',
#   'S4': '47',
#   'S5': '68',
#   'S6': '81',
#   'corr': '62',
#   'incorr': '25',
#   'text': '62 11 45 47 68 81'},
#  {'S1': '53',
#   'S2': '15',
#   'S3': '85',
#   'S4': '22',
#   'S5': '64',
#   'S6': '46',
#   'corr': '53',
#   'incorr': '26',
#   'text': '53 15 85 22 64 46'},
#  {'S1': '72',
#   'S2': '10',
#   'S3': '95',
#   'S4': '12',
#   'S5': '48',
#   'S6': '24',
#   'corr': '72',
#   'incorr': '27',
#   'text': '72 10 95 12 48 24'},
#  {'S1': '34',
#   'S2': '2',
#   'S3': '40',
#   'S4': '47',
#   'S5': '14',
#   'S6': '41',
#   'corr': '34',
#   'incorr': '28',
#   'text': '34 2 40 47 14 41'},
#  {'S1': '79',
#   'S2': '6',
#   'S3': '84',
#   'S4': '5',
#   'S5': '7',
#   'S6': '60',
#   'corr': '79',
#   'incorr': '29',
#   'text': '79 6 84 5 7 60'},
#  {'S1': '5',
#   'S2': '32',
#   'S3': '12',
#   'S4': '72',
#   'S5': '71',
#   'S6': '5',
#   'corr': '5',
#   'incorr': '30',
#   'text': '5 32 12 72 71 5'},
#  {'S1': '21',
#   'S2': '72',
#   'S3': '24',
#   'S4': '34',
#   'S5': '10',
#   'S6': '73',
#   'corr': '21',
#   'incorr': '31',
#   'text': '21 72 24 34 10 73'},
#  {'S1': '63',
#   'S2': '75',
#   'S3': '7',
#   'S4': '28',
#   'S5': '36',
#   'S6': '69',
#   'corr': '63',
#   'incorr': '32',
#   'text': '63 75 7 28 36 69'},
#  {'S1': '47',
#   'S2': '31',
#   'S3': '83',
#   'S4': '41',
#   'S5': '8',
#   'S6': '8',
#   'corr': '47',
#   'incorr': '33',
#   'text': '47 31 83 41 8 8'},
#  {'S1': '4',
#   'S2': '52',
#   'S3': '38',
#   'S4': '81',
#   'S5': '46',
#   'S6': '53',
#   'corr': '4',
#   'incorr': '34',
#   'text': '4 52 38 81 46 53'},
#  {'S1': '100',
#   'S2': '64',
#   'S3': '1',
#   'S4': '48',
#   'S5': '17',
#   'S6': '29',
#   'corr': '100',
#   'incorr': '35',
#   'text': '100 64 1 48 17 29'},
#  {'S1': '49',
#   'S2': '71',
#   'S3': '28',
#   'S4': '33',
#   'S5': '43',
#   'S6': '15',
#   'corr': '49',
#   'incorr': '36',
#   'text': '49 71 28 33 43 15'},
#  {'S1': '100',
#   'S2': '21',
#   'S3': '54',
#   'S4': '86',
#   'S5': '89',
#   'S6': '78',
#   'corr': '100',
#   'incorr': '37',
#   'text': '100 21 54 86 89 78'},
#  {'S1': '84',
#   'S2': '62',
#   'S3': '71',
#   'S4': '41',
#   'S5': '48',
#   'S6': '85',
#   'corr': '84',
#   'incorr': '38',
#   'text': '84 62 71 41 48 85'},
#  {'S1': '63',
#   'S2': '30',
#   'S3': '21',
#   'S4': '88',
#   'S5': '11',
#   'S6': '65',
#   'corr': '63',
#   'incorr': '39',
#   'text': '63 30 21 88 11 65'},
#  {'S1': '100',
#   'S2': '93',
#   'S3': '28',
#   'S4': '40',
#   'S5': '64',
#   'S6': '82',
#   'corr': '100',
#   'incorr': '40',
#   'text': '100 93 28 40 64 82'},
#  {'S1': '81',
#   'S2': '59',
#   'S3': '56',
#   'S4': '42',
#   'S5': '7',
#   'S6': '9',
#   'corr': '81',
#   'incorr': '41',
#   'text': '81 59 56 42 7 9'},
#  {'S1': '73',
#   'S2': '22',
#   'S3': '22',
#   'S4': '2',
#   'S5': '38',
#   'S6': '63',
#   'corr': '73',
#   'incorr': '42',
#   'text': '73 22 22 2 38 63'},
#  {'S1': '57',
#   'S2': '10',
#   'S3': '84',
#   'S4': '52',
#   'S5': '85',
#   'S6': '60',
#   'corr': '57',
#   'incorr': '43',
#   'text': '57 10 84 52 85 60'},
#  {'S1': '94',
#   'S2': '75',
#   'S3': '11',
#   'S4': '12',
#   'S5': '91',
#   'S6': '88',
#   'corr': '94',
#   'incorr': '44',
#   'text': '94 75 11 12 91 88'},
#  {'S1': '41',
#   'S2': '33',
#   'S3': '97',
#   'S4': '16',
#   'S5': '13',
#   'S6': '41',
#   'corr': '41',
#   'incorr': '45',
#   'text': '41 33 97 16 13 41'},
#  {'S1': '41',
#   'S2': '83',
#   'S3': '47',
#   'S4': '5',
#   'S5': '60',
#   'S6': '38',
#   'corr': '41',
#   'incorr': '46',
#   'text': '41 83 47 5 60 38'},
#  {'S1': '28',
#   'S2': '80',
#   'S3': '70',
#   'S4': '1',
#   'S5': '68',
#   'S6': '42',
#   'corr': '28',
#   'incorr': '47',
#   'text': '28 80 70 1 68 42'},
#  {'S1': '13',
#   'S2': '89',
#   'S3': '34',
#   'S4': '30',
#   'S5': '27',
#   'S6': '70',
#   'corr': '13',
#   'incorr': '48',
#   'text': '13 89 34 30 27 70'},
#  {'S1': '11',
#   'S2': '19',
#   'S3': '29',
#   'S4': '64',
#   'S5': '77',
#   'S6': '72',
#   'corr': '11',
#   'incorr': '49',
#   'text': '11 19 29 64 77 72'},
#  {'S1': '7',
#   'S2': '99',
#   'S3': '37',
#   'S4': '74',
#   'S5': '86',
#   'S6': '27',
#   'corr': '7',
#   'incorr': '50',
#   'text': '7 99 37 74 86 27'},
#  {'S1': '85',
#   'S2': '35',
#   'S3': '3',
#   'S4': '80',
#   'S5': '39',
#   'S6': '79',
#   'corr': '85',
#   'incorr': '51',
#   'text': '85 35 3 80 39 79'},
#  {'S1': '84',
#   'S2': '84',
#   'S3': '96',
#   'S4': '98',
#   'S5': '52',
#   'S6': '53',
#   'corr': '84',
#   'incorr': '52',
#   'text': '84 84 96 98 52 53'},
#  {'S1': '93',
#   'S2': '44',
#   'S3': '69',
#   'S4': '61',
#   'S5': '46',
#   'S6': '4',
#   'corr': '93',
#   'incorr': '53',
#   'text': '93 44 69 61 46 4'},
#  {'S1': '66',
#   'S2': '58',
#   'S3': '61',
#   'S4': '10',
#   'S5': '72',
#   'S6': '98',
#   'corr': '66',
#   'incorr': '54',
#   'text': '66 58 61 10 72 98'},
#  {'S1': '85',
#   'S2': '70',
#   'S3': '14',
#   'S4': '27',
#   'S5': '9',
#   'S6': '50',
#   'corr': '85',
#   'incorr': '55',
#   'text': '85 70 14 27 9 50'},
#  {'S1': '17',
#   'S2': '56',
#   'S3': '34',
#   'S4': '66',
#   'S5': '12',
#   'S6': '38',
#   'corr': '17',
#   'incorr': '56',
#   'text': '17 56 34 66 12 38'},
#  {'S1': '43',
#   'S2': '32',
#   'S3': '72',
#   'S4': '93',
#   'S5': '99',
#   'S6': '52',
#   'corr': '43',
#   'incorr': '57',
#   'text': '43 32 72 93 99 52'},
#  {'S1': '96',
#   'S2': '42',
#   'S3': '80',
#   'S4': '16',
#   'S5': '14',
#   'S6': '89',
#   'corr': '96',
#   'incorr': '58',
#   'text': '96 42 80 16 14 89'},
#  {'S1': '97',
#   'S2': '70',
#   'S3': '99',
#   'S4': '20',
#   'S5': '63',
#   'S6': '82',
#   'corr': '97',
#   'incorr': '59',
#   'text': '97 70 99 20 63 82'},
#  {'S1': '63',
#   'S2': '2',
#   'S3': '52',
#   'S4': '99',
#   'S5': '26',
#   'S6': '51',
#   'corr': '63',
#   'incorr': '60',
#   'text': '63 2 52 99 26 51'},
#  {'S1': '64',
#   'S2': '19',
#   'S3': '45',
#   'S4': '28',
#   'S5': '38',
#   'S6': '74',
#   'corr': '64',
#   'incorr': '61',
#   'text': '64 19 45 28 38 74'},
#  {'S1': '89',
#   'S2': '72',
#   'S3': '74',
#   'S4': '41',
#   'S5': '90',
#   'S6': '39',
#   'corr': '89',
#   'incorr': '62',
#   'text': '89 72 74 41 90 39'},
#  {'S1': '80',
#   'S2': '36',
#   'S3': '42',
#   'S4': '91',
#   'S5': '25',
#   'S6': '43',
#   'corr': '80',
#   'incorr': '63',
#   'text': '80 36 42 91 25 43'},
#  {'S1': '45',
#   'S2': '75',
#   'S3': '57',
#   'S4': '98',
#   'S5': '32',
#   'S6': '37',
#   'corr': '45',
#   'incorr': '64',
#   'text': '45 75 57 98 32 37'},
#  {'S1': '31',
#   'S2': '17',
#   'S3': '22',
#   'S4': '71',
#   'S5': '46',
#   'S6': '15',
#   'corr': '31',
#   'incorr': '65',
#   'text': '31 17 22 71 46 15'},
#  {'S1': '55',
#   'S2': '22',
#   'S3': '98',
#   'S4': '61',
#   'S5': '47',
#   'S6': '63',
#   'corr': '55',
#   'incorr': '66',
#   'text': '55 22 98 61 47 63'},
#  {'S1': '7',
#   'S2': '51',
#   'S3': '9',
#   'S4': '11',
#   'S5': '56',
#   'S6': '3',
#   'corr': '7',
#   'incorr': '67',
#   'text': '7 51 9 11 56 3'},
#  {'S1': '81',
#   'S2': '43',
#   'S3': '87',
#   'S4': '93',
#   'S5': '88',
#   'S6': '57',
#   'corr': '81',
#   'incorr': '68',
#   'text': '81 43 87 93 88 57'},
#  {'S1': '97',
#   'S2': '66',
#   'S3': '23',
#   'S4': '72',
#   'S5': '34',
#   'S6': '15',
#   'corr': '97',
#   'incorr': '69',
#   'text': '97 66 23 72 34 15'},
#  {'S1': '100',
#   'S2': '13',
#   'S3': '99',
#   'S4': '93',
#   'S5': '92',
#   'S6': '48',
#   'corr': '100',
#   'incorr': '70',
#   'text': '100 13 99 93 92 48'},
#  {'S1': '83',
#   'S2': '21',
#   'S3': '37',
#   'S4': '70',
#   'S5': '92',
#   'S6': '74',
#   'corr': '83',
#   'incorr': '71',
#   'text': '83 21 37 70 92 74'},
#  {'S1': '19',
#   'S2': '36',
#   'S3': '15',
#   'S4': '41',
#   'S5': '83',
#   'S6': '46',
#   'corr': '19',
#   'incorr': '72',
#   'text': '19 36 15 41 83 46'},
#  {'S1': '59',
#   'S2': '47',
#   'S3': '81',
#   'S4': '73',
#   'S5': '86',
#   'S6': '71',
#   'corr': '59',
#   'incorr': '73',
#   'text': '59 47 81 73 86 71'},
#  {'S1': '69',
#   'S2': '73',
#   'S3': '79',
#   'S4': '59',
#   'S5': '51',
#   'S6': '7',
#   'corr': '69',
#   'incorr': '74',
#   'text': '69 73 79 59 51 7'},
#  {'S1': '100',
#   'S2': '47',
#   'S3': '85',
#   'S4': '39',
#   'S5': '61',
#   'S6': '15',
#   'corr': '100',
#   'incorr': '75',
#   'text': '100 47 85 39 61 15'},
#  {'S1': '76',
#   'S2': '24',
#   'S3': '100',
#   'S4': '41',
#   'S5': '57',
#   'S6': '15',
#   'corr': '76',
#   'incorr': '76',
#   'text': '76 24 100 41 57 15'},
#  {'S1': '44',
#   'S2': '20',
#   'S3': '16',
#   'S4': '30',
#   'S5': '76',
#   'S6': '3',
#   'corr': '44',
#   'incorr': '77',
#   'text': '44 20 16 30 76 3'},
#  {'S1': '18',
#   'S2': '90',
#   'S3': '67',
#   'S4': '95',
#   'S5': '23',
#   'S6': '92',
#   'corr': '18',
#   'incorr': '78',
#   'text': '18 90 67 95 23 92'},
#  {'S1': '27',
#   'S2': '24',
#   'S3': '94',
#   'S4': '67',
#   'S5': '4',
#   'S6': '13',
#   'corr': '27',
#   'incorr': '79',
#   'text': '27 24 94 67 4 13'},
#  {'S1': '74',
#   'S2': '88',
#   'S3': '7',
#   'S4': '81',
#   'S5': '68',
#   'S6': '48',
#   'corr': '74',
#   'incorr': '80',
#   'text': '74 88 7 81 68 48'},
#  {'S1': '75',
#   'S2': '83',
#   'S3': '23',
#   'S4': '5',
#   'S5': '13',
#   'S6': '63',
#   'corr': '75',
#   'incorr': '81',
#   'text': '75 83 23 5 13 63'},
#  {'S1': '40',
#   'S2': '12',
#   'S3': '59',
#   'S4': '44',
#   'S5': '68',
#   'S6': '75',
#   'corr': '40',
#   'incorr': '82',
#   'text': '40 12 59 44 68 75'},
#  {'S1': '62',
#   'S2': '87',
#   'S3': '69',
#   'S4': '32',
#   'S5': '13',
#   'S6': '88',
#   'corr': '62',
#   'incorr': '83',
#   'text': '62 87 69 32 13 88'},
#  {'S1': '1',
#   'S2': '38',
#   'S3': '58',
#   'S4': '65',
#   'S5': '32',
#   'S6': '62',
#   'corr': '1',
#   'incorr': '84',
#   'text': '1 38 58 65 32 62'},
#  {'S1': '75',
#   'S2': '77',
#   'S3': '79',
#   'S4': '16',
#   'S5': '1',
#   'S6': '50',
#   'corr': '75',
#   'incorr': '85',
#   'text': '75 77 79 16 1 50'},
#  {'S1': '55',
#   'S2': '91',
#   'S3': '25',
#   'S4': '29',
#   'S5': '92',
#   'S6': '47',
#   'corr': '55',
#   'incorr': '86',
#   'text': '55 91 25 29 92 47'},
#  {'S1': '40',
#   'S2': '92',
#   'S3': '87',
#   'S4': '89',
#   'S5': '68',
#   'S6': '90',
#   'corr': '40',
#   'incorr': '87',
#   'text': '40 92 87 89 68 90'},
#  {'S1': '18',
#   'S2': '31',
#   'S3': '40',
#   'S4': '98',
#   'S5': '78',
#   'S6': '33',
#   'corr': '18',
#   'incorr': '88',
#   'text': '18 31 40 98 78 33'},
#  {'S1': '11',
#   'S2': '49',
#   'S3': '44',
#   'S4': '33',
#   'S5': '85',
#   'S6': '51',
#   'corr': '11',
#   'incorr': '89',
#   'text': '11 49 44 33 85 51'},
#  {'S1': '49',
#   'S2': '18',
#   'S3': '3',
#   'S4': '16',
#   'S5': '28',
#   'S6': '19',
#   'corr': '49',
#   'incorr': '90',
#   'text': '49 18 3 16 28 19'},
#  {'S1': '87',
#   'S2': '77',
#   'S3': '32',
#   'S4': '70',
#   'S5': '4',
#   'S6': '27',
#   'corr': '87',
#   'incorr': '91',
#   'text': '87 77 32 70 4 27'},
#  {'S1': '59',
#   'S2': '4',
#   'S3': '86',
#   'S4': '80',
#   'S5': '66',
#   'S6': '3',
#   'corr': '59',
#   'incorr': '92',
#   'text': '59 4 86 80 66 3'},
#  {'S1': '76',
#   'S2': '75',
#   'S3': '7',
#   'S4': '22',
#   'S5': '47',
#   'S6': '10',
#   'corr': '76',
#   'incorr': '93',
#   'text': '76 75 7 22 47 10'},
#  {'S1': '30',
#   'S2': '26',
#   'S3': '97',
#   'S4': '6',
#   'S5': '70',
#   'S6': '30',
#   'corr': '30',
#   'incorr': '94',
#   'text': '30 26 97 6 70 30'},
#  {'S1': '24',
#   'S2': '16',
#   'S3': '51',
#   'S4': '57',
#   'S5': '100',
#   'S6': '30',
#   'corr': '24',
#   'incorr': '95',
#   'text': '24 16 51 57 100 30'},
#  {'S1': '55',
#   'S2': '65',
#   'S3': '33',
#   'S4': '82',
#   'S5': '68',
#   'S6': '35',
#   'corr': '55',
#   'incorr': '96',
#   'text': '55 65 33 82 68 35'},
#  {'S1': '95',
#   'S2': '23',
#   'S3': '51',
#   'S4': '71',
#   'S5': '85',
#   'S6': '82',
#   'corr': '95',
#   'incorr': '97',
#   'text': '95 23 51 71 85 82'},
#  {'S1': '49',
#   'S2': '90',
#   'S3': '58',
#   'S4': '74',
#   'S5': '76',
#   'S6': '37',
#   'corr': '49',
#   'incorr': '98',
#   'text': '49 90 58 74 76 37'},
#  {'S1': '43',
#   'S2': '13',
#   'S3': '95',
#   'S4': '93',
#   'S5': '100',
#   'S6': '2',
#   'corr': '43',
#   'incorr': '99',
#   'text': '43 13 95 93 100 2'},
#  {'S1': '15',
#   'S2': '79',
#   'S3': '74',
#   'S4': '46',
#   'S5': '44',
#   'S6': '13',
#   'corr': '15',
#   'incorr': '100',
#   'text': '15 79 74 46 44 13'},
#  {'S1': '38',
#   'S2': '100',
#   'S3': '60',
#   'S4': '84',
#   'S5': '1',
#   'S6': '99',
#   'corr': '38',
#   'incorr': '101',
#   'text': '38 100 60 84 1 99'},
#  {'S1': '10',
#   'S2': '93',
#   'S3': '1',
#   'S4': '3',
#   'S5': '63',
#   'S6': '17',
#   'corr': '10',
#   'incorr': '102',
#   'text': '10 93 1 3 63 17'},
#  {'S1': '67',
#   'S2': '50',
#   'S3': '7',
#   'S4': '86',
#   'S5': '28',
#   'S6': '21',
#   'corr': '67',
#   'incorr': '103',
#   'text': '67 50 7 86 28 21'},
#  {'S1': '55',
#   'S2': '41',
#   'S3': '90',
#   'S4': '37',
#   'S5': '34',
#   'S6': '49',
#   'corr': '55',
#   'incorr': '104',
#   'text': '55 41 90 37 34 49'},
#  {'S1': '12',
#   'S2': '99',
#   'S3': '85',
#   'S4': '57',
#   'S5': '24',
#   'S6': '35',
#   'corr': '12',
#   'incorr': '105',
#   'text': '12 99 85 57 24 35'},
#  {'S1': '74',
#   'S2': '71',
#   'S3': '21',
#   'S4': '64',
#   'S5': '7',
#   'S6': '65',
#   'corr': '74',
#   'incorr': '106',
#   'text': '74 71 21 64 7 65'}]

# %% [markdown]
# Logit diff is correct - incorr token. Here, correct is S5, and incorr is S4.
#
# Because of this, it's possible to have logit diffs HIGHER than the "full circuit" because the correct token will still be at first place, but the logit scores assigned will just be bigger (perhaps incorrect is scored even lower in the non-full circuit with a higher logit diff score)?

# %% [markdown]
# # Ablation Expm Functions

# %%
from torch import Tensor

def logits_to_ave_logit_diff_2(logits: Float[Tensor, "batch seq d_vocab"], dataset: Dataset, per_prompt=False):
    '''
    Returns logit difference between the correct and incorrect answer.

    If per_prompt=True, return the array of differences rather than the average.
    '''

    # Only the final logits are relevant for the answer
    # Get the logits corresponding to the indirect object / subject tokens respectively
    io_logits: Float[Tensor, "batch"] = logits[range(logits.size(0)), dataset.word_idx["end"], dataset.io_tokenIDs]
    s_logits: Float[Tensor, "batch"] = logits[range(logits.size(0)), dataset.word_idx["end"], dataset.s_tokenIDs]
    # Find logit difference
    answer_logit_diff = io_logits - s_logits
    return answer_logit_diff if per_prompt else answer_logit_diff.mean()

# %% [markdown]
# We can also prevent redundant computation of the full circuit score by storing it and just passing it in to the function.

# %%
ioi_logits_original, ioi_cache = model.run_with_cache(dataset.toks)
orig_score = logits_to_ave_logit_diff_2(ioi_logits_original, dataset)

# %%
model.reset_hooks(including_permanent=True)  #must do this after running with mean ablation hook
ioi_logits_original, ioi_cache = model.run_with_cache(dataset.toks)
logits_to_ave_logit_diff_2(ioi_logits_original, dataset)
# Out:
# tensor(8.2426, device='cuda:0')

# %%
def mean_ablate_by_lst(CIRCUIT, SEQ_POS_TO_KEEP, model, orig_score, print_output=True):
    model.reset_hooks(including_permanent=True)  #must do this after running with mean ablation hook

    # ioi_logits_original, ioi_cache = model.run_with_cache(dataset.toks)

    model_abl = ioi_circuit_extraction.add_mean_ablation_hook(model, means_dataset=dataset_2, circuit=CIRCUIT, seq_pos_to_keep=SEQ_POS_TO_KEEP)
    ioi_logits_minimal = model_abl(dataset.toks)

    # orig_score = logits_to_ave_logit_diff_2(ioi_logits_original, dataset)

    new_score = logits_to_ave_logit_diff_2(ioi_logits_minimal, dataset)
    if print_output:
        # print(f"Average logit difference (IOI dataset, using entire model): {orig_score:.4f}")
        # print(f"Average logit difference (IOI dataset, only using circuit): {new_score:.4f}")
        print(f"Average logit difference (circuit / full) %: {100 * new_score / orig_score:.4f}")
    # return new_score
    return 100 * new_score / orig_score

# %%
lst = [(0, 0)]

CIRCUIT = {
    "number mover": lst,
    "number mover 5": lst,
    "number mover 4": lst,
    "number mover 3": lst,
    "number mover 2": lst,
    "number mover 1": lst,
}

SEQ_POS_TO_KEEP = {
    "number mover": "end",
    "number mover 5": "S5",
    "number mover 4": "S4",
    "number mover 3": "S3",
    "number mover 2": "S2",
    "number mover 1": "S1",
}

model.reset_hooks(including_permanent=True)  #must do this after running with mean ablation hook
model_abl = ioi_circuit_extraction.add_mean_ablation_hook(model, means_dataset=dataset_2, circuit=CIRCUIT, seq_pos_to_keep=SEQ_POS_TO_KEEP)
ioi_logits_minimal = model_abl(dataset.toks)
logits_to_ave_logit_diff_2(ioi_logits_minimal, dataset)
# Out:
# tensor(-0.0447, device='cuda:0')

# %% [markdown]
# # Ablate the model and compare with original

# %%
lst = [(layer, head) for layer in range(24) for head in range(16)]

CIRCUIT = {
    "number mover": lst,
    "number mover 5": lst,
    "number mover 4": lst,
    "number mover 3": lst,
    "number mover 2": lst,
    "number mover 1": lst,
}

SEQ_POS_TO_KEEP = {
    "number mover": "end",
    "number mover 5": "S5",
    "number mover 4": "S4",
    "number mover 3": "S3",
    "number mover 2": "S2",
    "number mover 1": "S1",
}

mean_ablate_by_lst(CIRCUIT, SEQ_POS_TO_KEEP, model, orig_score, print_output=False).item()
# Out:
# 100.0

# %%
def circuit_from_headsList(headsList):
    CIRCUIT = {
    "number mover": headsList,
    "number mover 5": headsList,
    "number mover 4": headsList,
    "number mover 3": headsList,
    "number mover 2": headsList,
    "number mover 1": headsList,
    }

    SEQ_POS_TO_KEEP = {
        "number mover": "end",
        "number mover 5": "S5",
        "number mover 4": "S4",
        "number mover 3": "S3",
        "number mover 2": "S2",
        "number mover 1": "S1",
    }
    return CIRCUIT, SEQ_POS_TO_KEEP

# %%
CIRCUIT, SEQ_POS_TO_KEEP = circuit_from_headsList([(0,0)])
mean_ablate_by_lst(CIRCUIT, SEQ_POS_TO_KEEP, model, orig_score, print_output=False).item()
# Out:
# -0.5424507856369019

# %%
# Start with full circuit
curr_circuit = [(layer, head) for layer in range(24) for head in range(16)]
threshold = 3  # This is T, a %. if performance is less than T%, allow its removal

for layer in range(23, -1, -1):  # go thru all heads in a layer first
    for head in range(16):
        # Copying the curr_circuit so we can iterate over one and modify the other
        copy_circuit = curr_circuit.copy()

        # Temporarily removing the current tuple from the copied circuit
        copy_circuit.remove((layer, head))

        CIRCUIT, SEQ_POS_TO_KEEP = circuit_from_headsList(copy_circuit)
        new_score = mean_ablate_by_lst(CIRCUIT, SEQ_POS_TO_KEEP, model, orig_score, print_output=False).item()

        # print((layer,head), new_score)
        # If the result is less than the threshold, remove the tuple from the original list
        if (100 - new_score) < threshold:
            curr_circuit.remove((layer, head))

            print("Removed:", (layer, head))
            print(new_score)
            print("\n")
# Out:
# Removed: (23, 0)
# 100.05462646484375
#
#
# Removed: (23, 1)
# 99.90754699707031
#
#
# Removed: (23, 2)
# 99.92961883544922
#
#
# Removed: (23, 3)
# 99.65225982666016
#
#
# Removed: (23, 4)
# 99.30018615722656
#
#
# Removed: (23, 5)
# 99.90575408935547
#
#
# Removed: (23, 6)
# 100.0451889038086
#
#
# Removed: (23, 7)
# 100.4909439086914
#
#
# Removed: (23, 8)
# 99.06684875488281
#
#
# Removed: (23, 9)
# 99.07476806640625
#
#
# Removed: (23, 10)
# 99.26447296142578
#
#
# Removed: (23, 11)
# 99.05616760253906
#
#
# Removed: (23, 12)
# 99.20416259765625
#
#
# Removed: (23, 13)
# 99.84165954589844
#
#
# Removed: (23, 14)
# 99.87984466552734
#
#
# Removed: (23, 15)
# 99.71666717529297
#
#
# Removed: (22, 0)
# 99.68083953857422
#
#
# Removed: (22, 1)
# 99.62361145019531
#
#
# Removed: (22, 2)
# 100.02324676513672
#
#
# Removed: (22, 3)
# 100.0439224243164
#
#
# Removed: (22, 4)
# 100.10868835449219
#
#
# Removed: (22, 5)
# 100.6133041381836
#
#
# Removed: (22, 6)
# 100.76860809326172
#
#
# Removed: (22, 7)
# 100.71442413330078
#
#
# Removed: (22, 8)
# 100.02642822265625
#
#
# Removed: (22, 9)
# 100.20832824707031
#
#
# Removed: (22, 10)
# 100.31427764892578
#
#
# Removed: (22, 11)
# 100.41500091552734
#
#
# Removed: (22, 12)
# 100.40040588378906
#
#
# Removed: (22, 13)
# 100.12261962890625
#
#
# Removed: (22, 14)
# 99.4805908203125
#
#
# Removed: (22, 15)
# 99.48418426513672
#
#
# Removed: (21, 0)
# 101.96345520019531
#
#
# Removed: (21, 1)
# 99.27703857421875
#
#
# Removed: (21, 2)
# 99.29947662353516
#
#
# Removed: (21, 4)
# 99.27011108398438
#
#
# Removed: (21, 5)
# 99.22246551513672
#
#
# Removed: (21, 6)
# 99.16128540039062
#
#
# Removed: (21, 7)
# 100.43338775634766
#
#
# Removed: (21, 8)
# 100.44866943359375
#
#
# Removed: (21, 9)
# 100.46929931640625
#
#
# Removed: (21, 10)
# 100.49635314941406
#
#
# Removed: (21, 11)
# 100.43709564208984
#
#
# Removed: (21, 12)
# 100.43443298339844
#
#
# Removed: (21, 13)
# 100.37493133544922
#
#
# Removed: (21, 14)
# 99.56404113769531
#
#
# Removed: (21, 15)
# 99.64482116699219
#
#
# Removed: (20, 0)
# 100.01454162597656
#
#
# Removed: (20, 1)
# 97.77457427978516
#
#
# Removed: (20, 2)
# 98.30096435546875
#
#
# Removed: (20, 3)
# 98.71170806884766
#
#
# Removed: (20, 4)
# 98.30538177490234
#
#
# Removed: (20, 5)
# 97.96269989013672
#
#
# Removed: (20, 6)
# 97.95807647705078
#
#
# Removed: (20, 7)
# 97.28315734863281
#
#
# Removed: (20, 8)
# 97.96076202392578
#
#
# Removed: (20, 9)
# 97.96040344238281
#
#
# Removed: (20, 10)
# 98.05282592773438
#
#
# Removed: (20, 11)
# 98.20467376708984
#
#
# Removed: (20, 12)
# 98.25330352783203
#
#
# Removed: (20, 13)
# 98.18258666992188
#
#
# Removed: (20, 15)
# 98.11217498779297
#
#
# Removed: (19, 0)
# 98.08871459960938
#
#
# Removed: (19, 2)
# 98.32699584960938
#
#
# Removed: (19, 3)
# 98.95692443847656
#
#
# Removed: (19, 4)
# 98.91435241699219
#
#
# Removed: (19, 5)
# 98.92495727539062
#
#
# Removed: (19, 6)
# 98.87297058105469
#
#
# Removed: (19, 7)
# 98.74159240722656
#
#
# Removed: (19, 8)
# 98.61607360839844
#
#
# Removed: (19, 9)
# 98.07608032226562
#
#
# Removed: (19, 10)
# 98.15859985351562
#
#
# Removed: (19, 11)
# 97.676025390625
#
#
# Removed: (19, 12)
# 97.62393188476562
#
#
# Removed: (19, 13)
# 97.34101104736328
#
#
# Removed: (19, 14)
# 97.38666534423828
#
#
# Removed: (19, 15)
# 97.37737274169922
#
#
# Removed: (18, 0)
# 97.36804962158203
#
#
# Removed: (18, 1)
# 97.39154052734375
#
#
# Removed: (18, 2)
# 97.41352844238281
#
#
# Removed: (18, 4)
# 97.60730743408203
#
#
# Removed: (18, 5)
# 97.62168884277344
#
#
# Removed: (18, 6)
# 97.5118637084961
#
#
# Removed: (18, 7)
# 97.38733673095703
#
#
# Removed: (18, 8)
# 97.37399291992188
#
#
# Removed: (18, 12)
# 97.38104248046875
#
#
# Removed: (18, 14)
# 97.4178466796875
#
#
# Removed: (17, 0)
# 97.97975158691406
#
#
# Removed: (17, 1)
# 97.65029907226562
#
#
# Removed: (17, 2)
# 97.57129669189453
#
#
# Removed: (17, 4)
# 98.73626708984375
#
#
# Removed: (17, 5)
# 97.92538452148438
#
#
# Removed: (17, 6)
# 97.8653793334961
#
#
# Removed: (17, 7)
# 98.09969329833984
#
#
# Removed: (17, 8)
# 97.30805206298828
#
#
# Removed: (17, 9)
# 97.48115539550781
#
#
# Removed: (17, 10)
# 97.94770050048828
#
#
# Removed: (17, 11)
# 98.39873504638672
#
#
# Removed: (17, 13)
# 98.08875274658203
#
#
# Removed: (17, 14)
# 98.13459014892578
#
#
# Removed: (17, 15)
# 97.82137298583984
#
#
# Removed: (16, 0)
# 97.64191436767578
#
#
# Removed: (16, 1)
# 99.26659393310547
#
#
# Removed: (16, 2)
# 99.2420883178711
#
#
# Removed: (16, 4)
# 99.26544952392578
#
#
# Removed: (16, 5)
# 99.25426483154297
#
#
# Removed: (16, 6)
# 99.66890716552734
#
#
# Removed: (16, 7)
# 98.95472717285156
#
#
# Removed: (16, 8)
# 98.4884262084961
#
#
# Removed: (16, 9)
# 98.7084732055664
#
#
# Removed: (16, 10)
# 98.7122573852539
#
#
# Removed: (16, 12)
# 98.61023712158203
#
#
# Removed: (16, 13)
# 98.59915161132812
#
#
# Removed: (16, 14)
# 97.3712158203125
#
#
# Removed: (16, 15)
# 98.27669525146484
#
#
# Removed: (15, 0)
# 98.26918029785156
#
#
# Removed: (15, 1)
# 98.6822738647461
#
#
# Removed: (15, 2)
# 98.66283416748047
#
#
# Removed: (15, 3)
# 98.7405014038086
#
#
# Removed: (15, 4)
# 98.78408813476562
#
#
# Removed: (15, 5)
# 98.2452392578125
#
#
# Removed: (15, 6)
# 98.21829986572266
#
#
# Removed: (15, 7)
# 97.19586944580078
#
#
# Removed: (15, 10)
# 97.25151824951172
#
#
# Removed: (15, 11)
# 97.86442565917969
#
#
# Removed: (15, 14)
# 99.21321105957031
#
#
# Removed: (15, 15)
# 99.23004150390625
#
#
# Removed: (14, 0)
# 100.53111267089844
#
#
# Removed: (14, 1)
# 100.52570343017578
#
#
# Removed: (14, 2)
# 100.64778137207031
#
#
# Removed: (14, 3)
# 100.62488555908203
#
#
# Removed: (14, 4)
# 100.48375701904297
#
#
# Removed: (14, 6)
# 100.67626190185547
#
#
# Removed: (14, 7)
# 100.41783142089844
#
#
# Removed: (14, 8)
# 102.0737533569336
#
#
# Removed: (14, 9)
# 102.0160140991211
#
#
# Removed: (14, 10)
# 100.93663024902344
#
#
# Removed: (14, 11)
# 98.89859008789062
#
#
# Removed: (14, 12)
# 98.94625091552734
#
#
# Removed: (14, 13)
# 98.83932495117188
#
#
# Removed: (14, 15)
# 98.03739166259766
#
#
# Removed: (13, 1)
# 99.21083068847656
#
#
# Removed: (13, 2)
# 98.88369750976562
#
#
# Removed: (13, 3)
# 98.07603454589844
#
#
# Removed: (13, 4)
# 98.60224151611328
#
#
# Removed: (13, 5)
# 97.02046203613281
#
#
# Removed: (13, 9)
# 99.77055358886719
#
#
# Removed: (13, 10)
# 99.21941375732422
#
#
# Removed: (13, 11)
# 99.21920013427734
#
#
# Removed: (13, 12)
# 100.46967315673828
#
#
# Removed: (13, 14)
# 99.82745361328125
#
#
# Removed: (13, 15)
# 99.80377960205078
#
#
# Removed: (12, 0)
# 99.2259750366211
#
#
# Removed: (12, 1)
# 99.26081085205078
#
#
# Removed: (12, 2)
# 98.63004302978516
#
#
# Removed: (12, 3)
# 98.56416320800781
#
#
# Removed: (12, 5)
# 98.02584838867188
#
#
# Removed: (12, 6)
# 97.46211242675781
#
#
# Removed: (12, 7)
# 97.06443786621094
#
#
# Removed: (12, 9)
# 98.60112762451172
#
#
# Removed: (12, 10)
# 97.5370864868164
#
#
# Removed: (12, 11)
# 98.98738861083984
#
#
# Removed: (12, 13)
# 98.04090881347656
#
#
# Removed: (12, 14)
# 97.96461486816406
#
#
# Removed: (11, 2)
# 97.98748779296875
#
#
# Removed: (11, 3)
# 97.13948822021484
#
#
# Removed: (11, 8)
# 97.6307601928711
#
#
# Removed: (11, 9)
# 98.9930191040039
#
#
# Removed: (11, 10)
# 98.06665802001953
#
#
# Removed: (11, 11)
# 98.05775451660156
#
#
# Removed: (11, 13)
# 99.52958679199219
#
#
# Removed: (11, 14)
# 99.27987670898438
#
#
# Removed: (11, 15)
# 99.8444595336914
#
#
# Removed: (10, 0)
# 99.66217041015625
#
#
# Removed: (10, 2)
# 98.09426879882812
#
#
# Removed: (10, 4)
# 99.71691131591797
#
#
# Removed: (10, 5)
# 99.70932006835938
#
#
# Removed: (10, 6)
# 99.06983184814453
#
#
# Removed: (10, 7)
# 99.11585998535156
#
#
# Removed: (10, 8)
# 98.44989776611328
#
#
# Removed: (10, 9)
# 99.0234603881836
#
#
# Removed: (10, 10)
# 98.93889617919922
#
#
# Removed: (10, 11)
# 98.42007446289062
#
#
# Removed: (10, 12)
# 97.76346588134766
#
#
# Removed: (10, 13)
# 97.85039520263672
#
#
# Removed: (9, 0)
# 97.37347412109375
#
#
# Removed: (9, 2)
# 97.12863159179688
#
#
# Removed: (9, 6)
# 99.28779602050781
#
#
# Removed: (9, 7)
# 98.35850524902344
#
#
# Removed: (9, 8)
# 98.60492706298828
#
#
# Removed: (9, 10)
# 98.51324462890625
#
#
# Removed: (9, 11)
# 97.59585571289062
#
#
# Removed: (9, 12)
# 97.39024353027344
#
#
# Removed: (9, 13)
# 98.98247528076172
#
#
# Removed: (9, 15)
# 98.14742279052734
#
#
# Removed: (8, 2)
# 98.14599609375
#
#
# Removed: (8, 3)
# 98.7273941040039
#
#
# Removed: (8, 4)
# 98.78955841064453
#
#
# Removed: (8, 5)
# 98.06138610839844
#
#
# Removed: (8, 6)
# 97.20033264160156
#
#
# Removed: (8, 8)
# 97.31031799316406
#
#
# Removed: (8, 11)
# 97.19525146484375
#
#
# Removed: (8, 13)
# 97.28328704833984
#
#
# Removed: (8, 14)
# 104.74803161621094
#
#
# Removed: (8, 15)
# 104.16315460205078
#
#
# Removed: (7, 0)
# 102.8751220703125
#
#
# Removed: (7, 1)
# 101.43223571777344
#
#
# Removed: (7, 2)
# 101.19164276123047
#
#
# Removed: (7, 3)
# 101.19535064697266
#
#
# Removed: (7, 4)
# 100.15574645996094
#
#
# Removed: (7, 5)
# 100.58570861816406
#
#
# Removed: (7, 6)
# 98.05266571044922
#
#
# Removed: (7, 7)
# 98.16967010498047
#
#
# Removed: (7, 8)
# 98.37910461425781
#
#
# Removed: (7, 9)
# 97.9987564086914
#
#
# Removed: (7, 10)
# 97.56476593017578
#
#
# Removed: (7, 11)
# 97.72393798828125
#
#
# Removed: (7, 12)
# 97.53887176513672
#
#
# Removed: (7, 14)
# 97.4739761352539
#
#
# Removed: (6, 2)
# 97.32569885253906
#
#
# Removed: (6, 5)
# 97.68362426757812
#
#
# Removed: (6, 6)
# 97.49678802490234
#
#
# Removed: (6, 7)
# 98.15795135498047
#
#
# Removed: (6, 8)
# 97.3113784790039
#
#
# Removed: (6, 9)
# 97.08976745605469
#
#
# Removed: (6, 13)
# 97.38516235351562
#
#
# Removed: (5, 0)
# 97.41515350341797
#
#
# Removed: (5, 1)
# 97.25494384765625
#
#
# Removed: (5, 2)
# 97.32723999023438
#
#
# Removed: (5, 6)
# 97.36796569824219
#
#
# Removed: (5, 7)
# 97.15302276611328
#
#
# Removed: (5, 9)
# 97.66870880126953
#
#
# Removed: (5, 10)
# 97.54729461669922
#
#
# Removed: (5, 13)
# 98.6276626586914
#
#
# Removed: (5, 14)
# 97.9262924194336
#
#
# Removed: (4, 0)
# 97.80815124511719
#
#
# Removed: (4, 3)
# 97.98512268066406
#
#
# Removed: (4, 4)
# 97.20893859863281
#
#
# Removed: (4, 5)
# 97.03834533691406
#
#
# Removed: (4, 6)
# 97.12496185302734
#
#
# Removed: (4, 7)
# 97.27764129638672
#
#
# Removed: (4, 8)
# 97.78955841064453
#
#
# Removed: (4, 9)
# 97.00992584228516
#
#
# Removed: (4, 10)
# 97.51425170898438
#
#
# Removed: (4, 12)
# 97.43973541259766
#
#
# Removed: (4, 13)
# 97.64042663574219
#
#
# Removed: (4, 14)
# 97.069091796875
#
#
# Removed: (3, 6)
# 97.06297302246094
#
#
# Removed: (3, 7)
# 97.06330108642578
#
#
# Removed: (3, 11)
# 97.04817199707031
#
#
# Removed: (3, 14)
# 97.02117156982422
#
#
# Removed: (2, 0)
# 97.08240509033203
#
#
# Removed: (2, 1)
# 97.03114318847656
#
#
# Removed: (2, 11)
# 97.1425552368164
#
#
# Removed: (2, 13)
# 97.02625274658203
#
#
# Removed: (1, 0)
# 97.09866333007812
#
#
# Removed: (1, 1)
# 97.15576171875
#
#
# Removed: (1, 3)
# 97.150146484375
#
#
# Removed: (1, 4)
# 97.3879623413086
#
#
# Removed: (1, 6)
# 97.40328979492188
#
#
# Removed: (1, 7)
# 97.44847106933594
#
#
# Removed: (1, 8)
# 97.66527557373047
#
#
# Removed: (1, 9)
# 97.55400848388672
#
#
# Removed: (1, 10)
# 97.4004898071289
#
#
# Removed: (1, 12)
# 97.22093963623047
#
#
# Removed: (1, 13)
# 97.25817108154297
#
#
# Removed: (1, 15)
# 97.20648193359375
#
#
# Removed: (0, 0)
# 97.63921356201172
#
#
# Removed: (0, 2)
# 97.32073974609375
#
#
# Removed: (0, 3)
# 97.16927337646484
#
#
# Removed: (0, 5)
# 97.20853424072266
#
#
# Removed: (0, 6)
# 97.4170150756836
#
#
# Removed: (0, 7)
# 97.50605010986328
#
#
# Removed: (0, 11)
# 97.65776824951172
#
#
# Removed: (0, 12)
# 97.96427917480469
#
#
# Removed: (0, 13)
# 97.83130645751953
#
#
# Removed: (0, 14)
# 97.19249725341797

# %%
curr_circuit
# Out:
# [(0, 1),
#  (0, 4),
#  (0, 8),
#  (0, 9),
#  (0, 10),
#  (0, 15),
#  (1, 2),
#  (1, 5),
#  (1, 11),
#  (1, 14),
#  (2, 2),
#  (2, 3),
#  (2, 4),
#  (2, 5),
#  (2, 6),
#  (2, 7),
#  (2, 8),
#  (2, 9),
#  (2, 10),
#  (2, 12),
#  (2, 14),
#  (2, 15),
#  (3, 0),
#  (3, 1),
#  (3, 2),
#  (3, 3),
#  (3, 4),
#  (3, 5),
#  (3, 8),
#  (3, 9),
#  (3, 10),
#  (3, 12),
#  (3, 13),
#  (3, 15),
#  (4, 1),
#  (4, 2),
#  (4, 11),
#  (4, 15),
#  (5, 3),
#  (5, 4),
#  (5, 5),
#  (5, 8),
#  (5, 11),
#  (5, 12),
#  (5, 15),
#  (6, 0),
#  (6, 1),
#  (6, 3),
#  (6, 4),
#  (6, 10),
#  (6, 11),
#  (6, 12),
#  (6, 14),
#  (6, 15),
#  (7, 13),
#  (7, 15),
#  (8, 0),
#  (8, 1),
#  (8, 7),
#  (8, 9),
#  (8, 10),
#  (8, 12),
#  (9, 1),
#  (9, 3),
#  (9, 4),
#  (9, 5),
#  (9, 9),
#  (9, 14),
#  (10, 1),
#  (10, 3),
#  (10, 14),
#  (10, 15),
#  (11, 0),
#  (11, 1),
#  (11, 4),
#  (11, 5),
#  (11, 6),
#  (11, 7),
#  (11, 12),
#  (12, 4),
#  (12, 8),
#  (12, 12),
#  (12, 15),
#  (13, 0),
#  (13, 6),
#  (13, 7),
#  (13, 8),
#  (13, 13),
#  (14, 5),
#  (14, 14),
#  (15, 8),
#  (15, 9),
#  (15, 12),
#  (15, 13),
#  (16, 3),
#  (16, 11),
#  (17, 3),
#  (17, 12),
#  (18, 3),
#  (18, 9),
#  (18, 10),
#  (18, 11),
#  (18, 13),
#  (18, 15),
#  (19, 1),
#  (20, 14),
#  (21, 3)]

# %%
len(curr_circuit)
# Out:
# 107

# %% [markdown]
# 384 total

# %% [markdown]
# ## comapre to 246

# %%
circ_123 = [(0, 9), (1, 2), (1, 11), (1, 14), (2, 3), (2, 4), (2, 5), (2, 7), (2, 9), (2, 10), (2, 14), (3, 0), (3, 3), (3, 4), (3, 9), (3, 13), (3, 15), (4, 6), (4, 7), (4, 8), (4, 9), (4, 13), (5, 5), (5, 11), (5, 12), (5, 13), (6, 12), (6, 15), (7, 2), (8, 10), (9, 5), (10, 1), (10, 4), (10, 14), (11, 1), (11, 3), (11, 4), (11, 5), (11, 6), (12, 15), (13, 13), (14, 5), (14, 14), (15, 7), (15, 10), (17, 12), (19, 1)]
len(circ_123)
# Out:
# 47

# %%
circ_246 =  [(0, 2), (0, 3), (0, 4), (0, 5), (0, 9), (0, 10), (0, 14), (1, 2), (1, 4), (1, 7), (1, 14), (2, 3), (2, 4), (2, 5), (2, 7), (2, 8), (2, 9), (2, 15), (3, 0), (3, 3), (3, 13), (3, 14), (3, 15), (4, 2), (4, 6), (4, 8), (4, 10), (4, 11), (5, 8), (6, 14), (6, 15), (7, 2), (7, 11), (7, 13), (8, 0), (9, 3), (9, 4), (9, 5), (9, 6), (9, 12), (9, 15), (10, 1), (10, 4), (10, 9), (10, 10), (10, 13), (10, 14), (11, 1), (11, 4), (11, 5), (11, 8), (12, 1), (12, 4), (12, 12), (12, 13), (12, 15), (13, 5), (13, 12), (13, 13), (14, 5), (14, 14), (15, 5), (15, 7), (15, 11), (15, 12), (15, 15), (16, 6), (16, 7), (16, 9), (16, 11), (16, 13), (16, 14), (17, 0), (17, 1), (17, 12), (18, 3), (18, 11), (18, 13), (19, 1), (19, 4), (20, 0), (20, 1), (20, 14), (21, 0), (21, 2), (21, 7)]
len(circ_246)
# Out:
# 86

# %%
sorted(list(set(circ_123)-set(circ_246)))
# Out:
# [(1, 11),
#  (2, 10),
#  (2, 14),
#  (3, 4),
#  (3, 9),
#  (4, 7),
#  (4, 9),
#  (4, 13),
#  (5, 5),
#  (5, 11),
#  (5, 12),
#  (5, 13),
#  (6, 12),
#  (8, 10),
#  (11, 3),
#  (11, 6),
#  (15, 10)]

# %%
sorted(list(set(circ_246)-set(circ_123)))
# Out:
# [(0, 2),
#  (0, 3),
#  (0, 4),
#  (0, 5),
#  (0, 10),
#  (0, 14),
#  (1, 4),
#  (1, 7),
#  (2, 8),
#  (2, 15),
#  (3, 14),
#  (4, 2),
#  (4, 10),
#  (4, 11),
#  (5, 8),
#  (6, 14),
#  (7, 11),
#  (7, 13),
#  (8, 0),
#  (9, 3),
#  (9, 4),
#  (9, 6),
#  (9, 12),
#  (9, 15),
#  (10, 9),
#  (10, 10),
#  (10, 13),
#  (11, 8),
#  (12, 1),
#  (12, 4),
#  (12, 12),
#  (12, 13),
#  (13, 5),
#  (13, 12),
#  (15, 5),
#  (15, 11),
#  (15, 12),
#  (15, 15),
#  (16, 6),
#  (16, 7),
#  (16, 9),
#  (16, 11),
#  (16, 13),
#  (16, 14),
#  (17, 0),
#  (17, 1),
#  (18, 3),
#  (18, 11),
#  (18, 13),
#  (19, 4),
#  (20, 0),
#  (20, 1),
#  (20, 14),
#  (21, 0),
#  (21, 2),
#  (21, 7)]

# %% [markdown]
# # manually rmv and check for most impt heads

# %% [markdown]
# https://colab.research.google.com/drive/12HF5UCvMERizkhOiYJKDziahgVq_3KD9#scrollTo=C2EgKgmJS4qb&line=1&uniqifier=1

# %%
# incr_circ = [(0, 10), (0, 11), (1, 2), (1, 6), (1, 7), (1, 8), (1, 9), (1, 14), (2, 4), (2, 5), (2, 6), (2, 7), (2, 9), (2, 10), (2, 15), (3, 4), (3, 5), (3, 10), (3, 11), (3, 12), (3, 13), (3, 15), (4, 1), (4, 2), (4, 3), (4, 13), (5, 0), (5, 1), (5, 4), (5, 5), (5, 8), (5, 11), (5, 13), (5, 15), (6, 0), (6, 4), (6, 5), (6, 10), (6, 11), (6, 12), (6, 13), (6, 14), (6, 15), (7, 4), (7, 6), (7, 15), (8, 0), (8, 10), (8, 12), (9, 14), (9, 15), (10, 3), (10, 14), (10, 15), (11, 0), (11, 1), (11, 2), (11, 3), (11, 4), (11, 5), (11, 6), (11, 7), (12, 8), (12, 15), (13, 0), (13, 13), (14, 5), (14, 11), (14, 14), (15, 5), (15, 7), (15, 12), (15, 13), (16, 8), (16, 11), (16, 14), (16, 15), (17, 3), (18, 13), (19, 12), (20, 1), (20, 7), (20, 14), (21, 0), (21, 1), (21, 7), (21, 14), (22, 8)]
incr_circ = curr_circuit
CIRCUIT, SEQ_POS_TO_KEEP = circuit_from_headsList(incr_circ)
mean_ablate_by_lst(CIRCUIT, SEQ_POS_TO_KEEP, model, orig_score, print_output=True).item()
# Out:
# Average logit difference (circuit / full) %: 97.1925
# 97.19249725341797

# %%
lh_scores = {}
for lh in incr_circ:
    copy_circuit = incr_circ.copy()
    copy_circuit.remove(lh)
    print("removed: " + str(lh))
    CIRCUIT, SEQ_POS_TO_KEEP = circuit_from_headsList(copy_circuit)
    new_score = mean_ablate_by_lst(CIRCUIT, SEQ_POS_TO_KEEP, model, orig_score, print_output=True).item()
    lh_scores[lh] = new_score
# Out:
# removed: (0, 1)
# Average logit difference (circuit / full) %: 96.5166
# removed: (0, 4)
# Average logit difference (circuit / full) %: 96.6474
# removed: (0, 8)
# Average logit difference (circuit / full) %: 96.6877
# removed: (0, 9)
# Average logit difference (circuit / full) %: 95.9630
# removed: (0, 10)
# Average logit difference (circuit / full) %: 96.7188
# removed: (0, 15)
# Average logit difference (circuit / full) %: 96.8809
# removed: (1, 2)
# Average logit difference (circuit / full) %: 96.4395
# removed: (1, 5)
# Average logit difference (circuit / full) %: 96.8441
# removed: (1, 11)
# Average logit difference (circuit / full) %: 95.4817
# removed: (1, 14)
# Average logit difference (circuit / full) %: 92.9865
# removed: (2, 2)
# Average logit difference (circuit / full) %: 96.9801
# removed: (2, 3)
# Average logit difference (circuit / full) %: 96.4369
# removed: (2, 4)
# Average logit difference (circuit / full) %: 94.2528
# removed: (2, 5)
# Average logit difference (circuit / full) %: 96.6296
# removed: (2, 6)
# Average logit difference (circuit / full) %: 97.1382
# removed: (2, 7)
# Average logit difference (circuit / full) %: 96.7586
# removed: (2, 8)
# Average logit difference (circuit / full) %: 96.9116
# removed: (2, 9)
# Average logit difference (circuit / full) %: 96.6490
# removed: (2, 10)
# Average logit difference (circuit / full) %: 95.7784
# removed: (2, 12)
# Average logit difference (circuit / full) %: 96.6988
# removed: (2, 14)
# Average logit difference (circuit / full) %: 96.6003
# removed: (2, 15)
# Average logit difference (circuit / full) %: 96.8756
# removed: (3, 0)
# Average logit difference (circuit / full) %: 94.9289
# removed: (3, 1)
# Average logit difference (circuit / full) %: 96.9943
# removed: (3, 2)
# Average logit difference (circuit / full) %: 96.7358
# removed: (3, 3)
# Average logit difference (circuit / full) %: 93.6497
# removed: (3, 4)
# Average logit difference (circuit / full) %: 96.9554
# removed: (3, 5)
# Average logit difference (circuit / full) %: 96.5864
# removed: (3, 8)
# Average logit difference (circuit / full) %: 96.6374
# removed: (3, 9)
# Average logit difference (circuit / full) %: 96.5761
# removed: (3, 10)
# Average logit difference (circuit / full) %: 96.4725
# removed: (3, 12)
# Average logit difference (circuit / full) %: 97.0716
# removed: (3, 13)
# Average logit difference (circuit / full) %: 94.6767
# removed: (3, 15)
# Average logit difference (circuit / full) %: 96.2237
# removed: (4, 1)
# Average logit difference (circuit / full) %: 94.4014
# removed: (4, 2)
# Average logit difference (circuit / full) %: 95.5768
# removed: (4, 11)
# Average logit difference (circuit / full) %: 96.4053
# removed: (4, 15)
# Average logit difference (circuit / full) %: 96.4384
# removed: (5, 3)
# Average logit difference (circuit / full) %: 96.7545
# removed: (5, 4)
# Average logit difference (circuit / full) %: 96.6500
# removed: (5, 5)
# Average logit difference (circuit / full) %: 96.6199
# removed: (5, 8)
# Average logit difference (circuit / full) %: 93.0581
# removed: (5, 11)
# Average logit difference (circuit / full) %: 93.5719
# removed: (5, 12)
# Average logit difference (circuit / full) %: 93.0680
# removed: (5, 15)
# Average logit difference (circuit / full) %: 95.9616
# removed: (6, 0)
# Average logit difference (circuit / full) %: 96.4486
# removed: (6, 1)
# Average logit difference (circuit / full) %: 90.6220
# removed: (6, 3)
# Average logit difference (circuit / full) %: 96.9115
# removed: (6, 4)
# Average logit difference (circuit / full) %: 96.0841
# removed: (6, 10)
# Average logit difference (circuit / full) %: 96.1284
# removed: (6, 11)
# Average logit difference (circuit / full) %: 95.6964
# removed: (6, 12)
# Average logit difference (circuit / full) %: 90.7571
# removed: (6, 14)
# Average logit difference (circuit / full) %: 95.8370
# removed: (6, 15)
# Average logit difference (circuit / full) %: 88.9444
# removed: (7, 13)
# Average logit difference (circuit / full) %: 94.2538
# removed: (7, 15)
# Average logit difference (circuit / full) %: 88.9310
# removed: (8, 0)
# Average logit difference (circuit / full) %: 95.3265
# removed: (8, 1)
# Average logit difference (circuit / full) %: 96.5960
# removed: (8, 7)
# Average logit difference (circuit / full) %: 96.0226
# removed: (8, 9)
# Average logit difference (circuit / full) %: 93.9231
# removed: (8, 10)
# Average logit difference (circuit / full) %: 51.3129
# removed: (8, 12)
# Average logit difference (circuit / full) %: 94.0531
# removed: (9, 1)
# Average logit difference (circuit / full) %: 95.8714
# removed: (9, 3)
# Average logit difference (circuit / full) %: 97.1118
# removed: (9, 4)
# Average logit difference (circuit / full) %: 95.1985
# removed: (9, 5)
# Average logit difference (circuit / full) %: 96.7427
# removed: (9, 9)
# Average logit difference (circuit / full) %: 95.8530
# removed: (9, 14)
# Average logit difference (circuit / full) %: 94.8331
# removed: (10, 1)
# Average logit difference (circuit / full) %: 94.7019
# removed: (10, 3)
# Average logit difference (circuit / full) %: 88.2724
# removed: (10, 14)
# Average logit difference (circuit / full) %: 85.2323
# removed: (10, 15)
# Average logit difference (circuit / full) %: 95.2535
# removed: (11, 0)
# Average logit difference (circuit / full) %: 96.1188
# removed: (11, 1)
# Average logit difference (circuit / full) %: 92.6268
# removed: (11, 4)
# Average logit difference (circuit / full) %: 75.9998
# removed: (11, 5)
# Average logit difference (circuit / full) %: 94.5951
# removed: (11, 6)
# Average logit difference (circuit / full) %: 94.2373
# removed: (11, 7)
# Average logit difference (circuit / full) %: 95.6068
# removed: (11, 12)
# Average logit difference (circuit / full) %: 95.7937
# removed: (12, 4)
# Average logit difference (circuit / full) %: 96.0435
# removed: (12, 8)
# Average logit difference (circuit / full) %: 94.6405
# removed: (12, 12)
# Average logit difference (circuit / full) %: 95.4294
# removed: (12, 15)
# Average logit difference (circuit / full) %: 96.3481
# removed: (13, 0)
# Average logit difference (circuit / full) %: 94.7421
# removed: (13, 6)
# Average logit difference (circuit / full) %: 97.1514
# removed: (13, 7)
# Average logit difference (circuit / full) %: 96.8961
# removed: (13, 8)
# Average logit difference (circuit / full) %: 95.7603
# removed: (13, 13)
# Average logit difference (circuit / full) %: 92.2644
# removed: (14, 5)
# Average logit difference (circuit / full) %: 92.8637
# removed: (14, 14)
# Average logit difference (circuit / full) %: 74.3808
# removed: (15, 8)
# Average logit difference (circuit / full) %: 96.9529
# removed: (15, 9)
# Average logit difference (circuit / full) %: 97.1191
# removed: (15, 12)
# Average logit difference (circuit / full) %: 92.7746
# removed: (15, 13)
# Average logit difference (circuit / full) %: 94.6426
# removed: (16, 3)
# Average logit difference (circuit / full) %: 95.4002
# removed: (16, 11)
# Average logit difference (circuit / full) %: 93.2694
# removed: (17, 3)
# Average logit difference (circuit / full) %: 95.6295
# removed: (17, 12)
# Average logit difference (circuit / full) %: 96.2137
# removed: (18, 3)
# Average logit difference (circuit / full) %: 94.5032
# removed: (18, 9)
# Average logit difference (circuit / full) %: 96.7744
# removed: (18, 10)
# Average logit difference (circuit / full) %: 97.0572
# removed: (18, 11)
# Average logit difference (circuit / full) %: 96.3699
# removed: (18, 13)
# Average logit difference (circuit / full) %: 95.8157
# removed: (18, 15)
# Average logit difference (circuit / full) %: 95.9171
# removed: (19, 1)
# Average logit difference (circuit / full) %: 95.0879
# removed: (20, 14)
# Average logit difference (circuit / full) %: 92.7155
# removed: (21, 3)
# Average logit difference (circuit / full) %: 96.3370

# %%
lh_scores
# Out:
# {(0, 1): 96.5166244506836,
#  (0, 4): 96.64743041992188,
#  (0, 8): 96.68769073486328,
#  (0, 9): 95.96304321289062,
#  (0, 10): 96.71881103515625,
#  (0, 15): 96.88088989257812,
#  (1, 2): 96.43949890136719,
#  (1, 5): 96.84407806396484,
#  (1, 11): 95.48165130615234,
#  (1, 14): 92.98648071289062,
#  (2, 2): 96.98013305664062,
#  (2, 3): 96.43694305419922,
#  (2, 4): 94.2528076171875,
#  (2, 5): 96.62957000732422,
#  (2, 6): 97.13822174072266,
#  (2, 7): 96.7586441040039,
#  (2, 8): 96.91163635253906,
#  (2, 9): 96.64895629882812,
#  (2, 10): 95.77836608886719,
#  (2, 12): 96.69879150390625,
#  (2, 14): 96.60031127929688,
#  (2, 15): 96.87557220458984,
#  (3, 0): 94.92894744873047,
#  (3, 1): 96.99434661865234,
#  (3, 2): 96.73584747314453,
#  (3, 3): 93.64968872070312,
#  (3, 4): 96.95536804199219,
#  (3, 5): 96.58637237548828,
#  (3, 8): 96.63741302490234,
#  (3, 9): 96.57608795166016,
#  (3, 10): 96.47249603271484,
#  (3, 12): 97.07164764404297,
#  (3, 13): 94.6766586303711,
#  (3, 15): 96.22369384765625,
#  (4, 1): 94.40135955810547,
#  (4, 2): 95.57675170898438,
#  (4, 11): 96.40526580810547,
#  (4, 15): 96.43838500976562,
#  (5, 3): 96.7545394897461,
#  (5, 4): 96.65001678466797,
#  (5, 5): 96.61988830566406,
#  (5, 8): 93.05807495117188,
#  (5, 11): 93.57185363769531,
#  (5, 12): 93.06798553466797,
#  (5, 15): 95.9616470336914,
#  (6, 0): 96.4486312866211,
#  (6, 1): 90.62203216552734,
#  (6, 3): 96.9114761352539,
#  (6, 4): 96.08411407470703,
#  (6, 10): 96.12837982177734,
#  (6, 11): 95.6963882446289,
#  (6, 12): 90.757080078125,
#  (6, 14): 95.83704376220703,
#  (6, 15): 88.94437408447266,
#  (7, 13): 94.25381469726562,
#  (7, 15): 88.93096923828125,
#  (8, 0): 95.3265151977539,
#  (8, 1): 96.59603881835938,
#  (8, 7): 96.02256774902344,
#  (8, 9): 93.92313385009766,
#  (8, 10): 51.31289291381836,
#  (8, 12): 94.05313873291016,
#  (9, 1): 95.8713607788086,
#  (9, 3): 97.11180877685547,
#  (9, 4): 95.1985092163086,
#  (9, 5): 96.74274444580078,
#  (9, 9): 95.85297393798828,
#  (9, 14): 94.83311462402344,
#  (10, 1): 94.70188903808594,
#  (10, 3): 88.27239227294922,
#  (10, 14): 85.2322769165039,
#  (10, 15): 95.25350189208984,
#  (11, 0): 96.11883544921875,
#  (11, 1): 92.62682342529297,
#  (11, 4): 75.99982452392578,
#  (11, 5): 94.5951156616211,
#  (11, 6): 94.2373275756836,
#  (11, 7): 95.6068115234375,
#  (11, 12): 95.79373168945312,
#  (12, 4): 96.04347229003906,
#  (12, 8): 94.64053344726562,
#  (12, 12): 95.42942810058594,
#  (12, 15): 96.34806823730469,
#  (13, 0): 94.7420883178711,
#  (13, 6): 97.15137481689453,
#  (13, 7): 96.89610290527344,
#  (13, 8): 95.76033782958984,
#  (13, 13): 92.2644271850586,
#  (14, 5): 92.86366271972656,
#  (14, 14): 74.38078308105469,
#  (15, 8): 96.952880859375,
#  (15, 9): 97.11912536621094,
#  (15, 12): 92.7745590209961,
#  (15, 13): 94.64264678955078,
#  (16, 3): 95.40022277832031,
#  (16, 11): 93.26941680908203,
#  (17, 3): 95.62952423095703,
#  (17, 12): 96.21372985839844,
#  (18, 3): 94.50316619873047,
#  (18, 9): 96.77438354492188,
#  (18, 10): 97.05721282958984,
#  (18, 11): 96.3698501586914,
#  (18, 13): 95.81568908691406,
#  (18, 15): 95.91708374023438,
#  (19, 1): 95.08789825439453,
#  (20, 14): 92.7154541015625,
#  (21, 3): 96.33704376220703}

# %%
dict(sorted(lh_scores.items(), key=lambda item: item[1]))
# Out:
# {(8, 10): 51.31289291381836,
#  (14, 14): 74.38078308105469,
#  (11, 4): 75.99982452392578,
#  (10, 14): 85.2322769165039,
#  (10, 3): 88.27239227294922,
#  (7, 15): 88.93096923828125,
#  (6, 15): 88.94437408447266,
#  (6, 1): 90.62203216552734,
#  (6, 12): 90.757080078125,
#  (13, 13): 92.2644271850586,
#  (11, 1): 92.62682342529297,
#  (20, 14): 92.7154541015625,
#  (15, 12): 92.7745590209961,
#  (14, 5): 92.86366271972656,
#  (1, 14): 92.98648071289062,
#  (5, 8): 93.05807495117188,
#  (5, 12): 93.06798553466797,
#  (16, 11): 93.26941680908203,
#  (5, 11): 93.57185363769531,
#  (3, 3): 93.64968872070312,
#  (8, 9): 93.92313385009766,
#  (8, 12): 94.05313873291016,
#  (11, 6): 94.2373275756836,
#  (2, 4): 94.2528076171875,
#  (7, 13): 94.25381469726562,
#  (4, 1): 94.40135955810547,
#  (18, 3): 94.50316619873047,
#  (11, 5): 94.5951156616211,
#  (12, 8): 94.64053344726562,
#  (15, 13): 94.64264678955078,
#  (3, 13): 94.6766586303711,
#  (10, 1): 94.70188903808594,
#  (13, 0): 94.7420883178711,
#  (9, 14): 94.83311462402344,
#  (3, 0): 94.92894744873047,
#  (19, 1): 95.08789825439453,
#  (9, 4): 95.1985092163086,
#  (10, 15): 95.25350189208984,
#  (8, 0): 95.3265151977539,
#  (16, 3): 95.40022277832031,
#  (12, 12): 95.42942810058594,
#  (1, 11): 95.48165130615234,
#  (4, 2): 95.57675170898438,
#  (11, 7): 95.6068115234375,
#  (17, 3): 95.62952423095703,
#  (6, 11): 95.6963882446289,
#  (13, 8): 95.76033782958984,
#  (2, 10): 95.77836608886719,
#  (11, 12): 95.79373168945312,
#  (18, 13): 95.81568908691406,
#  (6, 14): 95.83704376220703,
#  (9, 9): 95.85297393798828,
#  (9, 1): 95.8713607788086,
#  (18, 15): 95.91708374023438,
#  (5, 15): 95.9616470336914,
#  (0, 9): 95.96304321289062,
#  (8, 7): 96.02256774902344,
#  (12, 4): 96.04347229003906,
#  (6, 4): 96.08411407470703,
#  (11, 0): 96.11883544921875,
#  (6, 10): 96.12837982177734,
#  (17, 12): 96.21372985839844,
#  (3, 15): 96.22369384765625,
#  (21, 3): 96.33704376220703,
#  (12, 15): 96.34806823730469,
#  (18, 11): 96.3698501586914,
#  (4, 11): 96.40526580810547,
#  (2, 3): 96.43694305419922,
#  (4, 15): 96.43838500976562,
#  (1, 2): 96.43949890136719,
#  (6, 0): 96.4486312866211,
#  (3, 10): 96.47249603271484,
#  (0, 1): 96.5166244506836,
#  (3, 9): 96.57608795166016,
#  (3, 5): 96.58637237548828,
#  (8, 1): 96.59603881835938,
#  (2, 14): 96.60031127929688,
#  (5, 5): 96.61988830566406,
#  (2, 5): 96.62957000732422,
#  (3, 8): 96.63741302490234,
#  (0, 4): 96.64743041992188,
#  (2, 9): 96.64895629882812,
#  (5, 4): 96.65001678466797,
#  (0, 8): 96.68769073486328,
#  (2, 12): 96.69879150390625,
#  (0, 10): 96.71881103515625,
#  (3, 2): 96.73584747314453,
#  (9, 5): 96.74274444580078,
#  (5, 3): 96.7545394897461,
#  (2, 7): 96.7586441040039,
#  (18, 9): 96.77438354492188,
#  (1, 5): 96.84407806396484,
#  (2, 15): 96.87557220458984,
#  (0, 15): 96.88088989257812,
#  (13, 7): 96.89610290527344,
#  (6, 3): 96.9114761352539,
#  (2, 8): 96.91163635253906,
#  (15, 8): 96.952880859375,
#  (3, 4): 96.95536804199219,
#  (2, 2): 96.98013305664062,
#  (3, 1): 96.99434661865234,
#  (18, 10): 97.05721282958984,
#  (3, 12): 97.07164764404297,
#  (9, 3): 97.11180877685547,
#  (15, 9): 97.11912536621094,
#  (2, 6): 97.13822174072266,
#  (13, 6): 97.15137481689453}
