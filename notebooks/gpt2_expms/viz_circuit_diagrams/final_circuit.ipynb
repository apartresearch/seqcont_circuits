# %%
import pickle

# %% [markdown]
# Now upload files manually via sidebar

# %% [markdown]
# ## load data

# %%
task = 'numerals'

numerals_adjlists = {}

with open(task + "_head_to_head_adjList.pkl", "rb") as file:
#     numerals_head_to_head_adjList = pickle.load(file)
    numerals_adjlists['head_to_head_adjList']  = pickle.load(file)

with open(task + "_mlp_to_mlp_adjList.pkl", "rb") as file:
#     numerals_mlp_to_mlp_adjList = pickle.load(file)
    numerals_adjlists['mlp_to_mlp_adjList']  = pickle.load(file)

with open(task + "_head_to_mlp_adjList.pkl", "rb") as file:
#     numerals_head_to_mlp_adjList = pickle.load(file)
    numerals_adjlists['head_to_mlp_adjList']  = pickle.load(file)

with open(task + "_mlp_to_head_adjList.pkl", "rb") as file:
#     numerals_mlp_to_head_adjList = pickle.load(file)
    numerals_adjlists['mlp_to_head_adjList']  = pickle.load(file)

with open(task + "_heads_to_resid.pkl", "rb") as file:
#     numerals_heads_to_resid = pickle.load(file)
    numerals_adjlists['heads_to_resid']  = pickle.load(file)

with open(task + "_mlps_to_resid.pkl", "rb") as file:
#     numerals_mlps_to_resid = pickle.load(file)
    numerals_adjlists['mlps_to_resid']  = pickle.load(file)

# %%
task = 'numwords'

numwords_adjlists = {}

with open(task + "_head_to_head_adjList.pkl", "rb") as file:
#     numwords_head_to_head_adjList = pickle.load(file)
    numwords_adjlists['head_to_head_adjList']  = pickle.load(file)

with open(task + "_mlp_to_mlp_adjList.pkl", "rb") as file:
#     numwords_mlp_to_mlp_adjList = pickle.load(file)
    numwords_adjlists['mlp_to_mlp_adjList']  = pickle.load(file)

with open(task + "_head_to_mlp_adjList.pkl", "rb") as file:
#     numwords_head_to_mlp_adjList = pickle.load(file)
    numwords_adjlists['head_to_mlp_adjList']  = pickle.load(file)

with open(task + "_mlp_to_head_adjList.pkl", "rb") as file:
#     numwords_mlp_to_head_adjList = pickle.load(file)
    numwords_adjlists['mlp_to_head_adjList']  = pickle.load(file)

with open(task + "_heads_to_resid.pkl", "rb") as file:
#     numwords_heads_to_resid = pickle.load(file)
    numwords_adjlists['heads_to_resid']  = pickle.load(file)

with open(task + "_mlps_to_resid.pkl", "rb") as file:
#     numwords_mlps_to_resid = pickle.load(file)
    numwords_adjlists['mlps_to_resid']  = pickle.load(file)

# %%
task = 'months'

months_adjlists = {}

with open(task + "_head_to_head_adjList.pkl", "rb") as file:
#     months_head_to_head_adjList = pickle.load(file)
    months_adjlists['head_to_head_adjList']  = pickle.load(file)

with open(task + "_mlp_to_mlp_adjList.pkl", "rb") as file:
#     months_mlp_to_mlp_adjList = pickle.load(file)
    months_adjlists['mlp_to_mlp_adjList']  = pickle.load(file)

with open(task + "_head_to_mlp_adjList.pkl", "rb") as file:
#     months_head_to_mlp_adjList = pickle.load(file)
    months_adjlists['head_to_mlp_adjList']  = pickle.load(file)

with open(task + "_mlp_to_head_adjList.pkl", "rb") as file:
#     months_mlp_to_head_adjList = pickle.load(file)
    months_adjlists['mlp_to_head_adjList']  = pickle.load(file)

with open(task + "_heads_to_resid.pkl", "rb") as file:
#     months_heads_to_resid = pickle.load(file)
    months_adjlists['heads_to_resid']  = pickle.load(file)

with open(task + "_mlps_to_resid.pkl", "rb") as file:
#     months_mlps_to_resid = pickle.load(file)
    months_adjlists['mlps_to_resid']  = pickle.load(file)

# %% [markdown]
# # fix empty dict

# %% [markdown]
# only do this once, then save and overwrite. needs gpu

# %%
# numerals_adjlists['mlp_to_mlp_adjList']  # {}

# %%
# with open("numerals_mlp_to_mlp_results.pkl", "rb") as file:
#     res = pickle.load(file)

# %%
# res
# Out:
# {11: tensor([0.5660, 0.6314, 0.6963, 0.7543, 0.6346, 0.0000, 0.7312, 0.7397, 0.6478,
#          0.7073, 0.7423], device='cuda:0'),
#  10: tensor([0.4146, 0.6155, 0.6942, 0.7460, 0.6355, 0.0000, 0.7336, 0.7194, 0.6042,
#          0.6255], device='cuda:0'),
#  9: tensor([0.2158, 0.5803, 0.6774, 0.7250, 0.6462, 0.0000, 0.7323, 0.7303, 0.5779],
#         device='cuda:0'),
#  8: tensor([0.3926, 0.7558, 0.7769, 0.7710, 0.7512, 0.0000, 0.7744, 0.7593],
#         device='cuda:0'),
#  7: tensor([0.6675, 0.8077, 0.8160, 0.8237, 0.8088, 0.0000, 0.7997],
#         device='cuda:0'),
#  6: tensor([0.6383, 0.7722, 0.8046, 0.8212, 0.8136, 0.0000], device='cuda:0'),
#  4: tensor([0.4749, 0.7105, 0.7358, 0.7608], device='cuda:0'),
#  3: tensor([0.6625, 0.7900, 0.7806], device='cuda:0'),
#  2: tensor([0.5751, 0.7726], device='cuda:0'),
#  1: tensor([0.4907], device='cuda:0'),
#  0: tensor([], device='cuda:0')}

# %%
# mlp_to_mlp_adjList = {}
# mlps_not_ablate = [0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11]
# for mlp in mlps_not_ablate:
#     result = res[mlp]
#     filtered_indices = (result < 0.80) & (result != 0.0)
#     filtered_indices = filtered_indices.nonzero(as_tuple=True)[0]
#     mlp_to_mlp_adjList[mlp] = filtered_indices.tolist()

# %%
# mlp_to_mlp_adjList
# Out:
# {0: [],
#  1: [0],
#  2: [0, 1],
#  3: [0, 1, 2],
#  4: [0, 1, 2, 3],
#  6: [0, 1],
#  7: [0, 6],
#  8: [0, 1, 2, 3, 4, 6, 7],
#  9: [0, 1, 2, 3, 4, 6, 7, 8],
#  10: [0, 1, 2, 3, 4, 6, 7, 8, 9],
#  11: [0, 1, 2, 3, 4, 6, 7, 8, 9, 10]}

# %%
# from google.colab import files
# with open("# numerals_mlp_to_mlp_adjList.pkl", "wb") as file:
#     pickle.dump(mlp_to_mlp_adjList, file)
# files.download("# numerals_mlp_to_mlp_adjList.pkl")

# %%
# numerals_adjlists['mlp_to_mlp_adjList']  = mlp_to_mlp_adjList

# %% [markdown]
# # run

# %% [markdown]
# Call get_overlap for every adj_list

# %%
import pdb

# %%
def get_node_name(end_node):
    if isinstance(end_node, int):
        receiver_name = "MLP " + str(end_node)
    elif isinstance(end_node, tuple):
        receiver_name = f"{end_node[0]} , {end_node[1]}"
    else:
        receiver_name = 'resid_post'
    return receiver_name

# %%
from graphviz import Digraph, Source
from IPython.display import display
from google.colab import files
import pdb

def get_overlap(dot, head_adjList_1, head_adjList_2, head_adjList_3, nodes_in_graph):
    # dot = Digraph()
    # dot.attr(ranksep='0.45', nodesep='0.12')  # Adjust the rankdir, ranksep, and nodesep (defaults 0.75, 0.25)

    if 'resid' in head_adjList_1.keys():
        set1 = set(list(head_adjList_1['resid']))
        set2 = set(list(head_adjList_2['resid']))
        set3 = set(list(head_adjList_3['resid']))
    else:
        set1 = set(list(head_adjList_1.keys()))
        set2 = set(list(head_adjList_2.keys()))
        set3 = set(list(head_adjList_3.keys()))


    # pdb.set_trace()
    if isinstance(list(head_adjList_1.keys())[0], tuple):
        set1 = {(a, b) for a, b, _ in set1}
        set2 = {(a, b) for a, b, _ in set2}
        set3 = {(a, b) for a, b, _ in set3}

    set1 = set( list(set1) + [item for sublist in head_adjList_1.values() for item in sublist] )
    set2 = set( list(set2) + [item for sublist in head_adjList_2.values() for item in sublist] )
    set3 = set( list(set3) + [item for sublist in head_adjList_3.values() for item in sublist] )

    setX = set1.union(set2, set3)
    # print(setX)

    impt_nodes = [(0,1), (1,5), (4,4), (7,11), (9,1), 9]

    # dot.node('MLP 1', fontsize='20', width='1.1', height='0.6', fontname='Arial bold')
    # prevent overriding previous overlap colors
    # nodes_in_graph = [] # set this outside fn

    color_dict = {}
    for end_node in setX:
        if end_node in nodes_in_graph:
            continue
        else:
            nodes_in_graph.append(end_node)

        in_set1 = end_node in set1
        in_set2 = end_node in set2
        in_set3 = end_node in set3

        # node_name = f"{end_node[0]} , {end_node[1]}" # Change to x.y format
        node_name = get_node_name(end_node)

        # if end_node == 1:
        #     pdb.set_trace()

        if in_set1 and not in_set2 and not in_set3:
            dot.node(node_name, color="black", fillcolor="#ffcccb", style='filled',
                     fontsize='20', width='1.1', height='0.6', fontname='Arial bold') #light red
        elif not in_set1 and in_set2 and not in_set3:
            dot.node(node_name, color="black", fillcolor="#ADD8E6", style='filled',
                     fontsize='20', width='1.1', height='0.6', fontname='Arial bold') #light blue
        elif not in_set1 and not in_set2 and in_set3:
            dot.node(node_name, color="black", fillcolor="#FDDC5C", style='filled',
                     fontsize='20', width='1.1', height='0.6', fontname='Arial bold') #light gold
        elif in_set1 and in_set2 and not in_set3:
            # if end_node == 1:
            #     pdb.set_trace()
            dot.node(node_name, color="black", fillcolor="#D8BFD8", style='filled',
                     fontsize='20', width='1.1', height='0.6', fontname='Arial bold') #"#E6E6FA" #light purple
        elif not in_set1 and in_set2 and in_set3:
            dot.node(node_name, color="black", fillcolor="#90EE90", style='filled',
                     fontsize='20', width='1.1', height='0.6', fontname='Arial bold') #light green
        elif in_set1 and not in_set2 and in_set3:
            dot.node(node_name, color="black", fillcolor="#FFD580", style='filled',
                     fontsize='20', width='1.1', height='0.6', fontname='Arial bold')  #light orange
        elif in_set1 and in_set2 and in_set3:
            if end_node in impt_nodes:
                dot.node(node_name, color="black", fillcolor="#EDEDF2", style='filled',
                         penwidth='3', fontsize='20', width='1.1', height='0.6', fontname='Arial bold')
            else:
                dot.node(node_name, fontsize='20', width='1.1', height='0.6', fontname='Arial bold')

    dot.node('resid_post', fontsize='20', width='1.1', height='0.6', fontname='Arial bold')

    adjList_1_edges = []
    adjList_2_edges = []
    adjList_3_edges = []

    # First, populate the edge lists from all adjacency lists
    for end_node, start_nodes_list in head_adjList_1.items():
        for start_node in start_nodes_list:
            adjList_1_edges.append((start_node, end_node))

    for end_node, start_nodes_list in head_adjList_2.items():
        for start_node in start_nodes_list:
            adjList_2_edges.append((start_node, end_node))

    for end_node, start_nodes_list in head_adjList_3.items():
        for start_node in start_nodes_list:
            adjList_3_edges.append((start_node, end_node))

    # Now, iterate over the union of all edges and draw them according to the rules
    all_edges = set(adjList_1_edges).union(set(adjList_2_edges), set(adjList_3_edges))

    edges_added = []  # nodes are not unique to adjlist but eddges are so this can be local
    for edge in all_edges:
        start_node, end_node = edge
        # start_name = f"{start_node[0]} , {start_node[1]}"
        # end_name = f"{end_node[0]} , {end_node[1]}"
        start_name = get_node_name(start_node)
        end_name = get_node_name(end_node)

        # what = f"9 , 7"
        # if start_name == what or end_name == what:
        #     pdb.set_trace()

        if (start_name, end_name) in edges_added:
            continue

        edges_added.append((start_name, end_name))

        # if start_name == "4 , 4" and end_name == "7 , 11":
        #     continue
        if start_name == "4 , 4" and end_name == "7 , 11":
            dot.edge(str(f"{4} , {4}"), str(f"{7} , {11}"), color='black', penwidth='4.5')
            continue
        if start_name == "4 , 4" and end_name == "9 , 1":
            dot.edge(str(f"{4} , {4}"), str(f"{9} , {1}"), color='black', penwidth='4.5')
            continue
        if start_name == "1 , 5" and end_name == "7 , 11":
            dot.edge(str(f"{1} , {5}"), str(f"{7} , {11}"), color='purple', penwidth='4.5')
            continue
        if start_name == "1 , 5" and end_name == "9 , 1":
            dot.edge(str(f"{1} , {5}"), str(f"{9} , {1}"), color='purple', penwidth='4.5')
            continue
        if start_name == "7 , 11" and end_name == "9 , 1":
            dot.edge(str(f"{7} , {11}"), str(f"{9} , {1}"), color='black', penwidth='4.5')
            continue

        # Edge in all three lists (1, 2, 3)
        if edge in adjList_1_edges and edge in adjList_2_edges and edge in adjList_3_edges:
            dot.edge(str(start_name), str(end_name), color='black', penwidth='2.5') # Bolder gray 707070 # 4.0

        # Edge in lists 1 and 2, but not in 3 (Your new requirement)
        elif edge in adjList_1_edges and edge in adjList_2_edges and edge not in adjList_3_edges:
            dot.edge(str(start_name), str(end_name), color='purple', penwidth='2.75')

        # Edge in lists 1 and 3, but not in 2
        elif edge in adjList_1_edges and edge not in adjList_2_edges and edge in adjList_3_edges:
            dot.edge(str(start_name), str(end_name), color='orange', penwidth='3')

        # Edge in lists 2 and 3, but not in 1
        elif edge not in adjList_1_edges and edge in adjList_2_edges and edge in adjList_3_edges:
            dot.edge(str(start_name), str(end_name), color='lightgreen', penwidth='3')

        # Edge only in list 1
        elif edge in adjList_1_edges and edge not in adjList_2_edges and edge not in adjList_3_edges:
            dot.edge(str(start_name), str(end_name), color='red', penwidth='2.5')

        # Edge only in list 2
        elif edge not in adjList_1_edges and edge in adjList_2_edges and edge not in adjList_3_edges:
            dot.edge(str(start_name), str(end_name), color='blue', penwidth='2.5')

        # Edge only in list 3
        elif edge not in adjList_1_edges and edge not in adjList_2_edges and edge in adjList_3_edges:
            dot.edge(str(start_name), str(end_name), color='#D4AF37', penwidth='2.5')  # Bolder gold
    return nodes_in_graph

# %%
def plot_graph_adjacency(numerals_adjlists, numwords_adjlists, months_adjlists,
                             filename="circuit_graph", highlighted_nodes=None):
    dot = Digraph()
    # dot.attr(ranksep='0.45', nodesep='0.11')  # vert height- ranksep, nodesep- w
    dot.attr(ranksep='0.45', nodesep='0.105')  # vert height- ranksep, nodesep- w

    edges_added = [] # global var so no need pass in
    def loop_adjList(adjList):
        for end_node, start_nodes_list in adjList.items():
            receiver_name = get_node_name(end_node)
            for start in start_nodes_list:
                sender_name = get_node_name(start)
                dot.node(sender_name, color="#ffcccb", style='filled')
                dot.node(receiver_name, color="#ffcccb", style='filled')
                if (sender_name, receiver_name) not in edges_added:
                    dot.edge(sender_name, receiver_name, color = 'red')
                    edges_added.append((sender_name, receiver_name))

    edge_type_list = ['head_to_head_adjList', 'mlp_to_mlp_adjList', 'head_to_mlp_adjList',  'mlp_to_head_adjList', 'heads_to_resid', 'mlps_to_resid']

    nodes_in_graph = []
    for edge_type in edge_type_list:
        adjL_1 = numerals_adjlists[edge_type]
        adjL_2 = numwords_adjlists[edge_type]
        adjL_3 = months_adjlists[edge_type]
        nodes_in_graph = get_overlap(dot, adjL_1, adjL_2, adjL_3, nodes_in_graph)
        # loop_adjList(adjL_1)

    # dot.edge(str(f"{4} , {4}"), str(f"{7} , {11}"), color='black', penwidth='4')

    # # Display the graph in Colab
    # display(Source(dot.source))

    dot.format = 'pdf'  # You can change this to 'pdf', 'png', etc. based on your needs
    # dot.format = 'png'  # You can change this to 'pdf', 'svg', etc. based on your needs
    dot.render(filename)
    files.download(filename + ".pdf")
    # files.download(filename + ".png")

# %%
plot_graph_adjacency(numerals_adjlists, numwords_adjlists, months_adjlists, filename="all_no_qkv_circ")

# %% [markdown]
# # qkv m

# %%
from graphviz import Digraph, Source
from IPython.display import display
from google.colab import files

# head_to_head_adjList, mlp_to_mlp_adjList, head_to_mlp_adjList, mlp_to_head_adjList, heads_to_resid, mlps_to_resid,
def plot_graph_adjacency_qkv(adjLists,
                             filename="circuit_graph", highlighted_nodes=None):
    dot = Digraph()
    dot.attr(ranksep='0.45', nodesep='0.11')  # vert height- ranksep, nodesep- w

    dot.node('resid_post', color="black", fillcolor="#FDDC5C", style='filled',
                         penwidth='3', fontsize='20', width='1.1', height='0.6', fontname='Arial bold')

    for node in adjLists['mlp_to_mlp_adjList'].keys():
        sender_name = "MLP " + str(node)
        dot.node(sender_name, color="black", fillcolor="#FDDC5C", style='filled',
                         penwidth='3', fontsize='20', width='1.1', height='0.6', fontname='Arial bold')

    for node in adjLists['head_to_head_adjList'].keys():
        sender_name = f"{node[0]} , {node[1]} {node[2]}"
        dot.node(sender_name, color="black", fillcolor="#FDDC5C", style='filled',
                         penwidth='3', fontsize='20', width='1.1', height='0.6', fontname='Arial bold')
        sender_name = f"{node[0]} , {node[1]}"
        dot.node(sender_name, color="black", fillcolor="#FDDC5C", style='filled',
                         penwidth='3', fontsize='20', width='1.1', height='0.6', fontname='Arial bold')

    edges_added = []
    # for every q k v node, plot an edge to output node
    for node in adjLists['head_to_head_adjList'].keys():
        sender_name = f"{node[0]} , {node[1]} {node[2]}"
        receiver_name = f"{node[0]} , {node[1]}"
        dot.edge(sender_name, receiver_name, color = '#D4AF37')
        edges_added.append((sender_name, receiver_name))

    for node in adjLists['mlp_to_head_adjList'].keys():
        sender_name = f"{node[0]} , {node[1]} {node[2]}"
        dot.node(sender_name, color="black", fillcolor="#FDDC5C", style='filled',
                         penwidth='3', fontsize='20', width='1.1', height='0.6', fontname='Arial bold')
        sender_name = f"{node[0]} , {node[1]}"
        dot.node(sender_name, color="black", fillcolor="#FDDC5C", style='filled',
                         penwidth='3', fontsize='20', width='1.1', height='0.6', fontname='Arial bold')

    # for every q k v node, plot an edge to output node
    for node in adjLists['mlp_to_head_adjList'].keys():
        sender_name = f"{node[0]} , {node[1]} {node[2]}"
        receiver_name = f"{node[0]} , {node[1]}"
        if (sender_name, receiver_name) not in edges_added:
            dot.edge(sender_name, receiver_name, color = '#D4AF37')

    def loop_adjList(adjList):
        for end_node, start_nodes_list in adjList.items():
            if isinstance(end_node, int):
                receiver_name = "MLP " + str(end_node)
            elif isinstance(end_node, tuple):
                if len(end_node) == 3:
                    receiver_name = f"{end_node[0]} , {end_node[1]} {end_node[2]}"
                elif len(end_node) == 2:
                    receiver_name = f"{end_node[0]} , {end_node[1]}"
            else:
                receiver_name = 'resid_post'
            for start in start_nodes_list:
                if isinstance(start, int):
                    sender_name = "MLP " + str(start)
                elif isinstance(start, tuple):
                    if len(start) == 3:
                        sender_name = f"{start[0]} , {start[1]} {start[2]}"
                    elif len(start) == 2:
                        sender_name = f"{start[0]} , {start[1]}"
                dot.node(sender_name, color="black", fillcolor="#FDDC5C", style='filled',
                         penwidth='3', fontsize='20', width='1.1', height='0.6', fontname='Arial bold')
                dot.node(receiver_name, color="black", fillcolor="#FDDC5C", style='filled',
                         penwidth='3', fontsize='20', width='1.1', height='0.6', fontname='Arial bold')
                dot.edge(sender_name, receiver_name, color = '#D4AF37', penwidth='2.5')

    for aL in adjLists.values():
        loop_adjList(aL)
        # loop_adjList(head_to_head_adjList)
        # loop_adjList(mlp_to_mlp_adjList)
        # loop_adjList(head_to_mlp_adjList)
        # loop_adjList(mlp_to_head_adjList)
        # loop_adjList(heads_to_resid)
        # loop_adjList(mlps_to_resid)

    # Display the graph in Colab
    # display(Source(dot.source))

    # Save the graph to a file
    dot.format = 'png'  # You can change this to 'pdf', 'png', etc. based on your needs
    dot.render(filename)
    files.download(filename + ".png")

# %%
# plot_graph_adjacency_qkv(head_to_head_adjList, mlp_to_mlp_adjList, head_to_mlp_adjList,
#                          mlp_to_head_adjList, heads_to_resid, mlps_to_resid, filename= task+"_qkv_circ")

# %%
plot_graph_adjacency_qkv(months_adjlists, filename= task+"_qkv_circ")

# %% [markdown]
# # qkv nw

# %%
from graphviz import Digraph, Source
from IPython.display import display
from google.colab import files

# head_to_head_adjList, mlp_to_mlp_adjList, head_to_mlp_adjList, mlp_to_head_adjList, heads_to_resid, mlps_to_resid,
def plot_graph_adjacency_qkv(adjLists,
                             filename="circuit_graph", highlighted_nodes=None):
    dot = Digraph()
    dot.attr(ranksep='0.45', nodesep='0.11')  # vert height- ranksep, nodesep- w

    dot.node('resid_post', color="black", fillcolor="#ADD8E6", style='filled',
                         penwidth='3', fontsize='20', width='1.1', height='0.6', fontname='Arial bold')

    for node in adjLists['mlp_to_mlp_adjList'].keys():
        sender_name = "MLP " + str(node)
        dot.node(sender_name, color="black", fillcolor="#ADD8E6", style='filled',
                         penwidth='3', fontsize='20', width='1.1', height='0.6', fontname='Arial bold')

    for node in adjLists['head_to_head_adjList'].keys():
        sender_name = f"{node[0]} , {node[1]} {node[2]}"
        dot.node(sender_name, color="black", fillcolor="#ADD8E6", style='filled',
                         penwidth='3', fontsize='20', width='1.1', height='0.6', fontname='Arial bold')
        sender_name = f"{node[0]} , {node[1]}"
        dot.node(sender_name, color="black", fillcolor="#ADD8E6", style='filled',
                         penwidth='3', fontsize='20', width='1.1', height='0.6', fontname='Arial bold')

    edges_added = []
    # for every q k v node, plot an edge to output node
    for node in adjLists['head_to_head_adjList'].keys():
        sender_name = f"{node[0]} , {node[1]} {node[2]}"
        receiver_name = f"{node[0]} , {node[1]}"
        dot.edge(sender_name, receiver_name, color = 'blue')
        edges_added.append((sender_name, receiver_name))

    for node in adjLists['mlp_to_head_adjList'].keys():
        sender_name = f"{node[0]} , {node[1]} {node[2]}"
        dot.node(sender_name, color="black", fillcolor="#ADD8E6", style='filled',
                         penwidth='3', fontsize='20', width='1.1', height='0.6', fontname='Arial bold')
        sender_name = f"{node[0]} , {node[1]}"
        dot.node(sender_name, color="black", fillcolor="#ADD8E6", style='filled',
                         penwidth='3', fontsize='20', width='1.1', height='0.6', fontname='Arial bold')

    # for every q k v node, plot an edge to output node
    for node in adjLists['mlp_to_head_adjList'].keys():
        sender_name = f"{node[0]} , {node[1]} {node[2]}"
        receiver_name = f"{node[0]} , {node[1]}"
        if (sender_name, receiver_name) not in edges_added:
            dot.edge(sender_name, receiver_name, color = 'blue')

    def loop_adjList(adjList):
        for end_node, start_nodes_list in adjList.items():
            if isinstance(end_node, int):
                receiver_name = "MLP " + str(end_node)
            elif isinstance(end_node, tuple):
                if len(end_node) == 3:
                    receiver_name = f"{end_node[0]} , {end_node[1]} {end_node[2]}"
                elif len(end_node) == 2:
                    receiver_name = f"{end_node[0]} , {end_node[1]}"
            else:
                receiver_name = 'resid_post'
            for start in start_nodes_list:
                if isinstance(start, int):
                    sender_name = "MLP " + str(start)
                elif isinstance(start, tuple):
                    if len(start) == 3:
                        sender_name = f"{start[0]} , {start[1]} {start[2]}"
                    elif len(start) == 2:
                        sender_name = f"{start[0]} , {start[1]}"
                dot.node(sender_name, color="black", fillcolor="#ADD8E6", style='filled',
                         penwidth='3', fontsize='20', width='1.1', height='0.6', fontname='Arial bold')
                dot.node(receiver_name, color="black", fillcolor="#ADD8E6", style='filled',
                         penwidth='3', fontsize='20', width='1.1', height='0.6', fontname='Arial bold')
                dot.edge(sender_name, receiver_name, color = 'blue', penwidth='2.5')

    for aL in adjLists.values():
        loop_adjList(aL)
        # loop_adjList(head_to_head_adjList)
        # loop_adjList(mlp_to_mlp_adjList)
        # loop_adjList(head_to_mlp_adjList)
        # loop_adjList(mlp_to_head_adjList)
        # loop_adjList(heads_to_resid)
        # loop_adjList(mlps_to_resid)

    # Display the graph in Colab
    # display(Source(dot.source))

    # Save the graph to a file
    dot.format = 'png'  # You can change this to 'pdf', 'png', etc. based on your needs
    dot.render(filename)
    files.download(filename + ".png")

# %%
plot_graph_adjacency_qkv(numwords_adjlists, filename= "numwords_qkv_circ")

# %% [markdown]
# # qkv n

# %%
from graphviz import Digraph, Source
from IPython.display import display
from google.colab import files

# head_to_head_adjList, mlp_to_mlp_adjList, head_to_mlp_adjList, mlp_to_head_adjList, heads_to_resid, mlps_to_resid,
def plot_graph_adjacency_qkv(adjLists,
                             filename="circuit_graph", highlighted_nodes=None):
    dot = Digraph()
    dot.attr(ranksep='0.45', nodesep='0.11')  # vert height- ranksep, nodesep- w

    dot.node('resid_post', color="black", fillcolor="#ffcccb", style='filled',
                         penwidth='3', fontsize='20', width='1.1', height='0.6', fontname='Arial bold')

    for node in adjLists['mlp_to_mlp_adjList'].keys():
        sender_name = "MLP " + str(node)
        dot.node(sender_name, color="black", fillcolor="#ffcccb", style='filled',
                         penwidth='3', fontsize='20', width='1.1', height='0.6', fontname='Arial bold')

    for node in adjLists['head_to_head_adjList'].keys():
        sender_name = f"{node[0]} , {node[1]} {node[2]}"
        dot.node(sender_name, color="black", fillcolor="#ffcccb", style='filled',
                         penwidth='3', fontsize='20', width='1.1', height='0.6', fontname='Arial bold')
        sender_name = f"{node[0]} , {node[1]}"
        dot.node(sender_name, color="black", fillcolor="#ffcccb", style='filled',
                         penwidth='3', fontsize='20', width='1.1', height='0.6', fontname='Arial bold')

    edges_added = []
    # for every q k v node, plot an edge to output node
    for node in adjLists['head_to_head_adjList'].keys():
        sender_name = f"{node[0]} , {node[1]} {node[2]}"
        receiver_name = f"{node[0]} , {node[1]}"
        dot.edge(sender_name, receiver_name, color = 'red')
        edges_added.append((sender_name, receiver_name))

    for node in adjLists['mlp_to_head_adjList'].keys():
        sender_name = f"{node[0]} , {node[1]} {node[2]}"
        dot.node(sender_name, color="black", fillcolor="#ffcccb", style='filled',
                         penwidth='3', fontsize='20', width='1.1', height='0.6', fontname='Arial bold')
        sender_name = f"{node[0]} , {node[1]}"
        dot.node(sender_name, color="black", fillcolor="#ffcccb", style='filled',
                         penwidth='3', fontsize='20', width='1.1', height='0.6', fontname='Arial bold')

    # for every q k v node, plot an edge to output node
    for node in adjLists['mlp_to_head_adjList'].keys():
        sender_name = f"{node[0]} , {node[1]} {node[2]}"
        receiver_name = f"{node[0]} , {node[1]}"
        if (sender_name, receiver_name) not in edges_added:
            dot.edge(sender_name, receiver_name, color = 'red')

    def loop_adjList(adjList):
        for end_node, start_nodes_list in adjList.items():
            if isinstance(end_node, int):
                receiver_name = "MLP " + str(end_node)
            elif isinstance(end_node, tuple):
                if len(end_node) == 3:
                    receiver_name = f"{end_node[0]} , {end_node[1]} {end_node[2]}"
                elif len(end_node) == 2:
                    receiver_name = f"{end_node[0]} , {end_node[1]}"
            else:
                receiver_name = 'resid_post'
            for start in start_nodes_list:
                if isinstance(start, int):
                    sender_name = "MLP " + str(start)
                elif isinstance(start, tuple):
                    if len(start) == 3:
                        sender_name = f"{start[0]} , {start[1]} {start[2]}"
                    elif len(start) == 2:
                        sender_name = f"{start[0]} , {start[1]}"
                dot.node(sender_name, color="black", fillcolor="#ffcccb", style='filled',
                         penwidth='3', fontsize='20', width='1.1', height='0.6', fontname='Arial bold')
                dot.node(receiver_name, color="black", fillcolor="#ffcccb", style='filled',
                         penwidth='3', fontsize='20', width='1.1', height='0.6', fontname='Arial bold')
                dot.edge(sender_name, receiver_name, color = 'red', penwidth='2.5')

    for aL in adjLists.values():
        loop_adjList(aL)
        # loop_adjList(head_to_head_adjList)
        # loop_adjList(mlp_to_mlp_adjList)
        # loop_adjList(head_to_mlp_adjList)
        # loop_adjList(mlp_to_head_adjList)
        # loop_adjList(heads_to_resid)
        # loop_adjList(mlps_to_resid)

    # Display the graph in Colab
    # display(Source(dot.source))

    # Save the graph to a file
    dot.format = 'png'  # You can change this to 'pdf', 'png', etc. based on your needs
    dot.render(filename)
    files.download(filename + ".png")

# %%
plot_graph_adjacency_qkv(numerals_adjlists, filename= "numerals_qkv_circ")

# %% [markdown]
# # qkv overlap

# %% [markdown]
# todo

# %%
def get_node_name(end_node):
    if isinstance(end_node, int):
        receiver_name = "MLP " + str(end_node)
    elif isinstance(end_node, tuple):
        if len(end_node) == 3:
            receiver_name = f"{end_node[0]} , {end_node[1]} {end_node[2]}"
        elif len(end_node) == 2:
            receiver_name = f"{end_node[0]} , {end_node[1]}"
    else:
        receiver_name = 'resid_post'

# %%
def plot_graph_adjacency(numerals_adjlists, numwords_adjlists, months_adjlists,
                             filename="circuit_graph", highlighted_nodes=None):
    dot = Digraph()
    # dot.attr(ranksep='0.45', nodesep='0.11')  # vert height- ranksep, nodesep- w
    dot.attr(ranksep='0.45', nodesep='0.105')  # vert height- ranksep, nodesep- w

    edges_added = [] # global var so no need pass in
    def loop_adjList(adjList):
        for end_node, start_nodes_list in adjList.items():
            receiver_name = get_node_name(end_node)
            for start in start_nodes_list:
                sender_name = get_node_name(start)
                dot.node(sender_name, color="#ffcccb", style='filled')
                dot.node(receiver_name, color="#ffcccb", style='filled')
                if (sender_name, receiver_name) not in edges_added:
                    dot.edge(sender_name, receiver_name, color = 'red')
                    edges_added.append((sender_name, receiver_name))

    edge_type_list = ['head_to_head_adjList', 'mlp_to_mlp_adjList', 'head_to_mlp_adjList',  'mlp_to_head_adjList', 'heads_to_resid', 'mlps_to_resid']

    nodes_in_graph = []
    for edge_type in edge_type_list:
        adjL_1 = numerals_adjlists[edge_type]
        adjL_2 = numwords_adjlists[edge_type]
        adjL_3 = months_adjlists[edge_type]
        nodes_in_graph = get_overlap(dot, adjL_1, adjL_2, adjL_3, nodes_in_graph)
        # loop_adjList(adjL_1)

    # # Display the graph in Colab
    # display(Source(dot.source))

    dot.format = 'pdf'  # You can change this to 'pdf', 'png', etc. based on your needs
    # dot.format = 'png'  # You can change this to 'pdf', 'svg', etc. based on your needs
    dot.render(filename)
    files.download(filename + ".pdf")
    # files.download(filename + ".png")

# %%
plot_graph_adjacency(numerals_adjlists, numwords_adjlists, months_adjlists, filename="all_no_qkv_circ")
